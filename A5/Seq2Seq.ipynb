# %% [markdown]
# # Load metadata
#
# This assumes that the file train.zip has been unzipped in the current directory.  If needed, insert code here to load the data from your computer.

# %%
# !unzip train.zip
# !ls

# %%
import json
import numpy as np


# load metadata
with open("train.json", 'r') as f:
    metadata = json.load(f)
n_claims = len(metadata)

metadata;

# %% [markdown]
# # RNN architecture
#
# We define a simple RNN that processes one token at time to update a hidden vector.  The last hidden vector is passed to a classifier that uses a softmax to predict the category.

# %%
import torch
import torch.nn as nn
import numpy as np
import random

class RNN(nn.Module):
    def __init__(self, input_size, hidden_size):
        super(RNN, self).__init__()
        self.hidden_size = hidden_size
        self.i2h = nn.Linear(input_size + hidden_size, hidden_size)

    def forward(self, input, hidden):
        combined = torch.cat((input, hidden), 1)
        hidden = self.i2h(combined)
        return hidden

    def initHidden(self):
        return torch.zeros(1, self.hidden_size)
      
      
class Classifier(nn.Module):
    def __init__(self, hidden_size, output_size):
        super(Classifier, self).__init__()
        self.hidden_size = hidden_size
        self.h2o = nn.Linear(hidden_size, output_size)
        self.softmax = nn.LogSoftmax(dim=1)

    def forward(self, hidden):
        hidden = self.h2o(hidden)
        output = self.softmax(hidden)
        return output

# %% [markdown]
# # Sample a claim & claimant
# Sample a claim, tokenize it and embed it.

# %%
# !pip install bpemb
from bpemb import BPEmb
n_embedding_dims = 50
bpemb_en = BPEmb(lang="en", dim=n_embedding_dims)

def sampleClaim(metadata): 
    id = random.randint(0, len(metadata) - 1)
    claim = metadata[id]["claim"]
    embedding = bpemb_en.embed(claim)
    embedding = np.reshape(embedding,(embedding.shape[0],1,embedding.shape[1]))
    label = metadata[id]["label"]
    label_tensor = torch.tensor([label], dtype=torch.long)
    claim_tensor = torch.tensor(embedding, dtype=torch.float)
    return claim_tensor, label_tensor, claim, label, id
# Out:
# Collecting bpemb
#   Downloading https://files.pythonhosted.org/packages/bc/70/468a9652095b370f797ed37ff77e742b11565c6fd79eaeca5f2e50b164a7/bpemb-0.3.0-py3-none-any.whl
# Requirement already satisfied: tqdm in /usr/local/lib/python3.6/dist-packages (from bpemb) (4.28.1)
# Collecting sentencepiece (from bpemb)
#   Downloading https://files.pythonhosted.org/packages/00/95/7f357995d5eb1131aa2092096dca14a6fc1b1d2860bd99c22a612e1d1019/sentencepiece-0.1.82-cp36-cp36m-manylinux1_x86_64.whl (1.0MB)
#      |████████████████████████████████| 1.0MB 7.7MB/s
# Requirement already satisfied: gensim in /usr/local/lib/python3.6/dist-packages (from bpemb) (3.6.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.6/dist-packages (from bpemb) (2.21.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from bpemb) (1.16.4)
# Requirement already satisfied: smart-open>=1.2.1 in /usr/local/lib/python3.6/dist-packages (from gensim->bpemb) (1.8.4)
# Requirement already satisfied: six>=1.5.0 in /usr/local/lib/python3.6/dist-packages (from gensim->bpemb) (1.12.0)
# Requirement already satisfied: scipy>=0.18.1 in /usr/local/lib/python3.6/dist-packages (from gensim->bpemb) (1.3.0)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests->bpemb) (3.0.4)
# Requirement already satisfied: idna<2.9,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests->bpemb) (2.8)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests->bpemb) (2019.6.16)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests->bpemb) (1.24.3)
# Requirement already satisfied: boto>=2.32 in /usr/local/lib/python3.6/dist-packages (from smart-open>=1.2.1->gensim->bpemb) (2.49.0)
# Requirement already satisfied: boto3 in /usr/local/lib/python3.6/dist-packages (from smart-open>=1.2.1->gensim->bpemb) (1.9.189)
# Requirement already satisfied: jmespath<1.0.0,>=0.7.1 in /usr/local/lib/python3.6/dist-packages (from boto3->smart-open>=1.2.1->gensim->bpemb) (0.9.4)
# Requirement already satisfied: s3transfer<0.3.0,>=0.2.0 in /usr/local/lib/python3.6/dist-packages (from boto3->smart-open>=1.2.1->gensim->bpemb) (0.2.1)
# Requirement already satisfied: botocore<1.13.0,>=1.12.189 in /usr/local/lib/python3.6/dist-packages (from boto3->smart-open>=1.2.1->gensim->bpemb) (1.12.189)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1; python_version >= "2.7" in /usr/local/lib/python3.6/dist-packages (from botocore<1.13.0,>=1.12.189->boto3->smart-open>=1.2.1->gensim->bpemb) (2.5.3)
# Requirement already satisfied: docutils>=0.10 in /usr/local/lib/python3.6/dist-packages (from botocore<1.13.0,>=1.12.189->boto3->smart-open>=1.2.1->gensim->bpemb) (0.14)
# Installing collected packages: sentencepiece, bpemb
# Successfully installed bpemb-0.3.0 sentencepiece-0.1.82
# downloading https://nlp.h-its.org/bpemb/en/en.wiki.bpe.vs10000.model
# 100%|██████████| 400869/400869 [00:00<00:00, 577985.00B/s]
# downloading https://nlp.h-its.org/bpemb/en/en.wiki.bpe.vs10000.d50.w2v.bin.tar.gz
# 100%|██████████| 1924908/1924908 [00:01<00:00, 1729422.02B/s]
# /usr/local/lib/python3.6/dist-packages/smart_open/smart_open_lib.py:398: UserWarning: This function is deprecated, use smart_open.open instead. See the migration notes for details: https://github.com/RaRe-Technologies/smart_open/blob/master/README.rst#migrating-to-the-new-open-function
#   'See the migration notes for details: %s' % _MIGRATION_NOTES_URL

# %%
def sampleClaimant(id): 
    claimant = metadata[id]["claimant"]
    embedding = bpemb_en.embed(claimant)
    embedding = np.reshape(embedding,(embedding.shape[0],1,embedding.shape[1]))
    claimant_tensor = torch.tensor(embedding, dtype=torch.float)
    return claimant_tensor, claimant

# %% [markdown]
# # Training procedure

# %%
def train(category_tensor, line_tensor, update=True):
    rnnOptimizer.zero_grad()
    classifierOptimizer.zero_grad()

    hidden = rnn.initHidden()
    for i in range(line_tensor.size()[0]):
        hidden = rnn(line_tensor[i], hidden)
    output = classifier(hidden)

    loss = criterion(output, category_tensor)
    if update:
        loss.backward()
        rnnOptimizer.step()
        classifierOptimizer.step()
        
    return output, loss.item()

# %% [markdown]
# # Train RNN and plot results

# %%
import time
import math

n_hidden = 128
n_categories = 3
rnn = RNN(n_embedding_dims, n_hidden)
classifier = Classifier(n_hidden, n_categories)

criterion = nn.NLLLoss()
learning_rate = 1e-4
rnnOptimizer = torch.optim.Adam(rnn.parameters(), lr=learning_rate)
classifierOptimizer = torch.optim.Adam(classifier.parameters(), lr=learning_rate)

n_iters = 100000
plot_every = 1000

# Keep track of losses for plotting
current_loss = 0
all_losses = []

def timeSince(since):
    now = time.time()
    s = now - since
    m = math.floor(s / 60)
    s -= m * 60
    return '%dm %ds' % (m, s)

start = time.time()

train_data = metadata[:10000]
test_data = metadata[10000:]
train_cumulative_loss = 0
test_cumulative_loss = 0
average_train_accuracy = 0
average_test_accuracy = 0
all_train_losses = []
all_train_accuracies = []
all_test_losses = []
all_test_accuracies = []
count = 0
for iter in range(1, n_iters + 1):
    train_line_tensor, train_category_tensor, train_line, train_category, train_id = sampleClaim(train_data)
    train_output, train_loss = train(train_category_tensor, train_line_tensor)    
    top_train_value, top_train_index = train_output.topk(1)
    train_guess_category = top_train_index[0].item()
    train_cumulative_loss += train_loss
    train_accuracy = 1 if train_guess_category == train_category else 0
    average_train_accuracy = (average_train_accuracy * count + train_accuracy) / (count+1)
    
    test_line_tensor, test_category_tensor, test_line, test_category, test_id = sampleClaim(test_data)
    test_output, test_loss = train(test_category_tensor, test_line_tensor, update=False)
    top_test_value, top_test_index = test_output.topk(1)
    test_guess_category = top_test_index[0].item()
    test_cumulative_loss += test_loss
    test_accuracy = 1 if test_guess_category == test_category else 0
    average_test_accuracy = (average_test_accuracy * count + test_accuracy) / (count+1)
    count += 1

    # Add current loss avg to list of losses
    if iter % plot_every == 0:
        train_correct = '✓' if train_guess_category == train_category else '✗ (%s)' % train_category
        print('Train: %d  %d%% (%s) average_accuracy=%.4f average_loss=%.4f %s / %s %s' % (iter, iter / n_iters * 100, timeSince(start), average_train_accuracy, train_cumulative_loss / plot_every, train_line, train_guess_category, train_correct))
        test_correct = '✓' if test_guess_category == test_category else '✗ (%s)' % test_category
        print('Test: %d  %d%% (%s) average_accuracy=%.4f average_loss=%.4f %s / %s %s' % (iter, iter / n_iters * 100, timeSince(start), average_test_accuracy, test_cumulative_loss / plot_every, test_line, test_guess_category, test_correct))
        all_train_losses.append(train_cumulative_loss / plot_every)
        all_train_accuracies.append(average_train_accuracy)
        all_test_losses.append(test_cumulative_loss / plot_every)
        all_test_accuracies.append(average_test_accuracy)
        train_cumulative_loss = 0
        average_train_accuracy = 0
        test_cumulative_loss = 0
        average_test_accuracy = 0
        count = 0
        
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker

plt.figure()
plt.plot(all_train_accuracies)
# Out:
# Train: 1000  1% (0m 11s) average_accuracy=0.5340 average_loss=0.9709 "Public trust in our election system is at an all-time low." / 1 ✗ (0)
# Test: 1000  1% (0m 11s) average_accuracy=0.5220 average_loss=0.9588 "Mr. Trump is self-financing his campaign, so we don’t have any donors." / 1 ✗ (0)
# Train: 2000  2% (0m 23s) average_accuracy=0.5710 average_loss=0.9433 "Wisconsin does not have a deficit. Thanks to Republican reforms, the 2014 budget will begin with a $443 million surplus." / 1 ✓
# Test: 2000  2% (0m 23s) average_accuracy=0.5170 average_loss=0.9435 "John McCain intervened, which helped Airbus get that Pentagon contract." / 1 ✓
# Train: 3000  3% (0m 35s) average_accuracy=0.5590 average_loss=0.9073 Outback Steakhouse announced that supporters of President Donald Trump are barred from their restaurants. / 0 ✓
# Test: 3000  3% (0m 35s) average_accuracy=0.5570 average_loss=0.9404 "Black Diamond Collection" Disney films on VHS are worth thousands of dollars, particularly "Beauty and the Beast."
#
#
#
#
# 						See Example(s)
#
#
#
#
# 									Are the Disney Black Diamond editions of VHS tapes really as valuable as people are claiming? There are articles circulating about how these vhs tapes are rare and could be worth thousands. I saw posts on eBay with said VHS tapes--astronomical prices. The question is, is anyone actually buying those? Or is it just a scam to get people to waste their time? Or maybe an advertising scam to get people to talk about Disney VHS tapes?
#
# Apparently I have roughly $50,000 “worth" of Disney VHS tapes in my attic. pic.twitter.com/GhOplfnl7q
# — Scott Gustin (@ScottGustin) May 31, 2016
# 																			Collected via e-mail and Twitter, June 2016 / 0 ✗ (1)
# Train: 4000  4% (0m 46s) average_accuracy=0.5380 average_loss=0.9275 "When you pull up to the gas pump to fill up your car, get your cell phone and search for Bluetooth devices. If a sequence of letters and numbers show up don’t pay at the pump. One of the pumps has a credit card skimmer inside of it. All of these skimmers run on bluetooth." / 0 ✗ (1)
# Test: 4000  4% (0m 46s) average_accuracy=0.5480 average_loss=0.9171 “Mr. Steele was on the payroll of Fusion GPS, who was being paid by the Democratic Party to do opposition research on Donald Trump. That while he was working with the FBI, he was shopping this dossier all over the world. That’s not what an informant should do.” / 0 ✗ (1)
# Train: 5000  5% (0m 59s) average_accuracy=0.5580 average_loss=0.9200 Pro-Donald Trump activists were accosted by a "violent mob" while eating pizza at a Chicano Park. / 0 ✗ (1)
# Test: 5000  5% (0m 59s) average_accuracy=0.5800 average_loss=0.9145 "More Americans receive food aid than work in (the) private sector." / 1 ✗ (0)
# Train: 6000  6% (1m 11s) average_accuracy=0.5560 average_loss=0.9360 "We spend about 75 percent of the entire cost of the military aspect of NATO." / 1 ✓
# Test: 6000  6% (1m 11s) average_accuracy=0.5690 average_loss=0.8941 Rape would be designated a pre-existing condition under the American Health Care Act. / 0 ✗ (1)
# Train: 7000  7% (1m 24s) average_accuracy=0.5600 average_loss=0.9408 Nike donated three times more to Republicans than Democrats during the 2018 federal election cycle, up to August 2018. / 0 ✗ (1)
# Test: 7000  7% (1m 24s) average_accuracy=0.5500 average_loss=0.9261 In 2018, Oprah Winfrey promoted a pro-choice online campaign called #ShoutYourAbortion. / 0 ✗ (1)
# Train: 8000  8% (1m 37s) average_accuracy=0.5790 average_loss=0.8997 Says Hillary Clinton’s energy agenda "will cost the U.S. economy over $5 trillion" / 1 ✗ (0)
# Test: 8000  8% (1m 37s) average_accuracy=0.5440 average_loss=0.9360 If carried out, President Donald Trump's 12 November proposal to finalize the election night results of two contests in Florida would exclude ballots mailed by U.S. military personnel overseas. / 0 ✗ (1)
# Train: 9000  9% (1m 49s) average_accuracy=0.5670 average_loss=0.9145 A reporter who was found dead mailed her lawyer a recording “to be played if anything happens to her." / 0 ✓
# Test: 9000  9% (1m 49s) average_accuracy=0.5850 average_loss=0.8898 Marjory Stoneman Douglas student David Hogg was caught lying about being on campus during a February 2018 school shooting when he told CBS that he had to get on his bicycle and ride to school. / 0 ✓
# Train: 10000  10% (2m 2s) average_accuracy=0.5470 average_loss=0.9290 Missouri is "#1 in the nation for holding down tuition increases at public universities." / 1 ✓
# Test: 10000  10% (2m 2s) average_accuracy=0.5600 average_loss=0.9361 The government buried news of weather modification in the classifieds section of a small newspaper.
#
#
#
#
# 						See Example(s)
#
#
#
#
# 									Any thoughts on this:
#
# http://wakeup-world.com/2016/03/12/government-quietly-admits-to-weather-modification-program/
#
# Thanks for this -- very cool https://t.co/P1kUTPOM2r
# — Clyde Lewis (@ClydeLewis) March 16, 2016
#
#
# 																			Collected via e-mail, Twitter, and Facebook, March 2016 / 0 ✗ (1)
# Train: 11000  11% (2m 15s) average_accuracy=0.5920 average_loss=0.8724 Malaysia Airlines Flight 370 was captured by the U.S. Navy. / 0 ✓
# Test: 11000  11% (2m 15s) average_accuracy=0.5510 average_loss=0.9429 Elizabeth Warren lives in a multi-million-dollar mansion and relied on scant Native American heritage claims to land a job at Harvard. / 0 ✗ (1)
# Train: 12000  12% (2m 26s) average_accuracy=0.5720 average_loss=0.9395 Republicans "made it easier to buy a gun" in states they won in 2010. / 0 ✗ (1)
# Test: 12000  12% (2m 26s) average_accuracy=0.5710 average_loss=0.9222  "No, we [Democrats] don't get much support from Wall Street."  / 0 ✓
# Train: 13000  13% (2m 39s) average_accuracy=0.5570 average_loss=0.9165  "US Surgeon, Who Exposed Clinton Foundation Corruption In Haiti, Found Dead"  / 0 ✓
# Test: 13000  13% (2m 39s) average_accuracy=0.5590 average_loss=0.8993 Gravity Payments CEO Dan Price rented his house in order to make ends meet after taking a $900,000 pay cut and raising the minimum salary at his company to $70,000. / 0 ✗ (1)
# Train: 14000  14% (2m 50s) average_accuracy=0.5820 average_loss=0.9068 The medical marijuana ballot initiative "doesn’t require a physician writing a prescription" and can be for conditions like "having a back that needs to be scratched." / 0 ✗ (1)
# Test: 14000  14% (2m 50s) average_accuracy=0.6080 average_loss=0.8784 One-third of the caravan migrants have HIV/AIDS, tuberculosis, or chicken pox. / 0 ✗ (1)
# Train: 15000  15% (3m 2s) average_accuracy=0.5960 average_loss=0.8939 Weapons-wielding clowns from the U.S. invaded Canada and murdered 23 victims. / 0 ✓
# Test: 15000  15% (3m 2s) average_accuracy=0.5850 average_loss=0.8927 Says Obama administration delay of health care law's employer mandate affects about 1 percent of the American workforce. / 0 ✗ (1)
# Train: 16000  16% (3m 15s) average_accuracy=0.5710 average_loss=0.9088 Peppa Pig causes autism / 0 ✓
# Test: 16000  16% (3m 15s) average_accuracy=0.5570 average_loss=0.9226 "Obama Declares November National Muslim Appreciation Month." / 1 ✗ (0)
# Train: 17000  17% (3m 27s) average_accuracy=0.5880 average_loss=0.8954 Mohammed Atta, a convicted terrorist released by Israel at the insistence of the U.S., participated in the 9/11 terrorist attacks.
#
#
#
#
# 						See Example(s)
#
#
#
#
# 									I received this e-mail note today, from a reliable source. What can we say?
#
# An Arab terrorist named Atta blew up a bus in Israel in 1986. The Israelis captured, tried and imprisoned him. As part of the Oslo agreement Israel had to agree to release so called "political prisoners". However, Israeli officials insisted that they would not release any with "blood on their hands". Some well meaning American President and Secretary of State insisted that all be released.
#
# Thus Mr. Atta was freed and eventually thanked the US by flying an airplane into Tower One of the World Trade Center. This was reported by many of the networks at the time the terrorists were first identified. It was missing from later reports. That President and Secretary of State were Ronald Reagan and George Schultz.
#
#
#
# In case you didn't know ...
#
# Terrorist pilot Mohammed Atta blew up a bus in Israel in 1986. The Israelis captured, tried and imprisoned him.
#
# As part of the Oslo agreement with the Palestinians in 1993, Israel had to agree to release so-called "political prisoners." However, the Israelis would not release any with "blood on their hands."
#
# The American President at the time, Bill Clinton, and his Secretary of State, Warren Christopher, "insisted" that all prisoners be released. Thus Mr. Atta was freed and eventually "Thanked the US" by flying an airplane into Tower One of the World Trade Center.
#
# This was reported by many of the American TV networks at the time that the terrorists were first identified. It was censored in the US from all later reports.
#
# The American public must be made aware of this fact. / 0 ✓
# Test: 17000  17% (3m 27s) average_accuracy=0.6070 average_loss=0.8941 Says Donald Trump’s health care policies have "left millions more Americans uninsured since he took office." / 1 ✓
# Train: 18000  18% (3m 39s) average_accuracy=0.5880 average_loss=0.9065 Episodes of some syndicated TV series are sped up to fit more commercials into their time slots. / 1 ✗ (2)
# Test: 18000  18% (3m 39s) average_accuracy=0.5450 average_loss=0.9209 Cadbury chocolate infected with blood from HIV positive man / 0 ✓
# Train: 19000  19% (3m 51s) average_accuracy=0.5860 average_loss=0.8901 The religious liberty bill proposed in the Georgia House of Representatives does not specifically exclude corporations, which means they can legally claim a religious exemption. / 0 ✗ (2)
# Test: 19000  19% (3m 51s) average_accuracy=0.5600 average_loss=0.9308 A British mother lost custody of her children because she ignored warnings about 'co-sleeping' with her children. / 0 ✗ (1)
# Train: 20000  20% (4m 3s) average_accuracy=0.5670 average_loss=0.9109 "Today many Florida teachers are at risk of having their pay impacted by the performance of children who are not even in their classrooms or subject areas." / 1 ✓
# Test: 20000  20% (4m 3s) average_accuracy=0.5450 average_loss=0.9018 Says "Rosie O’Donnell apparently committed the same offense five times, five times, when she broke the identical law that Dinesh (D'Souza) was prosecuted for." / 1 ✗ (0)
# Train: 21000  21% (4m 14s) average_accuracy=0.5820 average_loss=0.9139 Says Donald Trump mocked "someone with a disability." / 1 ✗ (2)
# Test: 21000  21% (4m 14s) average_accuracy=0.5850 average_loss=0.9135 Says former President Barack Obama’s Supreme Court nominations "required 60 votes." / 0 ✗ (1)
# Train: 22000  22% (4m 26s) average_accuracy=0.5720 average_loss=0.8977 It is a myth that Florida's education legislation was "negotiated in secret." / 1 ✗ (0)
# Test: 22000  22% (4m 26s) average_accuracy=0.5390 average_loss=0.9449 In Virginia’s Medicaid program, "approximately 30 percent, or $2.7 billion a year, is lost to waste, fraud and inefficiencies." / 1 ✓
# Train: 23000  23% (4m 38s) average_accuracy=0.6030 average_loss=0.8870 There are small islands of fire ants floating in the floodwaters from Tropical Storm Harvey. / 0 ✗ (2)
# Test: 23000  23% (4m 38s) average_accuracy=0.5890 average_loss=0.9115 Republicans extended unemployment insurance under President Bush "when he asked to extend unemployment insurance." / 1 ✓
# Train: 24000  24% (4m 51s) average_accuracy=0.5810 average_loss=0.9253 President Obama has decreed that the phrase "In God We Trust" be removed from all U.S. currency. / 0 ✓
# Test: 24000  24% (4m 51s) average_accuracy=0.5980 average_loss=0.8821 A black box recording has surfaced featuring an eerie message that suggests the disappearance of Malaysia Flight MH370 involved extraterrestrials. / 0 ✓
# Train: 25000  25% (5m 3s) average_accuracy=0.5810 average_loss=0.9115 Says Jeb Bush -- not Charlie Crist -- signed legislation that let Duke Energy collect money for nuclear projects. / 1 ✗ (2)
# Test: 25000  25% (5m 3s) average_accuracy=0.5740 average_loss=0.8984  Suggests John McCain is too old to fulfill another six-year Senate term, saying "the life expectancy of the American male is not 86. It's less."  / 0 ✓
# Train: 26000  26% (5m 15s) average_accuracy=0.5880 average_loss=0.8829 Sitting inside a running, snowed-in car can result in carbon monoxide poisoning. / 0 ✗ (2)
# Test: 26000  26% (5m 15s) average_accuracy=0.5550 average_loss=0.9174 "Larry Krasner is the only candidate running for District Attorney who explicitly pledges to never seek the death penalty." / 1 ✓
# Train: 27000  27% (5m 28s) average_accuracy=0.5800 average_loss=0.9093 "There are places in America that are among the most dangerous in the world. You go to places like Oakland. Or Ferguson. The crime numbers are worse. Seriously." / 1 ✗ (0)
# Test: 27000  27% (5m 28s) average_accuracy=0.5600 average_loss=0.9283 Only 60 of the 1,566 churches in Houston opened to help the victims of Hurricane Harvey. / 0 ✓
# Train: 28000  28% (5m 41s) average_accuracy=0.5880 average_loss=0.8943 Says that "on average, Democratic congressional districts received 81 percent more stimulus funds than Republican districts." / 1 ✓
# Test: 28000  28% (5m 41s) average_accuracy=0.5710 average_loss=0.9174 “We have already made a statement that this is all nonsense, we have nothing to do with this” / 0 ✓
# Train: 29000  28% (5m 52s) average_accuracy=0.5780 average_loss=0.8959 "Since December 2010 Florida has created 540,000 new jobs." / 1 ✓
# Test: 29000  28% (5m 52s) average_accuracy=0.5500 average_loss=0.9339 Boxing promoter Barry Gibson was killed after he revealed that the Mayweather-McGregor fight was going to be fixed. / 0 ✓
# Train: 30000  30% (6m 5s) average_accuracy=0.5870 average_loss=0.8990 A photograph shows Beto O'Rourke with words such as "feminist," "vegan," "atheist," and "queer" painted on his body. / 0 ✓
# Test: 30000  30% (6m 5s) average_accuracy=0.5450 average_loss=0.9432 Says Donald Trump’s "only economic agenda is imposing massive taxes on the American people with a 40 percent tax hike of a giant tariff." / 1 ✓
# Train: 31000  31% (6m 16s) average_accuracy=0.5970 average_loss=0.8957 The Gardasil HPV vaccine has been proved to have caused the deaths of 32 women.
#
#
#
#
# 						See Example(s)
#
#
#
#
# 									32 Girls Have Died
#
# 11,916 adverse events already reported to the CDC ... and counting.
#
# Pain and swelling. Life-threatening muscle weakness. Blood clots in the heart and lungs.
#
# And the deaths of 32 innocent girls and young women.
#
# You might think I'm talking about a deadly new disease or a global epidemic ...
#
# I'm not.
#
# Sadly, it's more sinister than that. The health threats listed above have all been linked with Gardasil, the so-called "cervical cancer vaccine." And thanks to Pharma giant Merck, desperate parents and naive young women believe this vaccine saves lives... they couldn't be more wrong.
#
# That's why HSI's Jenny Thompson has released a new video in which she exposes the deception for what it is — and reveals some truly shocking information no one else is talking about.
#
# And you are the very first to see it.
#
# Please, if you have daughters, granddaughters or friends who might be considering this terrible vaccine, you must watch this video. And please forward it to anyone you think would benefit from the vital information it contains.
#
# If you think you know the whole story on Gardasil, I think you'll be shocked by what you're about to see. Just click here to start watching the video. It's just a few minutes long...and those few minutes might just save a young girl's life.																			Collected via e-mail, April 2009 / 0 ✓
# Test: 31000  31% (6m 16s) average_accuracy=0.5930 average_loss=0.9047 A photograph shows a man who was mugged while delivering comic books to his sick daughter. / 0 ✓
# Train: 32000  32% (6m 28s) average_accuracy=0.5630 average_loss=0.9324 "I have stated my concerns with Amazon long before the Election. Unlike others, they pay little or no taxes to state & local governments, use our Postal System as their Delivery Boy (causing tremendous loss to the U.S.)." / 0 ✗ (1)
# Test: 32000  32% (6m 28s) average_accuracy=0.5600 average_loss=0.9307 The New York Times contradicted their 20 January 2017 report about wire tapping in an article entitled "Trump, Offering No Evidence, Says Obama Tapped His Phones." / 0 ✓
# Train: 33000  33% (6m 40s) average_accuracy=0.5820 average_loss=0.8862 The National Rifle Association was "founded by religious leaders who wanted to protect freed slaves from the Ku Klux Klan." / 0 ✓
# Test: 33000  33% (6m 40s) average_accuracy=0.5930 average_loss=0.9159 California upheld the "right" of pedophiles to marry children as young as 10 years old. / 0 ✓
# Train: 34000  34% (6m 52s) average_accuracy=0.5980 average_loss=0.8963  “Barack Obama and Hillary Clinton refuse to declare war on ISIS.”  / 0 ✓
# Test: 34000  34% (6m 52s) average_accuracy=0.5890 average_loss=0.8957 A white strawberry that tastes like pineapple is available in certain markets.
#
#
#
#
# 						See Example(s)
#
#
#
#
# 									https://twitter.com/UberFacts/status/707397251606380544																			Collected via Twitter, March 2016 / 0 ✗ (2)
# Train: 35000  35% (7m 5s) average_accuracy=0.5670 average_loss=0.8937 “As we speak, we are removing gang members, drug dealers and criminals that threaten our communities and prey on our citizens. Bad ones are going out as I speak and as I have promised throughout the campaign.” / 0 ✗ (1)
# Test: 35000  35% (7m 5s) average_accuracy=0.5710 average_loss=0.9184 The pilot of missing Malaysia Airlines Flight 370 reappeared in Taiwan two years after the plane disappeared. / 0 ✓
# Train: 36000  36% (7m 17s) average_accuracy=0.5950 average_loss=0.8941 "Before Leaving, Obama Enacts Rules to Take $3,000 From EVERY American." / 1 ✓
# Test: 36000  36% (7m 17s) average_accuracy=0.5570 average_loss=0.9462 "What we said was, you can keep (your plan) if it hasn’t changed since the law passed." / 1 ✗ (0)
# Train: 37000  37% (7m 30s) average_accuracy=0.5850 average_loss=0.8981 Are Democrats ‘Trying to Give Illegal Immigrants the Right to Vote’? / 0 ✗ (1)
# Test: 37000  37% (7m 30s) average_accuracy=0.5330 average_loss=0.9280 “We lost, over the last number of years, $800 billion a year. Not a half a million dollars, not 12 cents. We lost $800 billion a year on trade." / 1 ✗ (0)
# Train: 38000  38% (7m 42s) average_accuracy=0.5850 average_loss=0.9224 “Omar Khadr didn’t apologize.” / 0 ✓
# Test: 38000  38% (7m 42s) average_accuracy=0.5800 average_loss=0.9516 Chinese restaurants in one of South Africa's capital cities are now allowed to sell dog meat. / 1 ✗ (0)
# Train: 39000  39% (7m 54s) average_accuracy=0.5630 average_loss=0.9168  Actress Emma Stone: "America made a great choice with Donald Trump."  / 0 ✓
# Test: 39000  39% (7m 54s) average_accuracy=0.5810 average_loss=0.9389 "Your chances of throwing it are actually a little bit better in that situation." / 1 ✗ (0)
# Train: 40000  40% (8m 7s) average_accuracy=0.5630 average_loss=0.9251 In Hillary Clinton's tax returns, "you saw a lot of income coming from donors to the Clinton Foundation and people who benefitted from her State Department term as well." / 1 ✓
# Test: 40000  40% (8m 7s) average_accuracy=0.5380 average_loss=0.9383 John McCain has seven houses. / 0 ✗ (1)
# Train: 41000  41% (8m 19s) average_accuracy=0.5610 average_loss=0.8970 A number advertised on a Facebook page lets callers "leave messages" for Santa Claus.
#
#
#
#
# 						See Example(s)
#
#
#
#
# 									I have seen posts from this page https://www.facebook.com/realsantahotline/ shared by many of my friends and when I called the number listed as the Santa Hotline some guy that said his name was Steve answered and started cursing me any my kids out. Could you guys please let people know this is not real? / 0 ✓
# Test: 41000  41% (8m 19s) average_accuracy=0.5580 average_loss=0.9448 Says judges "get better benefits at a lower cost than everybody else in the state." / 1 ✗ (2)
# Train: 42000  42% (8m 31s) average_accuracy=0.5910 average_loss=0.8757 Dairy Queen is hosting 'Free Cone Day' on 20 March 2017.
#
#
#
#
# 						See Example(s)
#
#
#
#
# 									I've seen on social media that Dairy Queen will be giving away free ice cream cones on March 20th. Typical of viral posts, there's a link that says "click for details," but I didn't in case it's some sort of spam. The Dairy Queen website says nothing of this. Can you confirm or deny?
#
# 																			Collected via e-mail, March 2017 / 0 ✗ (1)
# Test: 42000  42% (8m 31s) average_accuracy=0.5640 average_loss=0.9184 "March For Our Lives is backed by radicals with a history of violent threats, language and actions." / 0 ✓
# Train: 43000  43% (8m 43s) average_accuracy=0.6050 average_loss=0.8860 Says Marco Rubio took "three quarters of a million dollars from fossil fuel executives" during the 2016 Senate election. / 0 ✗ (1)
# Test: 43000  43% (8m 43s) average_accuracy=0.5890 average_loss=0.9060 “The bottom line has to equal 1 percent. A 1 percent cut each year is about $13 billion, actually balances the budget in five years.” / 1 ✗ (0)
# Train: 44000  44% (8m 54s) average_accuracy=0.5980 average_loss=0.8887 “The payout to Omar Khadr was a choice made by Justin Trudeau.” / 0 ✗ (2)
# Test: 44000  44% (8m 54s) average_accuracy=0.6020 average_loss=0.8816 "Obamacare premiums have doubled" in Wisconsin. / 0 ✗ (1)
# Train: 45000  45% (9m 6s) average_accuracy=0.5730 average_loss=0.9020 President Trump has established English as the official language of the United States. / 0 ✓
# Test: 45000  45% (9m 6s) average_accuracy=0.5780 average_loss=0.9155  Announced Charter Communications “has just committed" to investing $25 billion and hiring 20,000 U.S. workers, citing it as evidence that he is keeping his promise to create jobs.  / 0 ✓
# Train: 46000  46% (9m 18s) average_accuracy=0.5930 average_loss=0.8884 An Army report stated Allen West "performed illegal acts, merited court martial, faced 11 years in prison.'" / 0 ✗ (1)
# Test: 46000  46% (9m 18s) average_accuracy=0.5730 average_loss=0.9220 "College debt has increased 170 percent since 2006 and now exceeds $1.5 trillion dollars, which is second only to mortgage debt and surpasses even credit card debt." / 1 ✓
# Train: 47000  47% (9m 31s) average_accuracy=0.5760 average_loss=0.9029 Teachers were not involved in developing the Common Core State Standards. / 1 ✗ (0)
# Test: 47000  47% (9m 31s) average_accuracy=0.5860 average_loss=0.9200 "Starbucks just placed Trump’s photo on (the) floor so every customer (has) to step on it." / 1 ✗ (0)
# Train: 48000  48% (9m 44s) average_accuracy=0.6030 average_loss=0.8706 AARP is "endorsing" the health care reform bill. / 0 ✗ (1)
# Test: 48000  48% (9m 44s) average_accuracy=0.5910 average_loss=0.8960 "Donald Trump said he was excited for the 2008 housing crash that devastated millions of American families, because he thought it would help him scoop up more real estate on the cheap." / 0 ✗ (1)
# Train: 49000  49% (9m 56s) average_accuracy=0.5750 average_loss=0.9099 Says "Donald Trump himself contributed $100,000" to the Clinton Foundation. / 0 ✗ (1)
# Test: 49000  49% (9m 56s) average_accuracy=0.5620 average_loss=0.9202 The CEO of Wonder Bread has cut that company's ties with the NRA and other conservative companies. / 0 ✓
# Train: 50000  50% (10m 9s) average_accuracy=0.5810 average_loss=0.8923 "We have a fire marshal that said, 'Oh we can't allow more people’ ...  And the reason they won't let them in is because they don't know what the hell they're doing." / 0 ✓
# Test: 50000  50% (10m 9s) average_accuracy=0.5520 average_loss=0.9407 Ivanka Trump said that she would "mace" her "father" during an appearance on a talk show. / 0 ✓
# Train: 51000  51% (10m 21s) average_accuracy=0.5940 average_loss=0.8755 The CDC is "spending money on things like jazzercise, urban gardening and massage therapy" that could be redirected to Ebola. / 0 ✗ (1)
# Test: 51000  51% (10m 21s) average_accuracy=0.5890 average_loss=0.9203 "Ohioans can expect to pay up to 41 percent more for their insurance premiums when Obamacare takes effect next year." / 1 ✓
# Train: 52000  52% (10m 34s) average_accuracy=0.5870 average_loss=0.8884 Under Scott Walker, Wisconsin is "still 16,000 manufacturing jobs lower than we were during the recession." / 1 ✓
# Test: 52000  52% (10m 34s) average_accuracy=0.5680 average_loss=0.9179 Says Sen. John McCain "told dreamers that he’ll support the Dream Act, then he voted against it." / 0 ✗ (1)
# Train: 53000  53% (10m 46s) average_accuracy=0.6210 average_loss=0.8575 “We take care of illegal immigrants — people who come into our country illegally — better than we take care of our vets.” / 0 ✓
# Test: 53000  53% (10m 46s) average_accuracy=0.5720 average_loss=0.9223 A short list of "fun facts" distributed on the Internet accurately describes the workings of the U.S. Social Security system. / 1 ✓
# Train: 54000  54% (10m 57s) average_accuracy=0.5810 average_loss=0.8908 Actor-comedian Bill Murray died at age 81 in February 2019, expressing a wish to see ‘Americans united under Trump.’ / 0 ✓
# Test: 54000  54% (10m 57s) average_accuracy=0.5550 average_loss=0.9403 British £5 notes introduced in 2016 contain traces of beef tallow.
#
#
#
#
# 						See Example(s)
#
#
#
#
# 									I have just found out that the new £5 notes are not suitable for vegetarians. Are people aware of this?
#
# 																			Collected via e-mail, November 2016 / 0 ✗ (2)
# Train: 55000  55% (11m 9s) average_accuracy=0.5990 average_loss=0.8491 Is it against the law to shower and do laundry on the same day in California? / 0 ✓
# Test: 55000  55% (11m 9s) average_accuracy=0.5610 average_loss=0.9200 First Lady Melania Trump demanded that the White House be exorcised of "demonic idols and images" allegedly left there by the Obamas before she would enter it. / 0 ✓
# Train: 56000  56% (11m 22s) average_accuracy=0.5960 average_loss=0.8991 "Breaking: Michelle Wolf fired -- Comedy Central apologizes to Sarah Sanders." / 0 ✓
# Test: 56000  56% (11m 22s) average_accuracy=0.5740 average_loss=0.9104 A new tattoo ink changes color depending on a person's glucose levels, meaning people with diabetes can use it to check their blood sugar levels. / 1 ✓
# Train: 57000  56% (11m 33s) average_accuracy=0.6000 average_loss=0.8726 "We had 2 percent of the global market (for advanced batteries) when he (Obama) started. We now have 16 percent, headed to 40 percent by 2015." / 1 ✓
# Test: 57000  56% (11m 33s) average_accuracy=0.5790 average_loss=0.9010 A photograph shows 66,000 people who watched, listened, and cheered President Trump outside a rally. / 0 ✓
# Train: 58000  57% (11m 45s) average_accuracy=0.5720 average_loss=0.8977 "Charlie Crist was the only prominent Republican in the country to campaign with Barack Obama before the stimulus passed, on behalf of the stimulus." / 1 ✓
# Test: 58000  57% (11m 45s) average_accuracy=0.5670 average_loss=0.9179 Wisconsin’s criminal threshold for drunken-driving is "way out of line" with "states surrounding us," which "have the second offense as a felony." / 1 ✓
# Train: 59000  59% (11m 57s) average_accuracy=0.6000 average_loss=0.8868 Top Obama administration officials watched the Benghazi attack unfold in real-time but did nothing to intervene. / 0 ✓
# Test: 59000  59% (11m 57s) average_accuracy=0.5420 average_loss=0.9639 A photograph shows President Obama holding a Che Guevara t-shirt. / 0 ✓
# Train: 60000  60% (12m 9s) average_accuracy=0.6190 average_loss=0.8609 “First of all, 72 individuals, according to the Center for Immigration Studies, have been implicated in terroristic activity in the United States who hail from those seven nations, point one.” / 1 ✓
# Test: 60000  60% (12m 9s) average_accuracy=0.5910 average_loss=0.9134 Says Winston Churchill said, "When you’re 20, you care what everyone thinks, when you’re 40 you stop caring what everyone thinks, when you’re 60, you realize no one was ever thinking about you in the first place." / 0 ✓
# Train: 61000  61% (12m 22s) average_accuracy=0.6120 average_loss=0.8667 The UK issued a travel advisory for LGBT citizens visiting the United States after Mississippi and North Carolina passed controversial laws.
#
#
#
#
# 						See Example(s)
#
#
#
#
# 									United Kingdom issues travel advisory for LGBT citizens visiting NC?
#
# How bad is North Carolina's law? Foreign state departments are issuing travel advisories about it https://t.co/fJjSMZw15h — Matthew Martin (@hyperplanes) April 20, 2016
#
# 																			Collected via Twitter and e-mail, April 2016 / 0 ✗ (2)
# Test: 61000  61% (12m 22s) average_accuracy=0.5630 average_loss=0.9378 "A hedge fund in New York takes control of a great Wisconsin business, shuts down a factory and 450 people lose their jobs." / 1 ✓
# Train: 62000  62% (12m 34s) average_accuracy=0.5890 average_loss=0.8882 "Americans haven’t had a raise in 15 years." / 0 ✗ (1)
# Test: 62000  62% (12m 34s) average_accuracy=0.5550 average_loss=0.9265 Says Thomas Jefferson drafted the Declaration of Independence on hemp paper, grew and smoked marijuana, and said "hemp is of first necessity to the wealth and protection of the country." / 1 ✓
# Train: 63000  63% (12m 46s) average_accuracy=0.5680 average_loss=0.9223  "That Judge Kavanaugh is more of a centrist than some of his critics maintain is reflected in the fact that he and Chief Judge Merrick Garland voted the same way in 93 percent of the cases that they heard together."  / 1 ✗ (0)
# Test: 63000  63% (12m 46s) average_accuracy=0.5780 average_loss=0.9108 Says "Michael Bennet votes for President Obama's agenda 98 percent of the time. Hardly independent, hardly bipartisan." / 0 ✗ (1)
# Train: 64000  64% (12m 58s) average_accuracy=0.6070 average_loss=0.8521 The state budget fully funds "an initiative to provide free college tuition for illegal immigrants, while rejecting an increase in Tuition Assistance Program funding that would help middle-class families afford college." / 1 ✓
# Test: 64000  64% (12m 58s) average_accuracy=0.5730 average_loss=0.9211 Says "excise taxes are...disproportionately burdening middle- and lower-income consumers." / 1 ✓
# Train: 65000  65% (13m 11s) average_accuracy=0.5990 average_loss=0.8643 “Since its inception 3.881 million tonnes of cargo have been transported on the standard-gauge railway line.” / 1 ✓
# Test: 65000  65% (13m 11s) average_accuracy=0.5600 average_loss=0.9130 "Bill White has a long history of trying to limit or even disenfranchise military voters." / 1 ✓
# Train: 66000  66% (13m 23s) average_accuracy=0.5930 average_loss=0.8902 Unemployment and the housing and auto industry crises can be fixed by giving a million dollars to every worker over age 50 to retire. / 1 ✗ (0)
# Test: 66000  66% (13m 23s) average_accuracy=0.6040 average_loss=0.8788 An image shows Jimi Hendrix covered in tattoos while riding a dune buggy. / 0 ✓
# Train: 67000  67% (13m 35s) average_accuracy=0.5880 average_loss=0.8819 Paul Ryan nominated televangelist Joel Osteen as the new House Chaplain. / 0 ✓
# Test: 67000  67% (13m 35s) average_accuracy=0.5980 average_loss=0.9154 Kavanaugh accuser Deborah Ramirez has "ties" to billionaire philanthropist George Soros. / 0 ✓
# Train: 68000  68% (13m 47s) average_accuracy=0.5830 average_loss=0.8953 Says "A baby in Coos County is two times as likely to be born to a mother who is someone who used tobacco during her pregnancy as is the average baby born in Oregon or the U.S." / 1 ✗ (2)
# Test: 68000  68% (13m 47s) average_accuracy=0.5900 average_loss=0.8897 Jodi Arias was granted an early release from prison after an incident with correctional officers / 0 ✓
# Train: 69000  69% (13m 58s) average_accuracy=0.5980 average_loss=0.8739 A list of 'Which Side of the Fence?' entries distinguishing Republicans from Democrats originated with comedian Jeff Foxworthy. / 0 ✓
# Test: 69000  69% (13m 58s) average_accuracy=0.5630 average_loss=0.9274 Says if you try to hide marijuana in a hemp field, "it becomes worthless. The THC goes away." / 0 ✗ (1)
# Train: 70000  70% (14m 10s) average_accuracy=0.5890 average_loss=0.8837 "If you look at your voter rolls, you will see millions of people that are registered to vote ... that shouldn't be registered to vote." / 0 ✓
# Test: 70000  70% (14m 10s) average_accuracy=0.5830 average_loss=0.8993 A Californian and Ecuadorian couple proved it is possible to live on nothing but air. / 0 ✓
# Train: 71000  71% (14m 23s) average_accuracy=0.5860 average_loss=0.8679 Brad Pitt said that "elite Hollywood pedophiles" control the United States. / 0 ✓
# Test: 71000  71% (14m 23s) average_accuracy=0.5770 average_loss=0.9158 A 60-year-old woman shot and killed two teenagers who were attempting to make her a “knockout game” victim. / 0 ✓
# Train: 72000  72% (14m 35s) average_accuracy=0.5730 average_loss=0.9120 Barack Obama is the only president who has failed to visit the D-Day Monument on D-Day.
#
#
#
#
# 						See Example(s)
#
#
#
#
# 									Since its construction, only 3 times have presidents failed to go to the D-Day Monument that honors the soldiers killed on D-Day. Those 3 Presidents were:
#
# 1. Barack Obama 2010
# 2. Barack Obama 2011
# 3. Barack Obama 2012
#
# For the past 70 years, all presidents, except Obama, have paid tribute to the fallen soldiers killed on D-Day. This year, instead of honoring the soldiers, he made a campaign trip on Air Force 1 to California to raise funds for the upcoming election.
#
#
#   [Collected via e-mail, May 2014]
#
# Every year the French have a 4 day celebration in Normandy complete with American uniforms, tanks, jeeps and guns. They still honor the Americans who died there.
#
# In all the years since, Our country has only FOUR TIMES not been there to do the honors.
#
# Four times in 69 years!! I wonder who would have had the lack of respect to not honor our fighting forces?
#
# SHAME ON AMERICA FOR ELECTING A NON-VETERAN PRESIDENT WHO DOES NOT DESERVE TO BE THE COMMANDER-IN-CHIEF: HE IS ABSOLUTELY A DISGRACE TO ALL WHO FOUGHT FOR THIS NATION AND GAVE THEIR LIVES.
#
# June 6, 2013, the 69th anniversary of "D-Day", the largest invasion ever attempted, where 200,000 Americans stormed the beaches at Normandy to begin the final push to defeat Nazi Germany in WWII. D-Day marked the turning point in WWII in Europe . Today, European heads of state make it a point to recall and honor the sacrifices of those who landed in Normandy, as do our Presidents....well, most of them....
#
# In the 69 years since D-Day, there are four occasions when the President of the United States chose not to visit the D-Day Monument that honors the soldiers killed during the Invasion.
#
# The occasions were:
#
# 1. Barack Obama, 2010
# 2. Barack Obama, 2011
# 3. Barack Obama, 2012
# 4. Barack Obama, 2013
#
# For the past 69 years, every American President except Obama have taken the time to honor the memory and sacrifices of the 6,000 American soldiers killed on D-Day. ...Except Obama!
#
# June 6 2010,
# Obama had no events scheduled.
#
# June 6, 2011,
# Obama met with the National Security team and was interviewed by WEWS Cleveland and WDIV in Detroit about the auto industry - FAR too busy to visit the D-Day memorial.
#
# June 6, 2012,
# instead of honoring our fallen soldiers, Obama made a campaign trip to California on Air Force 1 (at our expense) to raise funds for (his) upcoming election.
#
# June 6, 2013,
# Obama was doing ANOTHER fund raiser with the multimillionaires in the Democratic Senatorial Campaign Committee in Palo Alto CA, once again at our expense.
#
# America - Aren't you proud?
#
# 																			Collected via e-mail, July 2012 / 0 ✓
# Test: 72000  72% (14m 35s) average_accuracy=0.5710 average_loss=0.9193 Denver Broncos general manager John Elway fired three players for kneeling during the national anthem. / 0 ✓
# Train: 73000  73% (14m 47s) average_accuracy=0.5840 average_loss=0.8829 Says Bernie Sanders marched with Fidel Castro and Che Guevara in Cuba. / 0 ✓
# Test: 73000  73% (14m 47s) average_accuracy=0.5990 average_loss=0.8789 "I have never supported cap and trade." / 1 ✓
# Train: 74000  74% (14m 59s) average_accuracy=0.5950 average_loss=0.8878 The United States has "one of the highest corporate tax rates in the world." / 1 ✗ (2)
# Test: 74000  74% (14m 59s) average_accuracy=0.5790 average_loss=0.8951 "Our state has no major rivers to produce big hydropower." / 1 ✓
# Train: 75000  75% (15m 10s) average_accuracy=0.6170 average_loss=0.8439 A nine-foot-long bull shark was found in Kentucky Lake. / 0 ✓
# Test: 75000  75% (15m 10s) average_accuracy=0.5750 average_loss=0.9326 A video clip shows a subsequently suppressed Fox News broadcast about Barack Obama.
#
#
#
#
# 						See Example(s)
#
#
#
#
# 									VERY INTERESTING
#
# Remember when we were told to watch Fox News on a Sunday night that was going to air something about Obama and we watched but never saw anything! Well, read below and click on the video to see why it got pulled before it could air
#
# Now we know why Fox News never broadcast it as they had originally planned to. This piece was pulled.
#
# *I encourage you to please send this to everyone on your email list ASAP.*
#
# *Remember all the notices we kept getting to watch Fox News on Sunday at 9PM? What Happened?*
#
# *This is the clip that got pulled due to pressure from the Administration.*
#
# Obama Puts Heat on Fox News to Prevent Sean Hannity from airing this piece.
#
# *This is a video that Sean Hannity of FOX News has been trying to show that we are told has consistently been blocked by the Obama Administration for several weeks. It was a matter of time until the internet picked it up.*
#
# *Watch it now before it gets pulled from the internet!*
#
# 																			Collected via e-mail, September 2012 / 0 ✓
# Train: 76000  76% (15m 23s) average_accuracy=0.5740 average_loss=0.9200 The man accused of opening fire on hundreds of people in a Las Vegas casino in October 2017 was spotted at an anti-Trump protest two months earlier. / 0 ✓
# Test: 76000  76% (15m 23s) average_accuracy=0.5610 average_loss=0.9301 Did Sam Clovis (a President Trump pick for a U.S. Department of Agriculture science position) called scientists "dumb" and claimed that dinosaurs never existed. / 0 ✓
# Train: 77000  77% (15m 35s) average_accuracy=0.5640 average_loss=0.9156 A study performed at the Los Alamos National Laboratory found that millimeter wave body scanners commonly used by airport security can alter your DNA. / 0 ✓
# Test: 77000  77% (15m 35s) average_accuracy=0.5610 average_loss=0.9322 Says New Jersey is "losing 50 football fields of open space to development every day and the more we develop upstream the more flooding we have downstream." / 1 ✓
# Train: 78000  78% (15m 48s) average_accuracy=0.5780 average_loss=0.8981 The partial government shutdown in early 2019 affected "18,000 federal employees in West Virginia." / 1 ✓
# Test: 78000  78% (15m 48s) average_accuracy=0.5700 average_loss=0.9271 Says "160,000 kids stay home every day because they are afraid to go to school because of bullying." / 1 ✓
# Train: 79000  79% (16m 0s) average_accuracy=0.6090 average_loss=0.8598 A clause in the document annexing Texas to the United States allowed for Texas to be divided into five different states. / 1 ✓
# Test: 79000  79% (16m 0s) average_accuracy=0.5490 average_loss=0.9329 "Black business ownership jumped 400% in one year." / 1 ✗ (0)
# Train: 80000  80% (16m 13s) average_accuracy=0.5870 average_loss=0.9081 Says British voters "under 50, especially millennials, overwhelmingly voted to stay," in the European Union. "It was older voters who voted to leave." / 1 ✓
# Test: 80000  80% (16m 13s) average_accuracy=0.5500 average_loss=0.9301 Under the "cromnibus" law, taxpayers must guarantee "incredibly risky" derivatives deals made by the nation's largest banks. / 1 ✓
# Train: 81000  81% (16m 25s) average_accuracy=0.6080 average_loss=0.8777 Former EPA Administrator Gina McCarthy said the Obama administration's Clean Power Plan would have little or no effect on carbon dioxide emissions. / 0 ✗ (1)
# Test: 81000  81% (16m 25s) average_accuracy=0.5410 average_loss=0.9274  Getting rid of the filibuster "would be the end of the Senate as it was originally devised and created going back to our Founding Fathers.”  / 0 ✓
# Train: 82000  82% (16m 36s) average_accuracy=0.5960 average_loss=0.8633 Says "Three Muslim congresswomen just refused" to sign an oath of office to uphold the U.S. Constitution. / 0 ✓
# Test: 82000  82% (16m 36s) average_accuracy=0.5720 average_loss=0.9174 Cavities are contagious, primarily between intimate partners or children and caregivers.
#
#
#
#
# 						See Example(s)
#
#
#
#
# 									I was told today that cavities in teeth are contagious person to person. Meaning my husband can get cavities from me having them. Is this true?!?!
#
#
#
# New research reveals that dental caries, also known as cavities or tooth decay, is actually an infectious disease ... The bacteria most responsible for tooth decay are Steptococcus mutans and Steptococcus sobrinus. These bacteria are passed easily from person to person.
#
# Research is finding that this bacteria is passed easily from adults to children when kissing, sharing utensils or any other activity that transmits saliva. Streptococcus mutans is not passed to each other as adults, so children, especially ages 6 to 36 months of age, are particularly susceptible.																			Collected via e-mail, December 2016 / 0 ✗ (1)
# Train: 83000  83% (16m 48s) average_accuracy=0.6020 average_loss=0.8441 The IAEA, or the International Atomic Energy Agency, "last month said the Iranians are not currently living up to their obligations." / 1 ✓
# Test: 83000  83% (16m 48s) average_accuracy=0.5700 average_loss=0.9158 Kenya has a workforce of 20 million people / 0 ✗ (1)
# Train: 84000  84% (17m 0s) average_accuracy=0.5990 average_loss=0.8636 Fundamental changes made to the language describing the Wisconsin Idea in the University of Wisconsin System's mission statement were the result of a "drafting error." / 1 ✗ (0)
# Test: 84000  84% (17m 0s) average_accuracy=0.5670 average_loss=0.9405 An FBI agent who exposed Hillary Clinton's corruption has been found dead. / 0 ✓
# Train: 85000  85% (17m 11s) average_accuracy=0.5860 average_loss=0.8944 Says Hillary Clinton "believes that all abortions should be legal, even on the due date of that unborn child." / 0 ✓
# Test: 85000  85% (17m 11s) average_accuracy=0.5480 average_loss=0.9284 "The U.S. recorded its slowest economic growth in five years (2016). GDP up only 1.6%. Trade deficits hurt the economy very badly." / 1 ✓
# Train: 86000  86% (17m 23s) average_accuracy=0.5710 average_loss=0.9144 Under Phil Bredesen, in sexual harassment cases, his administration chose "to shred some of the documents so that women’s voices would never be heard." / 0 ✗ (1)
# Test: 86000  86% (17m 23s) average_accuracy=0.5730 average_loss=0.8917 Says Charlie Crist's campaign bashed Sen. Bill Nelson's "big-government solutions." / 0 ✓
# Train: 87000  87% (17m 35s) average_accuracy=0.5970 average_loss=0.8776 "Obamacare has caused millions of full-time jobs to become part-time." / 1 ✓
# Test: 87000  87% (17m 35s) average_accuracy=0.5640 average_loss=0.9136 “We lost, over the last number of years, $800 billion a year. Not a half a million dollars, not 12 cents. We lost $800 billion a year on trade." / 1 ✗ (0)
# Train: 88000  88% (17m 47s) average_accuracy=0.5900 average_loss=0.8681 Did Democrats pass a law separating children and adults at the border? / 0 ✓
# Test: 88000  88% (17m 47s) average_accuracy=0.5690 average_loss=0.9215 Illinois has made it a felony for its citizens to record the activities of police. / 0 ✗ (1)
# Train: 89000  89% (17m 59s) average_accuracy=0.6090 average_loss=0.8679  Rep. Trey Gowdy “has been given the highest level of security clearance possible, granted with an executive order from the President himself.”  / 0 ✓
# Test: 89000  89% (17m 59s) average_accuracy=0.5550 average_loss=0.9423 "The port provides more than 297,000 jobs directly to the state of Georgia." / 1 ✓
# Train: 90000  90% (18m 10s) average_accuracy=0.6110 average_loss=0.8552 “We’ve saved taxpayers hundreds of millions of dollars by bringing down the price of the fantastic new F-35 jet fighter, and will be saving billions more dollars on contracts all across our government.” / 0 ✓
# Test: 90000  90% (18m 10s) average_accuracy=0.5910 average_loss=0.8981 "When I talk about (raising the) minimum wage ... half of Republicans agree with it." / 1 ✓
# Train: 91000  91% (18m 22s) average_accuracy=0.6130 average_loss=0.8611 Country star Willie Nelson has died. / 0 ✓
# Test: 91000  91% (18m 22s) average_accuracy=0.5790 average_loss=0.9137 Monica Lewinsky has announced she's voting for Hillary Clinton. / 0 ✓
# Train: 92000  92% (18m 34s) average_accuracy=0.5940 average_loss=0.8821 Police shootings kill more white Americans than black Americans. / 0 ✗ (1)
# Test: 92000  92% (18m 34s) average_accuracy=0.5710 average_loss=0.9413 Killed Ferguson, Missouri, teen Michael Brown had a lengthy arrest record. / 0 ✓
# Train: 93000  93% (18m 46s) average_accuracy=0.5790 average_loss=0.8971 "Some of the people, supposedly repressed for political reasons, whose release Washington is calling for, have been convicted of grave crimes such as terrorism and murder. Their guilt has been completely and exhaustively proven." / 0 ✓
# Test: 93000  93% (18m 46s) average_accuracy=0.5930 average_loss=0.9167 President Obama has sold the tabulating of votes in U.S. national elections to Scytl, a Spanish company run by a donor to his campaign. / 0 ✓
# Train: 94000  94% (18m 58s) average_accuracy=0.5860 average_loss=0.8768 A member of India's Congress party said the country will be ruled by Muslims / 0 ✓
# Test: 94000  94% (18m 58s) average_accuracy=0.5300 average_loss=0.9322 “I note that we’ve never, even in the days of tsarist Russia, killed people for dissent. This, by the way, is the great strength of our people.” / 0 ✓
# Train: 95000  95% (19m 10s) average_accuracy=0.5950 average_loss=0.8834 Says under her leadership, "Democrats fought to ... make sure the (2011 HOPE) bill ... prevented the use of ACT/SAT testing standards." / 1 ✓
# Test: 95000  95% (19m 10s) average_accuracy=0.5600 average_loss=0.9183 Maps shows that areas with high democratic populations also have high crime rates. / 1 ✗ (0)
# Train: 96000  96% (19m 21s) average_accuracy=0.5740 average_loss=0.8955 “The ratio of police officer to Kenyan citizen has improved from 1:500 to 1:400 a higher threshold than the UN benchmark of one officer for every 450 citizens.” / 0 ✓
# Test: 96000  96% (19m 21s) average_accuracy=0.5730 average_loss=0.9153 The No. 2 owner of Fox News is Prince Alwaleed bin Talal, who said, "A strong American Government is not good for us." / 0 ✗ (1)
# Train: 97000  97% (19m 33s) average_accuracy=0.5850 average_loss=0.9033 Says revenues "are actually up after tax reform." / 1 ✓
# Test: 97000  97% (19m 33s) average_accuracy=0.5790 average_loss=0.8921 A 12-year-old Wisconsin girl in died as a result of receiving the Gardasil HPV vaccine. / 0 ✓
# Train: 98000  98% (19m 45s) average_accuracy=0.6130 average_loss=0.8592 "Bioweapon! Zika virus is being spread by GMO mosquitos (sic)" / 0 ✓
# Test: 98000  98% (19m 45s) average_accuracy=0.5630 average_loss=0.9250 In Georgia, Perdue’s company closed plants and moved jobs to China. / 1 ✗ (2)
# Train: 99000  99% (19m 56s) average_accuracy=0.6270 average_loss=0.8502 Did 19 ICE Agents Call For ICE To Be ‘Dissolved’? / 0 ✗ (1)
# Test: 99000  99% (19m 56s) average_accuracy=0.5600 average_loss=0.9394 "The president is brain-dead." / 1 ✗ (0)
# Train: 100000  100% (20m 8s) average_accuracy=0.5960 average_loss=0.8884 "The average rate of fraud" in the Earned Income Tax Credit, Medicare, Medicaid and food stamps programs "is 20 to 25 percent." / 1 ✗ (0)
# Test: 100000  100% (20m 8s) average_accuracy=0.5510 average_loss=0.9437 "According to the Congressional Budget Office, repealing Obamacare would increase the budget deficit." / 1 ✓

# %%
#Saving data
import json
with open('A5Q2A_all_train_accuracies.json', 'w') as f:
    json.dump(all_train_accuracies, f)
    
with open('A5Q2A_all_test_accuracies.json', 'w') as f:
    json.dump(all_test_accuracies, f)

# %%
#Loading Data
import json
with open('A5Q2A_all_train_accuracies.json', 'r') as f:
   all_train_accuracies = json.load(f)
    
with open('A5Q2A_all_test_accuracies.json', 'r') as f:
   all_test_accuracies = json.load(f)

# %%
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker

plt.figure(figsize = (12,4))
plt.subplot(1,2,1)
plt.plot(all_train_accuracies, label = 'Train Accuracy (claim only)')
plt.legend()

plt.subplot(1,2,2)
plt.plot(all_test_accuracies, label = 'Test Accuracy (claim only)')
plt.legend()

# %% [markdown]
# # Preprocess articles
#
# This code preprocesses the aticles to extract the top 5 sentences with greatest similarity to the claim according to tf-idf.

# %%
def preprocess_articles():

    from nltk.tokenize import sent_tokenize
    import nltk
    nltk.download('punkt')
    from sklearn.feature_extraction.text import TfidfVectorizer
    
    # load metadata
    with open("train.json", 'r') as f:
        metadata = json.load(f)
    n_claims = len(metadata)

    # load related articles for each claim
    relevant_sentences = []
    for id in range(n_claims):
  
        if id % 500 == 0:
            print("Claims preprocessed: ",id)
        
        # retrieve related articles
        related_articles = metadata[id]['related_articles']
        articles = ""
        for article_id in related_articles:
            filename = "train_articles/" + str(article_id) + ".txt"
            # concatenate related articles
            with open(filename, 'r') as text_file:
                text = text_file.read()
                articles = articles + "\n" + text

        # split articles into sentences
        sentences = sent_tokenize(articles)

        # append claim to articles
        sentences.append(metadata[id]['claim'])

        # vectorize sentences based on tf-idf
        vectorizer = TfidfVectorizer()
        X = vectorizer.fit_transform(sentences)
    
        # measure similarity between claim and each sentence
        similarity =  X[-1,:] @ np.transpose(X[:-2,:])
        similarity = similarity.todense()

        # find top 5 sentences with greatest similarity
        sorted_index = np.argsort(similarity)
        top_sentences = []
        for i in range(1,min(5,sorted_index.shape[1])+1):
            top_sentences.append(sentences[sorted_index[0,-i]])
        relevant_sentences.append(top_sentences)

   
    return metadata, relevant_sentences

metadata, relevant_sentences = preprocess_articles()
print("Metadata of claim 0:")
print(metadata[0]['claim'])
print("Relevant sentences of claim 0:")
print(relevant_sentences[0])
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# Claims preprocessed:  0
# Claims preprocessed:  500
# Claims preprocessed:  1000
# Claims preprocessed:  1500
# Claims preprocessed:  2000
# Claims preprocessed:  2500
# Claims preprocessed:  3000
# Claims preprocessed:  3500
# Claims preprocessed:  4000
# Claims preprocessed:  4500
# Claims preprocessed:  5000
# Claims preprocessed:  5500
# Claims preprocessed:  6000
# Claims preprocessed:  6500
# Claims preprocessed:  7000
# Claims preprocessed:  7500
# Claims preprocessed:  8000
# Claims preprocessed:  8500
# Claims preprocessed:  9000
# Claims preprocessed:  9500
# Claims preprocessed:  10000
# Claims preprocessed:  10500
# Claims preprocessed:  11000
# Claims preprocessed:  11500
# Claims preprocessed:  12000
# Claims preprocessed:  12500
# Claims preprocessed:  13000
# Claims preprocessed:  13500
# Claims preprocessed:  14000
# Claims preprocessed:  14500
# Claims preprocessed:  15000
# Claims preprocessed:  15500
# Metadata of claim 0:
# A line from George Orwell's novel 1984 predicts the power of smartphones.
# Relevant sentences of claim 0:
# ['1984 by George Orwell\n1984 is a dystopian novel by English author George Orwell published in 1949.', 'Theater Review: \'1984\'\nEarly this year, sales of George Orwell\'s novel "1984" spiked after the words "alternative facts" entered the lexicon.', 'It is truly frightening to see the parallels between George Orwell\'s dystopian novel "1984" and the state of our union today.', '\n1984: George Orwell predicted 2017 almost 70 years ago\nApril, 1984.', 'The line is from one of the characters that works for the Government, otherwise known as Big Brother.']

# %% [markdown]
# # Q2a) ii
# # Claim & Claimant as Input to Neural Network

# %%
def train_ii(category_tensor, line_tensor, update=True):
    rnnOptimizer.zero_grad()
    classifierOptimizer.zero_grad()

    hidden = rnn_ii.initHidden()
    for i in range(line_tensor.size()[0]):
        hidden = rnn_ii(line_tensor[i], hidden)
    output = classifier_ii(hidden)

    loss = criterion(output, category_tensor)
    if update:
        loss.backward()
        rnnOptimizer.step()
        classifierOptimizer.step()
        
    return output, loss.item()

# %%
import time
import math

n_hidden = 128
n_categories = 3
rnn_ii = RNN(n_embedding_dims, n_hidden) #multiplied by 2 for claim+claimant
classifier_ii = Classifier(n_hidden, n_categories)

criterion = nn.NLLLoss()
learning_rate = 1e-4
rnnOptimizer = torch.optim.Adam(rnn_ii.parameters(), lr=learning_rate)
classifierOptimizer = torch.optim.Adam(classifier_ii.parameters(), lr=learning_rate)

n_iters = 100000
plot_every = 1000

# Keep track of losses for plotting
current_loss = 0
all_losses = []

def timeSince(since):
    now = time.time()
    s = now - since
    m = math.floor(s / 60)
    s -= m * 60
    return '%dm %ds' % (m, s)

start = time.time()

train_data = metadata[:10000]
test_data = metadata[10000:]
train_cumulative_loss = 0
test_cumulative_loss = 0
average_train_accuracy = 0
average_test_accuracy = 0
all_train_losses = []
all_train_accuracies_ii = []
all_test_losses = []
all_test_accuracies_ii = []
count = 0
for iter in range(1, n_iters + 1):
    train_claim_tensor, train_category_tensor, train_claim, train_category, train_id = sampleClaim(train_data)
    train_claimant_tensor, train_claimant = sampleClaimant(train_id)
    
    train_line_tensor = torch.cat((train_claim_tensor, train_claimant_tensor), 0)
    
     
    train_output, train_loss = train_ii(train_category_tensor, train_line_tensor)    
    top_train_value, top_train_index = train_output.topk(1)
    train_guess_category = top_train_index[0].item()
    train_cumulative_loss += train_loss
    train_accuracy = 1 if train_guess_category == train_category else 0
    average_train_accuracy = (average_train_accuracy * count + train_accuracy) / (count+1)
    
    test_claim_tensor, test_category_tensor, test_claim, test_category, test_id = sampleClaim(test_data)
    test_claimant_tensor, test_claimant = sampleClaimant(test_id)
    test_line_tensor = torch.cat((test_claim_tensor, test_claimant_tensor), 0)
    
    test_output, test_loss = train_ii(test_category_tensor, test_line_tensor, update=False)
    top_test_value, top_test_index = test_output.topk(1)
    test_guess_category = top_test_index[0].item()
    test_cumulative_loss += test_loss
    test_accuracy = 1 if test_guess_category == test_category else 0
    average_test_accuracy = (average_test_accuracy * count + test_accuracy) / (count+1)
    count += 1

    # Add current loss avg to list of losses
    if iter % plot_every == 0:
        train_correct = '✓' if train_guess_category == train_category else '✗ (%s)' % train_category
        print('Train: %d  %d%% (%s) average_accuracy=%.4f average_loss=%.4f %s / %s %s' % (iter, iter / n_iters * 100, timeSince(start), average_train_accuracy, train_cumulative_loss / plot_every, train_claim, train_guess_category, train_correct))
        test_correct = '✓' if test_guess_category == test_category else '✗ (%s)' % test_category
        print('Test: %d  %d%% (%s) average_accuracy=%.4f average_loss=%.4f %s / %s %s' % (iter, iter / n_iters * 100, timeSince(start), average_test_accuracy, test_cumulative_loss / plot_every, test_claim, test_guess_category, test_correct))
        all_train_losses.append(train_cumulative_loss / plot_every)
        all_train_accuracies_ii.append(average_train_accuracy)
        all_test_losses.append(test_cumulative_loss / plot_every)
        all_test_accuracies_ii.append(average_test_accuracy)
        train_cumulative_loss = 0
        average_train_accuracy = 0
        test_cumulative_loss = 0
        average_test_accuracy = 0
        count = 0
        
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker

plt.figure()
plt.plot(all_train_accuracies_ii)
# Out:
# Train: 1000  1% (0m 8s) average_accuracy=0.5080 average_loss=0.9717 Sylvester Stallone has passed away from prostate cancer. / 0 ✓
# Test: 1000  1% (0m 8s) average_accuracy=0.4260 average_loss=0.9954 "Half of all CEOs say that the shutdown and the threat of shutdown set back their plans to hire over the next six months." / 0 ✗ (1)
# Train: 2000  2% (0m 17s) average_accuracy=0.5810 average_loss=0.9314 A half dozen Trump-related entities were under criminal investigation in December 2018. / 0 ✗ (1)
# Test: 2000  2% (0m 17s) average_accuracy=0.4490 average_loss=1.0101 Images of a suspect arrested over the killing of a Philippine teenager / 0 ✓
# Train: 3000  3% (0m 25s) average_accuracy=0.6060 average_loss=0.8901 A man was released from jail in Texas after outliving his 99-year prison sentence for horse theft. / 0 ✓
# Test: 3000  3% (0m 25s) average_accuracy=0.4580 average_loss=1.0303 "I got a very, very small loan from my father many years ago. I built that into a massive empire." / 0 ✓
# Train: 4000  4% (0m 34s) average_accuracy=0.5970 average_loss=0.9079 The Chili's restaurant chain donates 15 percent of every sale to Planned Parenthood.
#
#
#
#
# 						See Example(s)
#
#
#
#
# 									PEOPLE are posting that Chili's restaurants are donating 15% of your tab to PLANNED PARENTHOOD if you bring in a printed voucher.
#
# 																			Collected via e-mail, January 2017 / 0 ✗ (1)
# Test: 4000  4% (0m 34s) average_accuracy=0.4520 average_loss=1.0120 Bernie Sanders purchased a $172,000 luxury car with presidential campaign donations. / 0 ✓
# Train: 5000  5% (0m 42s) average_accuracy=0.6080 average_loss=0.8827 "No city in the state, no state in this nation, for that matter the entire world, has adopted (clean energy) targets more ambitious in scale." / 1 ✓
# Test: 5000  5% (0m 42s) average_accuracy=0.4670 average_loss=0.9989 "We Really Do Have the Highest Corporate Tax Rate in the World." / 0 ✗ (1)
# Train: 6000  6% (0m 52s) average_accuracy=0.6000 average_loss=0.8941 About 40 percent of U.S. illegal immigrants "came in on an airplane, with a legal visa, and just overstayed their visa and have never gone home." / 1 ✓
# Test: 6000  6% (0m 52s) average_accuracy=0.4570 average_loss=0.9956 New Virginia regulations on abortion clinics "provide the same sanitary environment we expect of dental offices." / 0 ✓
# Train: 7000  7% (1m 0s) average_accuracy=0.6650 average_loss=0.8091 "The Simpsons" predicted that there would be a mass shooting at a screening of the movie "Black Panther." / 0 ✓
# Test: 7000  7% (1m 0s) average_accuracy=0.4720 average_loss=1.0205 "As Governor, Wolf has already proposed more than $8B in tax increases." / 0 ✗ (1)
# Train: 8000  8% (1m 8s) average_accuracy=0.6250 average_loss=0.8634 Says "we know" Erika Harold would "discriminate against a loving gay couple who want to adopt a child, favoring an abusive straight couple instead." / 1 ✗ (0)
# Test: 8000  8% (1m 8s) average_accuracy=0.4980 average_loss=1.0188 Says Wisconsin "doesn't even give" released prison inmates "a bus ticket to get home." / 1 ✓
# Train: 9000  9% (1m 17s) average_accuracy=0.6190 average_loss=0.8829 A "catch and release" immigration policy "is a Democrat rule, Sherrod Brown, this is a Democrat rule." / 0 ✓
# Test: 9000  9% (1m 17s) average_accuracy=0.4620 average_loss=1.0171 "Since taking office, Andrew Cuomo has given massive tax breaks to corporations and the super rich." / 1 ✓
# Train: 10000  10% (1m 26s) average_accuracy=0.5930 average_loss=0.8825 Kanye West has been banned from all future award shows. / 0 ✓
# Test: 10000  10% (1m 26s) average_accuracy=0.4780 average_loss=1.0389 An Olympic pool was installed at a prison for Stanford swimmer Brock Turner.
#
#
#
#
# 						See Example(s)
#
#
#
#
# 									Is the Santa Clara jail system truly adding a swimming pool for the man going to jail for raping an unconscious woman?																			Collected via e-mail, June 2016 / 0 ✓
# Train: 11000  11% (1m 34s) average_accuracy=0.6060 average_loss=0.8869 Says Rebecca Dallet "has talked about her interest in advocating for policies that need to be changed to achieve her political objectives." / 1 ✓
# Test: 11000  11% (1m 34s) average_accuracy=0.4530 average_loss=1.0343 Did Someone Light Their Feet on Fire to Protest Nike? / 0 ✓
# Train: 12000  12% (1m 43s) average_accuracy=0.6170 average_loss=0.8760  “Trump Warns Flu Shots Are The Greatest ‘Scam’ In Medical History.”  / 0 ✓
# Test: 12000  12% (1m 43s) average_accuracy=0.4630 average_loss=1.0178 The Inland Empire is "the second fastest growing region" for jobs in California. / 1 ✗ (2)
# Train: 13000  13% (1m 51s) average_accuracy=0.6040 average_loss=0.8754 Four major hurricanes have hit the United States on 29 August, across 12 years, forming a meaningful pattern. / 0 ✓
# Test: 13000  13% (1m 51s) average_accuracy=0.4890 average_loss=1.0050 Says the average government worker won't be impacted in the first two years under the reform of state health benefits. / 0 ✗ (1)
# Train: 14000  14% (1m 59s) average_accuracy=0.5970 average_loss=0.8933 Florida Democrats "put my Social Security number and my wife's Employment Identification Number in a mail piece." / 1 ✗ (2)
# Test: 14000  14% (1m 59s) average_accuracy=0.5010 average_loss=0.9829 "Fulton County numbers show massive duplicate ballots, rejected ballots, non-citizens trying to vote." / 1 ✓
# Train: 15000  15% (2m 8s) average_accuracy=0.6330 average_loss=0.8578 Gary Johnson once said 'global warming is in our future' because 'the sun is going to actually grow and encompass the Earth.' / 0 ✗ (1)
# Test: 15000  15% (2m 8s) average_accuracy=0.4790 average_loss=1.0619 Sen. Bernie Sanders once supported a proposal to "dump nuclear waste" in the "poor Latino community" of Sierra Blanca, Texas. / 0 ✗ (1)
# Train: 16000  16% (2m 17s) average_accuracy=0.6220 average_loss=0.8595 "It was Dan Sullivan who wrote a bill to cut Alaskans out of those decisions" about where they can hunt and fish. / 1 ✓
# Test: 16000  16% (2m 17s) average_accuracy=0.4950 average_loss=1.0025 The Guggenheim Museum planned to host a Chinese art exhibition that included three installations condemned as cruel to animals. / 0 ✗ (2)
# Train: 17000  17% (2m 25s) average_accuracy=0.6160 average_loss=0.8725 President Obama refused to participate in the ALS Association’s “Ice Bucket Challenge.” / 0 ✗ (1)
# Test: 17000  17% (2m 25s) average_accuracy=0.4840 average_loss=1.0203 A report issued by the FBI concluded that none of the sexual assault allegations against Supreme Court nominee Brett Kavanaugh was true. / 1 ✓
# Train: 18000  18% (2m 34s) average_accuracy=0.6280 average_loss=0.8615 A viral cartoon accurately reproduced statements made by Donald Trump on the presidential campaign trail. / 0 ✗ (2)
# Test: 18000  18% (2m 34s) average_accuracy=0.5140 average_loss=0.9897 A recent study of a proposed cap-and-trade policy’s effect on Wisconsin consumers showed it could "raise gasoline prices by 141 percent and electricity rates by 171 percent" by 2030. / 1 ✓
# Train: 19000  19% (2m 43s) average_accuracy=0.6250 average_loss=0.8747 President Obama altered the White House logo to replace the U.S flag with a white flag (commonly associated with surrender).
#
#
#
#
# 						See Example(s)
#
#
#
#
# 									For many years, the White House logo had the American flag flying on the top of the White House — as it does in real life. In Obama’s redesigned version, there is no American flag, just a white flag.
#
#
#
# 																			Collected via e-mail and Facebook, June 2016 / 0 ✓
# Test: 19000  19% (2m 43s) average_accuracy=0.4660 average_loss=1.0268 John McCain "began his career in Washington as a lobbyist when he was appointed in 1976 as the Navy's liaison to the United States Senate." / 0 ✗ (1)
# Train: 20000  20% (2m 52s) average_accuracy=0.6020 average_loss=0.8812 "This Congress made history as the least productive, most unpopular Congress in the history of this proud nation." / 1 ✓
# Test: 20000  20% (2m 52s) average_accuracy=0.4600 average_loss=1.0324  Getting rid of the filibuster "would be the end of the Senate as it was originally devised and created going back to our Founding Fathers.”  / 0 ✓
# Train: 21000  21% (3m 0s) average_accuracy=0.6040 average_loss=0.8648 On average, college students "are taking six years to get a four-year degree." / 1 ✓
# Test: 21000  21% (3m 0s) average_accuracy=0.4820 average_loss=1.0249 The United States is at "historic record highs" of individuals being apprehended on the border from countries with terrorist ties such as "Pakistan or Afghanistan or Syria." / 0 ✓
# Train: 22000  22% (3m 9s) average_accuracy=0.6230 average_loss=0.8565 Article contrasts observances of the passings of Ed McMahon, Farrah Fawcett, and Michael Jackson. / 0 ✗ (1)
# Test: 22000  22% (3m 9s) average_accuracy=0.5140 average_loss=0.9749 "They found 60 votes in the Senate in 2006 and 2013" for immigration legislation, and "each time the House Republican majority refused to take it up." / 1 ✗ (2)
# Train: 23000  23% (3m 18s) average_accuracy=0.6090 average_loss=0.8658 "Frankly, (Hillary Clinton) doesn’t do very well with women." / 0 ✓
# Test: 23000  23% (3m 18s) average_accuracy=0.4940 average_loss=0.9888 Photograph captures Senator Tom Daschle saluting the flag with the wrong hand. / 0 ✓
# Train: 24000  24% (3m 27s) average_accuracy=0.6140 average_loss=0.8423 Says a Josh Hawley lawsuit "would take away important prescription drug coverage for seniors through Medicare and end all of the consumer protections under the ACA." / 1 ✗ (2)
# Test: 24000  24% (3m 27s) average_accuracy=0.4780 average_loss=1.0249 Says the average government worker won't be impacted in the first two years under the reform of state health benefits. / 1 ✓
# Train: 25000  25% (3m 36s) average_accuracy=0.5910 average_loss=0.9055 A California "pro-choice activist" set a world record by going through her 27th abortion. / 0 ✓
# Test: 25000  25% (3m 36s) average_accuracy=0.4990 average_loss=0.9950 Hillary Clinton filed for divorce from Bill Clinton in November 2016. / 1 ✗ (0)
# Train: 26000  26% (3m 45s) average_accuracy=0.6020 average_loss=0.8656 Scott Fisher "tried to expand Obamacare in Texas and even voted for an official resolution to force 1 million Texans into Obamacare." / 1 ✗ (0)
# Test: 26000  26% (3m 45s) average_accuracy=0.4990 average_loss=1.0055 “The United States and its allies openly and freely discuss transitioning to a policy of containing their relations with Russia. They even threaten terrorist attacks in Russian cities.” / 0 ✓
# Train: 27000  27% (3m 53s) average_accuracy=0.6360 average_loss=0.8415 "The McCarran-Walter Act of 1952 bans Muslims from holding public office in the United States." / 0 ✓
# Test: 27000  27% (3m 53s) average_accuracy=0.4970 average_loss=1.0346 Barron Trump has earned the title of Chess Grandmaster. / 1 ✗ (0)
# Train: 28000  28% (4m 2s) average_accuracy=0.6110 average_loss=0.8540 A video shows Muslim migrants destroying a car in Italy. / 0 ✓
# Test: 28000  28% (4m 2s) average_accuracy=0.5080 average_loss=0.9886 An eclipse is going to cause an earthquake, which will in turn cause a devastating tsunami, on 22 July 2009. / 0 ✓
# Train: 29000  28% (4m 11s) average_accuracy=0.6560 average_loss=0.8175 Media giant Time Warner declined to renew CNN's contract. / 1 ✗ (0)
# Test: 29000  28% (4m 11s) average_accuracy=0.4950 average_loss=1.0054 "Throughout his time in elected office, Barack Obama has taken multiple positions on banning handguns and the D.C. handgun ban." / 1 ✓
# Train: 30000  30% (4m 20s) average_accuracy=0.6150 average_loss=0.8607 "Democrats mistakenly tweet 2014 pictures from Obama’s term showing children from the Border in steel cages." / 0 ✗ (2)
# Test: 30000  30% (4m 20s) average_accuracy=0.4990 average_loss=1.0293 "Now in half the homes in California, people speak a language other than English in their own homes." / 0 ✗ (1)
# Train: 31000  31% (4m 29s) average_accuracy=0.6040 average_loss=0.8649 "That 3.5 percent (increase in the third quarter GDP) came from two things — government spending on Cash for Clunkers — they just moved fourth-quarter auto sales into the third quarter — and the first-time home buyer thing." / 1 ✓
# Test: 31000  31% (4m 29s) average_accuracy=0.4800 average_loss=1.0140 Says West Virginia is "down to around 50 percent of the adult workers who are actually working now because of addiction or conviction." / 0 ✗ (1)
# Train: 32000  32% (4m 37s) average_accuracy=0.6360 average_loss=0.8423 Pat Robertson said that the Notre Dame fire was the result of "hell bubbling over with homosexuals." / 0 ✓
# Test: 32000  32% (4m 37s) average_accuracy=0.5060 average_loss=0.9728  A meme shows George W. Bush asking, “Where is the $50 billion I approved in ’06 for the Secure Fence Act that Obama was supposed to build?”  / 0 ✓
# Train: 33000  33% (4m 47s) average_accuracy=0.5970 average_loss=0.8699 Says U.S. Rep. Patrick Murphy has "sided with the GOP on key votes twice as often as he sided with Democrats." / 1 ✓
# Test: 33000  33% (4m 47s) average_accuracy=0.5110 average_loss=0.9815 After a gunman killed schoolchildren and a teacher in Scotland in 1996, the UK banned handguns; no school shootings have taken place there since. / 2 ✓
# Train: 34000  34% (4m 56s) average_accuracy=0.6270 average_loss=0.8315 As of August 2017, the Secret Service had run out of money for the year due to the demands of protecting President Trump and his family. / 0 ✗ (1)
# Test: 34000  34% (4m 56s) average_accuracy=0.4820 average_loss=1.0131 A billionaire avoided jail despite raping his infant daughter, while another man was sentenced to 50 years in jail for stealing a rack of ribs. / 0 ✗ (1)
# Train: 35000  35% (5m 4s) average_accuracy=0.6270 average_loss=0.8390 A federal judge ordered Brandon High School in Mississippi to remove the hymn "How Great Thou Art" from its marching band's halftime show. / 0 ✗ (1)
# Test: 35000  35% (5m 4s) average_accuracy=0.4740 average_loss=1.0551 “2016 was a landmark for us in terms of HIV. Firstly, because in 2016 the growth rate of new cases decreased by half and mortality was, accordingly, reduced. Overall, we had 86.8 thousand new HIV infections, while a year ago, in 2015, there more than 100 thousand. That is a decrease of 15%." / 1 ✓
# Train: 36000  36% (5m 13s) average_accuracy=0.6150 average_loss=0.8560 He "stood up to Barack Obama by passing legislation that prevents you from being forced to join government health plans or buy health insurance against your will." / 1 ✓
# Test: 36000  36% (5m 13s) average_accuracy=0.5010 average_loss=1.0145  Claims President Obama’s visits to China, Saudi Arabia and Cuba were “the first time in the history, the storied history of Air Force One” when “high officials” of a host country did not greet the president.  / 0 ✓
# Train: 37000  37% (5m 22s) average_accuracy=0.6280 average_loss=0.8422 Says David Perdue wants to abolish the U.S. Department of Education, which would cost Georgia schools $1 billion a year and eliminate millions in student loans. / 1 ✓
# Test: 37000  37% (5m 22s) average_accuracy=0.4850 average_loss=1.0410 In a leaked e-mail, Hillary Clinton said "we must destroy Syria for Israel." / 0 ✓
# Train: 38000  38% (5m 31s) average_accuracy=0.6200 average_loss=0.8507 In January 2019, Second Lady Karen Pence began working as a teacher at a school that bans LGBT teachers and students. / 0 ✗ (1)
# Test: 38000  38% (5m 31s) average_accuracy=0.5060 average_loss=0.9685 A private company building a natural gas pipeline into Florida "is being forced to spend months under the review of six federal agencies." / 1 ✗ (2)
# Train: 39000  39% (5m 40s) average_accuracy=0.5910 average_loss=0.8907 "California State Assembly bill would ban the (sale of the) Bible!" / 0 ✗ (1)
# Test: 39000  39% (5m 40s) average_accuracy=0.5040 average_loss=0.9786 "Sex roulette" is a new sexual trend in which one attendee at an orgy is HIV-positive.
#
#
#
#
# 						See Example(s)
#
#
#
#
# 									Can this be true??!!
#
# Sex roulette parties where one person is secretly HIV+ and nobody is allowed to use condoms are on the rise, warn doctors
#
# (Video) People In Spain Partake In ‘Sex Roulette’ Where Someone Secretly Has HIV https://t.co/oB0LRrT6D7 https://t.co/s0E0hMmso9
# — Funk Flex !!!!! (@funkflex) May 18, 2016
# Hi Snopes, I have seen stories floating around Facebook (as well as a couple of sensationalist British newspapers) claiming that 'sex roulette parties'involving a hiv positive participant are on the rise. Is there any truth to this or is it fake news being mistaken for the truth?																			Collected via e-mail and Twitter, May 2016 / 1 ✗ (0)
# Train: 40000  40% (5m 49s) average_accuracy=0.6050 average_loss=0.8570 All 28 members of NATO have "pledged to spend at least 2 percent of their economy on defense. But only three countries do -- Britain, Greece and us." / 1 ✓
# Test: 40000  40% (5m 49s) average_accuracy=0.4890 average_loss=1.0250 As of October 2017, would-be recipients of a repair grant from Dickinson, Texas, must promise not to boycott Israel. / 0 ✗ (2)
# Train: 41000  41% (5m 58s) average_accuracy=0.6100 average_loss=0.8621 The world's largest tortoise was 59 feet tall and weighed more than 800 pounds. / 1 ✗ (0)
# Test: 41000  41% (5m 58s) average_accuracy=0.4910 average_loss=1.0200 A photograph shows Donald Trump, Muhammad Ali, and Rosa Parks after receiving the Ellis Island Medal of Honor in 1986. / 0 ✗ (2)
# Train: 42000  42% (6m 7s) average_accuracy=0.5920 average_loss=0.8791 "Fifteen out of the 20 most polluted cities in the world" are in India and China. / 0 ✗ (1)
# Test: 42000  42% (6m 7s) average_accuracy=0.5140 average_loss=0.9845 "To this day, (the Cuban government) is a regime that provides safe harbor to terrorists and fugitives." / 1 ✓
# Train: 43000  43% (6m 16s) average_accuracy=0.6130 average_loss=0.8484 Says Congresswoman Loretta Sanchez "has passed one bill in her 20 years in Congress, and that was to rename a post office." / 1 ✓
# Test: 43000  43% (6m 16s) average_accuracy=0.5000 average_loss=0.9852  Trump's "budget reduced the deficit by $3 trillion, which is one of the largest in history."  / 1 ✗ (0)
# Train: 44000  44% (6m 24s) average_accuracy=0.6510 average_loss=0.8159 A fervent Hillary Clinton supporter ran her husband down with an SUV because she found out he voted for Donald Trump.
#
#
#
#
# 						See Example(s)
#
#
#
#
# 									Tania Whitmore, a devoted militant for the Hillary Clinton campaign, allegedly used her Ford Escape SUV to trample her husband, Darrell Johnson, after he told her that he’d voted for Trump.
# http://www.usanewspolitics.com/2016/11/14/woman-runs-over-her-husband-with-an-suv-after-learning-he-voted-for-trump/
#
#  																			Collected via e-mail, November 2016 / 0 ✓
# Test: 44000  44% (6m 24s) average_accuracy=0.4730 average_loss=1.0182 Bill Nye tweeted to ask if a person was "made of copper, nitrogen, terbium, and silver." / 0 ✓
# Train: 45000  45% (6m 33s) average_accuracy=0.6140 average_loss=0.8711 Under Common Core standards, it takes "more than a minute" to teach a student "how to add nine plus six." / 1 ✓
# Test: 45000  45% (6m 33s) average_accuracy=0.4860 average_loss=1.0456 "There aren’t enough ballots in question to change the outcome" of the Harris vs. McCready race in NC Congressional District 9. / 1 ✓
# Train: 46000  46% (6m 43s) average_accuracy=0.6170 average_loss=0.8539 Says Rick Scott’s per-pupil education spending is "about $200 less" than what it was under Charlie Crist during the recession. / 1 ✓
# Test: 46000  46% (6m 43s) average_accuracy=0.5380 average_loss=0.9756 At an Arizona town hall event, Sen. Jeff Flake told constituents "we can't rely on solar power because we can't tell people they will not have lights during the night." / 1 ✓
# Train: 47000  47% (6m 51s) average_accuracy=0.6380 average_loss=0.8347 A neo-Nazi woman gave birth to a black baby after being inseminated by the wrong sperm donor. / 0 ✓
# Test: 47000  47% (6m 51s) average_accuracy=0.4760 average_loss=1.0165 Says Cathy Jordan was "arrested" and dragged out of her home by "a SWAT team of hooligans" for using medical marijuana. / 0 ✗ (1)
# Train: 48000  48% (7m 0s) average_accuracy=0.6260 average_loss=0.8306 Barack Obama "openly supported (opposition leader) Raila Odinga during his visit to Africa in 2006." / 0 ✓
# Test: 48000  48% (7m 0s) average_accuracy=0.4830 average_loss=1.0275 A video shows an alien-like creature known as the 'Chay Na' near a cave in Thailand. / 0 ✓
# Train: 49000  49% (7m 10s) average_accuracy=0.6170 average_loss=0.8728 U.S. Senate candidate Jack Kingston "spent our tax dollars on thousands of wasteful earmarks." / 1 ✓
# Test: 49000  49% (7m 10s) average_accuracy=0.4690 average_loss=1.0437 Says Barack Obama found out about Russia "in August. Now, the election was in November. That's a lot of time. He did nothing about it." / 1 ✓
# Train: 50000  50% (7m 18s) average_accuracy=0.6310 average_loss=0.8218 The Obama administration’s "green" stimulus program "funneled close to $2 billion dollars to overseas firms," creating thousands of jobs in China. / 1 ✓
# Test: 50000  50% (7m 18s) average_accuracy=0.4920 average_loss=1.0181 A photograph shows a small boy who was handcuffed at Dulles Airport due to temporary immigration restrictions implemented in January 2017.
#
#
#
#
# 						See Example(s)
#
#
#
#
# 																												Collected via Facebook, February 2017 / 0 ✓
# Train: 51000  51% (7m 28s) average_accuracy=0.6260 average_loss=0.8481 “One of the things I hope we do as part of this tax process is repeal the tax on poor Americans. Right now, about half of the people that pay the penalty under the individual mandate are people who make $25,000 or less” / 1 ✓
# Test: 51000  51% (7m 28s) average_accuracy=0.4970 average_loss=0.9985 A video shows serial killer and babysitter Nancy James, hired by the Peerc family, placing barbed wire around a baby crib. / 0 ✓
# Train: 52000  52% (7m 37s) average_accuracy=0.6320 average_loss=0.8496 Police discovered human remains in a Satanic dungeon under a Chuck E. Cheese.
#
#
#
#
# 						See Example(s)
#
#
#
#
# 									http://now8news.com/police-find-satanic-ritual-dungeon-in-chicago-chuck-e-cheese-basement/
#
# Seems like bulls***. From the fourth of this month.
#
# Police Find Satanic Ritual Dungeon in Chuck E. Cheese Basement https://t.co/EcUKhp18ap always wondered?
# — kenn (@kennady_) February 11, 2016
# 																			Collected via e-mail and Twitter, February 2016 / 0 ✓
# Test: 52000  52% (7m 37s) average_accuracy=0.4850 average_loss=1.0092 Data on violent crime shows Wisconsin "has become less safe than it was when Scott Walker took office." / 0 ✗ (1)
# Train: 53000  53% (7m 45s) average_accuracy=0.6270 average_loss=0.8367 "Rand Paul’s speech ... on 'Gattaca' was totally ripped off of Wikipedia." / 1 ✗ (2)
# Test: 53000  53% (7m 45s) average_accuracy=0.5220 average_loss=1.0047 A new federal program provides subsidized "Obama phones" with 70 free minutes of cell phone service every month. / 1 ✓
# Train: 54000  54% (7m 54s) average_accuracy=0.6360 average_loss=0.8363 Women need more sleep than men because their brains get more use on a day-to-day basis.
#
#
#
#
# 						See Example(s)
#
#
#
#
# 									Science has confirmed that women have more complex brains, which suggests that they need more sleep. Professor Jim Horne, director of the Sleep Research Centre at Loughborough University has a specific explanation on the importance of sleeping. / 0 ✗ (1)
# Test: 54000  54% (7m 54s) average_accuracy=0.4720 average_loss=1.0297  Mars will appear “as big as the Moon” on July 27.  / 1 ✗ (0)
# Train: 55000  55% (8m 2s) average_accuracy=0.6240 average_loss=0.8317 "Obama has jumped the shark and ordered the ocean closed!" / 0 ✓
# Test: 55000  55% (8m 2s) average_accuracy=0.5070 average_loss=0.9920 Tim Kaine: "opposes everything President Trump does." / 0 ✗ (1)
# Train: 56000  56% (8m 11s) average_accuracy=0.6240 average_loss=0.8667 In 2018, over 17,000 adults arrested at the border had prior criminal records, including 6,000 gang members (many of them MS-13). / 0 ✗ (1)
# Test: 56000  56% (8m 11s) average_accuracy=0.5010 average_loss=1.0257 "Texas is one of the most gerrymandered states in the union." / 1 ✓
# Train: 57000  56% (8m 21s) average_accuracy=0.6130 average_loss=0.8641 "The African-American community lost half of their wealth as a result of the Wall Street collapse." / 1 ✗ (2)
# Test: 57000  56% (8m 21s) average_accuracy=0.4750 average_loss=1.0333 Says the "Pope calls for world wide gun confiscation except for the UN" / 0 ✓
# Train: 58000  57% (8m 29s) average_accuracy=0.6270 average_loss=0.8563 A meme shows the American flag displayed on the White House in 2017, and a rainbow display in 2016. / 0 ✗ (1)
# Test: 58000  57% (8m 29s) average_accuracy=0.5090 average_loss=1.0043 Marjory Stoneman Douglas student David Hogg was caught lying about being on campus during a February 2018 school shooting when he told CBS that he had to get on his bicycle and ride to school. / 0 ✓
# Train: 59000  59% (8m 38s) average_accuracy=0.6090 average_loss=0.8661 China is "in the South China Sea and (building) a military fortress the likes of which perhaps the world has not seen." / 0 ✗ (1)
# Test: 59000  59% (8m 38s) average_accuracy=0.4770 average_loss=1.0324 "Malia Obama expelled from Harvard." / 0 ✓
# Train: 60000  60% (8m 47s) average_accuracy=0.6120 average_loss=0.8614 Says a Texas Senate committee considering "private school voucher" legislation randomly called people to testify regardless of when the people submitted requests to testify. / 1 ✗ (2)
# Test: 60000  60% (8m 47s) average_accuracy=0.5070 average_loss=0.9919 Says Josh Mandel opposed federal loans to the auto industry. / 0 ✓
# Train: 61000  61% (8m 55s) average_accuracy=0.6080 average_loss=0.8577 Under a new federal regulation, it will cost Pinellas County "$31 million to fix a single ditch." / 1 ✓
# Test: 61000  61% (8m 55s) average_accuracy=0.5050 average_loss=1.0063 President Obama declared Islam as America's "official religion."
#
#
#
#
# 						See Example(s)
#
#
#
#
# 									Facebook is running an article stating that Obama has made Muslam or Islam the official religion of the U.S. Any truth to that?
#
# Impeach Obama, Muslim Traitor: Obama Declares Islam As America’s Religion: https://t.co/JdtBqQpFlU
# — eddie ni (@edngai078_ni) May 20, 2016
#
#
#  																			Collected via Twitter and e-mail, May 2016 / 0 ✓
# Train: 62000  62% (9m 3s) average_accuracy=0.6400 average_loss=0.8435 Mothers of girls should be on the lookout for ice cream trucks (specifically Mr. Softee branded ones) as reports of chloroform kidnappings have surfaced.
#
#
#
#
# 						See Example(s)
#
#
#
#
# 																												Collected via e-mail and Facebook, June 2016 / 0 ✗ (1)
# Test: 62000  62% (9m 3s) average_accuracy=0.4860 average_loss=1.0135 Ancestry.com can retain the rights to your genetic information if you sign up for their DNA testing. / 0 ✗ (1)
# Train: 63000  63% (9m 12s) average_accuracy=0.6240 average_loss=0.8404 New York state subsidizes private colleges "probably more than any other state except maybe one." / 1 ✗ (2)
# Test: 63000  63% (9m 12s) average_accuracy=0.5190 average_loss=0.9730 Chinese restaurants in one of South Africa's capital cities are now allowed to sell dog meat. / 0 ✓
# Train: 64000  64% (9m 21s) average_accuracy=0.6190 average_loss=0.8367 St. Louis prosecutor Robert McCulloch runs a charity called Backstoppers that sold “I support Ofc. Darren Wilson” shirts to raise money for the policeman’s defense fund. / 1 ✓
# Test: 64000  64% (9m 21s) average_accuracy=0.5050 average_loss=1.0272 Says Sen. Kay Hagan "has missed half of the (Senate Armed Services) Committee's hearings in 2014." / 1 ✓
# Train: 65000  65% (9m 30s) average_accuracy=0.6450 average_loss=0.8389 In April 2018, Suge Knight was stabbed to death in prison. / 0 ✓
# Test: 65000  65% (9m 30s) average_accuracy=0.5180 average_loss=1.0119 Barack Obama was president when Hurricane Katrina hit New Orleans in 2005. / 1 ✗ (0)
# Train: 66000  66% (9m 40s) average_accuracy=0.6480 average_loss=0.8216 Two altar boys in Spain were arrested for putting marijuana in a censer. / 0 ✓
# Test: 66000  66% (9m 40s) average_accuracy=0.5110 average_loss=1.0112 A video depicts a Muslim woman fraudulently using food stamps to purchase soda to resell at her store.
#
#
#
#
# 						See Example(s)
#
#
#
#
# 									I just saw a video of a muslim woman packing her car with 2 large carts full of soda, she used up all her food stamps on soda. Is this a real video?
#
# ?‼️?? #USA, #NewYork: Welfare Scammers - Muslims caught buying Soda with Food Stamps to sell at their store. More: https://t.co/74O8qmkW3n pic.twitter.com/YfqYBpxIJJ— Onlinemagazin (@OnlineMagazin) September 30, 2016
#
#
# 																			Collected via Twitter, September 2016 / 1 ✓
# Train: 67000  67% (9m 49s) average_accuracy=0.5960 average_loss=0.8605 "The Wawa Welcome America festival (features) . . . America's largest free concert." / 0 ✓
# Test: 67000  67% (9m 49s) average_accuracy=0.5130 average_loss=1.0014 "The teachers in (charter) schools don't even have to be certified." / 1 ✓
# Train: 68000  68% (9m 57s) average_accuracy=0.6250 average_loss=0.8563 "There is no statistical evidence that bail bonds increase the likelihood of those awaiting trial returning to court for their scheduled hearings." / 1 ✗ (0)
# Test: 68000  68% (9m 57s) average_accuracy=0.5150 average_loss=1.0050 Says that during the first 19 months of the Obama administration, the U.S. detained people from nations designated as state sponsors of terrorism on the southwestern border. / 1 ✓
# Train: 69000  69% (10m 6s) average_accuracy=0.6170 average_loss=0.8538 "Consumer confidence, business confidence, and manufacturing confidence are the highest they have been in many decades." / 0 ✗ (1)
# Test: 69000  69% (10m 6s) average_accuracy=0.5000 average_loss=1.0178 "Nothing in the Constitution explicitly guarantees our right to vote." / 1 ✗ (2)
# Train: 70000  70% (10m 14s) average_accuracy=0.6400 average_loss=0.8233 A new analysis of the residue on common American foods showed high levels of the herbicide glyphosate and Monsanto, the EPA, and the FDA are in cahoots to silence word of the chemical’s harmful effects and its high concentration in foods. / 0 ✓
# Test: 70000  70% (10m 14s) average_accuracy=0.4850 average_loss=1.0185 Says Rick Perry wrote a newspaper item saying he was "open to amnesty" for illegal immigrants in the United States. / 0 ✗ (1)
# Train: 71000  71% (10m 23s) average_accuracy=0.6440 average_loss=0.8421 Donald Trump "heaping praise on a dangerous dictator in North Korea.” / 1 ✓
# Test: 71000  71% (10m 23s) average_accuracy=0.5030 average_loss=1.0249 A marijuana bill introduced into the U.S. House of Representatives during the 116th Congress is numbered H.R. 420 — a reference to marijuana culture. / 0 ✗ (2)
# Train: 72000  72% (10m 31s) average_accuracy=0.6520 average_loss=0.8248  "The FEC has announced that it may have to recommend invalidating more than 60K votes” in Alabama’s U.S. Senate race.  / 0 ✓
# Test: 72000  72% (10m 31s) average_accuracy=0.5020 average_loss=1.0157 "WV's tourism industry grew at a rate 30% above the national rate in 2017. This increase reversed a four-year decline in which travel-generated spending fell more than $600 million." / 1 ✓
# Train: 73000  73% (10m 40s) average_accuracy=0.6430 average_loss=0.8139 Preventive care "saves money." / 1 ✗ (0)
# Test: 73000  73% (10m 40s) average_accuracy=0.4980 average_loss=0.9998  "Got to get the jobs. Got 96 million people out there. We got to get them going, and they want to work. They gave up looking for jobs."  / 0 ✓
# Train: 74000  74% (10m 48s) average_accuracy=0.6190 average_loss=0.8448 In August 2017, the makers of Pepto-Bismol added xylitol, a sugar substitute harmful to dogs, as an ingredient / 0 ✓
# Test: 74000  74% (10m 48s) average_accuracy=0.4640 average_loss=1.0538 "We now have more jobs in solar than we do in oil." / 1 ✗ (0)
# Train: 75000  75% (10m 57s) average_accuracy=0.6220 average_loss=0.8352 The government "knowingly" injected a birth defect-inducing vaccine into epidurals between 2010 and 2014 to hurt Black women
#
#
#
#
# 						See Example(s)
#
#
#
#
# 									An government anesthesiologist came out and said during the years of 2010-2014, the federal government knowingly injected mothers with a  vaccine mixed in an anesthetic shot known as an Epidural. What was that vaccine? Well according to Henry Rothschild, (no relation to the Rothschild family allegedly) the vaccine is known as Terminar.
#
# Terminar which is Spanish for terminate, according to Mr. Rothschild Terminar was design to break down African American/Black women ovaries exposing them to different germs and multiple diseases which will likely produce a child with serious birth defects and serious illnesses.
#
# The government ran a secret operation releasing the anesthetic to predominately black areas. They figure it was best to distribute it through an Epidural so it will go unnoticed. Mr. Rothschild child is asking both black and white women to find out what illnesses may run in your family. If you received an Epidural between 2010-2014 and later gave birth anywhere from 2011 until present, if your child was born with any illness that's not normal this may be the reason why.																			Collected via e-mail, October 2016 / 0 ✓
# Test: 75000  75% (10m 57s) average_accuracy=0.4890 average_loss=1.0229 The U.S. Supreme Court has ruled that motorists need not have licenses to drive vehicles on public roads. / 1 ✗ (0)
# Train: 76000  76% (11m 5s) average_accuracy=0.6430 average_loss=0.8146 A California man was arrested in April 2016 for dressing in women's clothes and surreptitiously filming women in a public bathroom. / 0 ✗ (1)
# Test: 76000  76% (11m 5s) average_accuracy=0.5020 average_loss=1.0542 If you sign up for Equifax's credit-monitoring service, you cannot join any class-action lawsuit against the company. / 0 ✗ (1)
# Train: 77000  77% (11m 14s) average_accuracy=0.5850 average_loss=0.8536 Electronic benefits recipients in Iowa can no longer purchase soda and candy as of 1 October 2017. / 0 ✓
# Test: 77000  77% (11m 14s) average_accuracy=0.4590 average_loss=1.0911 Wearing red on Fridays will demonstrate support for  troops overseas. / 1 ✓
# Train: 78000  78% (11m 23s) average_accuracy=0.6360 average_loss=0.8370 John McCain wants to "give oil companies another $4-billion" in tax breaks. / 1 ✗ (2)
# Test: 78000  78% (11m 23s) average_accuracy=0.5130 average_loss=1.0377 Says Indiana Gov. Mike Pence "denies that there's such a thing as evolution." / 0 ✗ (1)
# Train: 79000  79% (11m 31s) average_accuracy=0.6250 average_loss=0.8584 "We sell 40 percent of our guns without a background check." / 1 ✓
# Test: 79000  79% (11m 31s) average_accuracy=0.5150 average_loss=0.9957 When McCain was questioned about hiring lobbyists to his campaign staff, "his top lobbyist actually had the nerve to say, 'The American people won't care about this.' " / 0 ✗ (2)
# Train: 80000  80% (11m 40s) average_accuracy=0.6160 average_loss=0.8210 A photo depicting a man crucified and suspended from a road sign in Mexico has been shared tens of thousands of times in various contexts. The man in the photo was a suspect in a rape case in the town in Contepec, Mexico in 2012. He was kidnapped on his way to be interrogated by the police and found dead the next day, his naked body spread across a board and suspended from a road sign. Pedophile crucified as warning to others / 1 ✗ (0)
# Test: 80000  80% (11m 40s) average_accuracy=0.5140 average_loss=1.0039 Wisconsin is "dead-last in creating new businesses" for "three years in a row." / 1 ✓
# Train: 81000  81% (11m 49s) average_accuracy=0.6470 average_loss=0.8384 Says Donald Trump "said as recently as a few weeks ago in Phoenix that every undocumented person would be subject to deportation." / 1 ✓
# Test: 81000  81% (11m 49s) average_accuracy=0.5130 average_loss=1.0006 Ted Cruz is ineligible to serve as President of the United States because he was born in Canada. / 0 ✓
# Train: 82000  82% (11m 59s) average_accuracy=0.6350 average_loss=0.8327 DACA was "a mere memo from the Department of Homeland security under Barack Obama, which violated the laws." / 1 ✓
# Test: 82000  82% (11m 59s) average_accuracy=0.4960 average_loss=0.9991 "The pastor McCain calls his 'spiritual guide,' Rod Parsley, believes America's founding mission is to destroy Islam, which he calls a 'false religion.' " / 1 ✓
# Train: 83000  83% (12m 8s) average_accuracy=0.6450 average_loss=0.8248 Is Mayor Carmen Yulín Cruz of San Juan Facing Charges of Over $3 Million in Fraud? / 0 ✓
# Test: 83000  83% (12m 8s) average_accuracy=0.4880 average_loss=1.0308 Says Tammy Baldwin’s "Medicare for All" plan means senior citizens would "no longer have" Medicare. / 0 ✗ (1)
# Train: 84000  84% (12m 17s) average_accuracy=0.6030 average_loss=0.8452 “I’m very much opposed to sanctuary cities. They breed crime. There’s a lot of problems.” / 0 ✗ (1)
# Test: 84000  84% (12m 17s) average_accuracy=0.4690 average_loss=1.0461 Fireball whisky is being recalled due to concerns over a dangerous ingredient.
#
#
#
#
# 						See Example(s)
#
#
#
#
# 									There is some information coming through from unknown media sources and social media (namely, Facebook), that Fireball Whiskey is being pulled from shelves in Europe do to high levels of propylene glycol in the beverage.																			Collected via e-mail, October 2014 / 0 ✗ (1)
# Train: 85000  85% (12m 26s) average_accuracy=0.6220 average_loss=0.8458 States with voter ID laws have seen "zero decrease" in participation. "Most have seen an increase." / 1 ✓
# Test: 85000  85% (12m 26s) average_accuracy=0.5050 average_loss=1.0165 "Ted Cruz tried to ban contraception" five times. / 1 ✓
# Train: 86000  86% (12m 34s) average_accuracy=0.6240 average_loss=0.8540 New York State Gov. Andrew Cuomo issued a multi-state "travel ban" involving states with "lax gun laws."
#
#
#
#
# 						See Example(s)
#
#
#
#
# 									I can't bring myself to read all of this garbage but this can't possibly be real.
#
# http://concealednation.org/2016/04/ny-governor-andrew-cuomo-issues-travel-ban-to-numerous-states-over-lax-gun-laws/
#
# NY Governor Andrew Cuomo Issues Travel Ban To Numerous States Over Lax Gun Laws https://t.co/ZGliDGmvI8
# — FTSN Network (@fightingtyranny) April 7, 2016
# 																			Collected via e-mail and Twitter, April 2016 / 0 ✓
# Test: 86000  86% (12m 34s) average_accuracy=0.4860 average_loss=1.0657 Says "80 percent of the tax breaks in" President Donald Trump’s tax-cut "proposal go to the top 1 percent, that is, people making more than $730,000 a year." / 1 ✓
# Train: 87000  87% (12m 43s) average_accuracy=0.6090 average_loss=0.8621 If you don't count illegal aliens, people who qualify for other insurance, and people who make more than $75,000 a year, "it leaves about 15 million people" who are uninsured. / 1 ✓
# Test: 87000  87% (12m 43s) average_accuracy=0.4860 average_loss=1.0521 In February 2018, Amnesty International officially declared U.S. President Donald Trump a "human rights violator." / 0 ✗ (1)
# Train: 88000  88% (12m 52s) average_accuracy=0.6350 average_loss=0.8229 Says GOP Congressional candidate Scott Jones "wants to build a wall. He wants to round people up and deport folks." / 1 ✓
# Test: 88000  88% (12m 52s) average_accuracy=0.5090 average_loss=1.0150 In a "sweetheart deal … members of Congress, thanks to the Obama administration, are going to be the only people in America to get subsidies in the Obamacare exchanges." / 0 ✓
# Train: 89000  89% (13m 1s) average_accuracy=0.6180 average_loss=0.8390 Wisconsin politicians get daily expense payments "even if they don’t spend a dime on meals, or lodging or travel," and "no receipts are required for them to get paid." / 1 ✓
# Test: 89000  89% (13m 1s) average_accuracy=0.4880 average_loss=1.0203 Says former President Barack Obama "pardoned a traitor who gave U.S. enemies state secrets, he also pardoned a terrorist who killed Americans." / 0 ✗ (1)
# Train: 90000  90% (13m 10s) average_accuracy=0.6390 average_loss=0.8462 Photograph shows a drunk gorilla about to punch a photographer. / 0 ✗ (1)
# Test: 90000  90% (13m 10s) average_accuracy=0.4990 average_loss=1.0146 "Families in Del Valle, who are City of Austin residents, have to drive to Bastrop to go to the closest grocery store." / 1 ✗ (0)
# Train: 91000  91% (13m 19s) average_accuracy=0.6160 average_loss=0.8264 U.S. national security agencies went on "high alert" after President-Elect Donald Trump was caught telling "a dangerous lie." / 0 ✓
# Test: 91000  91% (13m 19s) average_accuracy=0.4780 average_loss=1.0412 Because George Holding doesn’t live in the congressional district he’s running for, he "doesn’t experience the same things that we are all experiencing." / 1 ✓
# Train: 92000  92% (13m 28s) average_accuracy=0.6010 average_loss=0.8408 President Trump tweeted on 14 February 2017 that Betsy DeVos was correct in suggesting disabled students are disruptive in the classroom.
#
#
#
#
# 						See Example(s)
#
#
#
#
# 									This tweet is on Facebook posted by Democrats for a Blue America. It's from @real Donald Trump.
# Devos is right. Handicapped and minority children are too disruptive for the classroom. Disaster! Perhaps not everyone needs K-12 education.
# I'm doubting it's real but who knows?																			Collected via e-mail, February 2017 / 0 ✓
# Test: 92000  92% (13m 28s) average_accuracy=0.4720 average_loss=1.0411 “That is absolutely false" that a servicemember who handled classified information the way Hillary Clinton did would be court-martialed. / 1 ✓
# Train: 93000  93% (13m 37s) average_accuracy=0.6190 average_loss=0.8375 The Employment Non-Discrimination Act "discriminates against Christian daycare, Christian parents, Christian business owners, and the rights of religious freedom." / 1 ✗ (0)
# Test: 93000  93% (13m 37s) average_accuracy=0.4620 average_loss=1.0399 American schools are "more segregated than they were in the 1960s." / 1 ✓
# Train: 94000  94% (13m 46s) average_accuracy=0.6030 average_loss=0.8751 "Update: Chuck Schumer’s steamy affair with a high school cheerleader confirmed." / 0 ✓
# Test: 94000  94% (13m 46s) average_accuracy=0.4950 average_loss=1.0144 It's entirely possible that the Democratic nominee, [Hillary Clinton], earned more money giving a single speech on Wall Street than I made the six years that I was there back in the 1980s… In fact, it’s quite likely. / 0 ✗ (1)
# Train: 95000  95% (13m 55s) average_accuracy=0.6000 average_loss=0.8709 "Venezuela is a country whose defense budget is probably 1/600th of the United States." / 1 ✓
# Test: 95000  95% (13m 55s) average_accuracy=0.4880 average_loss=1.0126 "We give (foreign aid) to developing countries, and 70 percent of it's stolen off the top." / 1 ✗ (0)
# Train: 96000  96% (14m 4s) average_accuracy=0.6260 average_loss=0.8402 A video shows Muslim men auctioning off women on the streets of England.
#
#
#
#
# 						See Example(s)
#
#
#
#
# 									Video showing Muslim men supposedly auctioning off Muslim women on the streets of England. Can this be true that this is allowed in a free country?																			Collected via e-mail, June 2016 / 0 ✓
# Test: 96000  96% (14m 4s) average_accuracy=0.4820 average_loss=1.0446 "More lives have been lost because of the war with the drug cartels in Juarez alone, just a few blocks from the United States of America, than have been lost in the war in Afghanistan." / 1 ✗ (0)
# Train: 97000  97% (14m 12s) average_accuracy=0.6150 average_loss=0.8324 "Hospitals have already begun layoffs, a direct result of Republican inaction" on Medicaid expansion. / 1 ✓
# Test: 97000  97% (14m 12s) average_accuracy=0.5210 average_loss=0.9907 A sculpture "celebrating" Saudi Arabia was erected at Ground Zero. / 0 ✗ (1)
# Train: 98000  98% (14m 21s) average_accuracy=0.6240 average_loss=0.8318 Artisanal and small-scale miners are responsible for 90% of Nigeria’s mineral production / 1 ✗ (0)
# Test: 98000  98% (14m 21s) average_accuracy=0.4970 average_loss=1.0266 The Joe's Crab Shack restaurant chain was criticized after a picture of a man being hanged was discovered on its table decor. / 0 ✗ (2)
# Train: 99000  99% (14m 31s) average_accuracy=0.6220 average_loss=0.8495 "We are not even into February and the cost of illegal immigration so far this year is $18,959,495,168. Cost Friday was $603,331,392. There are at least 25,772,342 illegal aliens, not the 11,000,000 that have been reported for years, in our Country." / 0 ✓
# Test: 99000  99% (14m 31s) average_accuracy=0.5060 average_loss=1.0147 Says Leah Vukmir was "just about the only legislator who stood with the insurance companies" and "voted against oral chemotherapy." / 1 ✓
# Train: 100000  100% (14m 41s) average_accuracy=0.6390 average_loss=0.8216 "House Republicans pledged to introduce a bill to reform America’s health care system," but "the 'party of no' has . . . failed to produce legislation." / 1 ✓
# Test: 100000  100% (14m 41s) average_accuracy=0.4890 average_loss=1.3349 There is a type of "living brooch" made and sold in Mexico consisting of a live beetle coated in gold and gemstones. / 1 ✗ (2)

# %%
#Saving data
import json
with open('A5Q2A_all_train_accuracies_ii.json', 'w') as f:
    json.dump(all_train_accuracies_ii, f)
    
with open('A5Q2A_all_test_accuracies_ii.json', 'w') as f:
    json.dump(all_test_accuracies_ii, f)

# %%
#Loading Data
import json
with open('A5Q2A_all_train_accuracies_ii.json', 'r') as f:
   all_train_accuracies_ii = json.load(f)
    
with open('A5Q2A_all_test_accuracies_ii.json', 'r') as f:
   all_test_accuracies_ii = json.load(f)

# %%
plt.figure(figsize = (12,4))
plt.subplot(1,2,1)
plt.plot(all_train_accuracies, label = 'Train Accuracy (claim only)')
plt.plot(all_train_accuracies_ii, label = 'Train Accuracy_ii (claim & claimant)')
plt.legend()

plt.subplot(1,2,2)
plt.plot(all_test_accuracies, label = 'Test Accuracy (claim only)')
plt.plot(all_test_accuracies_ii, label = 'Test Accuracy_ii (claim and claimant)')
plt.legend()

# %% [markdown]
# # Q2a) iii
# ## Claim, claimant, and sample sentences as inputs to RNN

# %%
def sampleSentences(id): 
  
  sentences = relevant_sentences[0]
  sentences_tensor = torch.tensor([])
  for i in range(5):
    embedding = bpemb_en.embed(relevant_sentences[0][i])
    embedding = np.reshape(embedding,(embedding.shape[0],1,embedding.shape[1]))
    sentence_tensor = torch.tensor(embedding, dtype=torch.float)
    sentences_tensor = torch.cat((sentences_tensor, sentence_tensor), 0)
  
  return sentences_tensor, sentences

# %%
def train_iii(category_tensor, line_tensor, update=True):
    rnnOptimizer.zero_grad()
    classifierOptimizer.zero_grad()

    hidden = rnn_iii.initHidden()
    for i in range(line_tensor.size()[0]):
        hidden = rnn_iii(line_tensor[i], hidden)
    output = classifier_iii(hidden)

    loss = criterion(output, category_tensor)
    if update:
        loss.backward()
        rnnOptimizer.step()
        classifierOptimizer.step()
        
    return output, loss.item()

# %%
import time
import math

n_hidden = 128
n_categories = 3
rnn_iii = RNN(n_embedding_dims, n_hidden) #multiplied by 2 for claim+claimant
classifier_iii = Classifier(n_hidden, n_categories)

criterion = nn.NLLLoss()
learning_rate = 1e-4
rnnOptimizer = torch.optim.Adam(rnn_iii.parameters(), lr=learning_rate)
classifierOptimizer = torch.optim.Adam(classifier_iii.parameters(), lr=learning_rate)

n_iters = 100000
plot_every = 1000

# Keep track of losses for plotting
current_loss = 0
all_losses = []

def timeSince(since):
    now = time.time()
    s = now - since
    m = math.floor(s / 60)
    s -= m * 60
    return '%dm %ds' % (m, s)

start = time.time()

train_data = metadata[:10000]
test_data = metadata[10000:]
train_cumulative_loss = 0
test_cumulative_loss = 0
average_train_accuracy = 0
average_test_accuracy = 0
all_train_losses = []
all_train_accuracies_iii = []
all_test_losses = []
all_test_accuracies_iii = []
count = 0
for iter in range(1, n_iters + 1):
    train_claim_tensor, train_category_tensor, train_claim, train_category, train_id = sampleClaim(train_data)
    train_claimant_tensor, train_claimant = sampleClaimant(train_id)
    
    train_sentences_tensor, train_sentences = sampleSentences(train_id)
    
    train_line_tensor = torch.cat((train_claim_tensor, train_claimant_tensor, train_sentences_tensor), 0)
    
     
    train_output, train_loss = train_iii(train_category_tensor, train_line_tensor)    
    top_train_value, top_train_index = train_output.topk(1)
    train_guess_category = top_train_index[0].item()
    train_cumulative_loss += train_loss
    train_accuracy = 1 if train_guess_category == train_category else 0
    average_train_accuracy = (average_train_accuracy * count + train_accuracy) / (count+1)
    
    test_claim_tensor, test_category_tensor, test_claim, test_category, test_id = sampleClaim(test_data)
    test_claimant_tensor, test_claimant = sampleClaimant(test_id)
    test_sentences_tensor, test_sentences = sampleSentences(test_id)
    test_line_tensor = torch.cat((test_claim_tensor, test_claimant_tensor, test_sentences_tensor), 0)
        
    test_output, test_loss = train_iii(test_category_tensor, test_line_tensor, update=False)
    
    top_test_value, top_test_index = test_output.topk(1)
    test_guess_category = top_test_index[0].item()
    test_cumulative_loss += test_loss
    test_accuracy = 1 if test_guess_category == test_category else 0
    average_test_accuracy = (average_test_accuracy * count + test_accuracy) / (count+1)
    count += 1

    # Add current loss avg to list of losses
    if iter % plot_every == 0:
        train_correct = '✓' if train_guess_category == train_category else '✗ (%s)' % train_category
        print('Train: %d  %d%% (%s) average_accuracy=%.4f average_loss=%.4f %s / %s %s' % (iter, iter / n_iters * 100, timeSince(start), average_train_accuracy, train_cumulative_loss / plot_every, train_claim, train_guess_category, train_correct))
        test_correct = '✓' if test_guess_category == test_category else '✗ (%s)' % test_category
        print('Test: %d  %d%% (%s) average_accuracy=%.4f average_loss=%.4f %s / %s %s' % (iter, iter / n_iters * 100, timeSince(start), average_test_accuracy, test_cumulative_loss / plot_every, test_claim, test_guess_category, test_correct))
        all_train_losses.append(train_cumulative_loss / plot_every)
        all_train_accuracies_iii.append(average_train_accuracy)
        all_test_losses.append(test_cumulative_loss / plot_every)
        all_test_accuracies_iii.append(average_test_accuracy)
        train_cumulative_loss = 0
        average_train_accuracy = 0
        test_cumulative_loss = 0
        average_test_accuracy = 0
        count = 0
        
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker

plt.figure()
plt.plot(all_train_accuracies_iii)
# Out:
# Train: 1000  1% (0m 53s) average_accuracy=0.4760 average_loss=0.9568 "Roy Cooper's refusal to do his job is costing taxpayers money." / 0 ✗ (1)
# Test: 1000  1% (0m 53s) average_accuracy=0.4420 average_loss=0.9713 Scientific studies support the conclusion that marijuana can play a role in healing broken bones. / 0 ✗ (1)
# Train: 2000  2% (1m 46s) average_accuracy=0.4690 average_loss=0.9540 It’s "typical" for a presidential candidate to release 10 or 11 years of tax returns. / 0 ✗ (1)
# Test: 2000  2% (1m 46s) average_accuracy=0.4730 average_loss=0.9472 Donald Trump said there should be "some form of punishment" for women who have abortions.
#
#
#
#
# 						See Example(s)
#
#
#
#
#
# SHOCKING SHOCKER: Trump Takes Left-wing Parody of Conservative Position on Abortion
# — Trumpbart News (@Trumpbart) March 30, 2016
#
#
# Wondering if this is true:
#
# Trump says if he's elected there will be "some form of punishment" for abortion. As if Trump being president wouldn't be enough punishment. — CAFE (@cafedotcom) March 30, 2016
#
# 																			Collected via e-mail and Twitter, March 2016 / 0 ✗ (1)
# Train: 3000  3% (2m 40s) average_accuracy=0.4440 average_loss=0.9519 Perpetrators of school shootings "have been drugged in many cases … many of these young boys have been on Ritalin since they were in kindergarten." / 0 ✓
# Test: 3000  3% (2m 40s) average_accuracy=0.4360 average_loss=0.9428 What Republicans call the "death tax" is the estate tax "on the ultra wealthy" which, in 2016, was paid by only "two out of every 1,000 people." / 0 ✗ (2)
# Train: 4000  4% (3m 34s) average_accuracy=0.4750 average_loss=0.9525 FBI agents raided Rep. Debbie Wasserman-Schultz's home and seized smashed computer hard drives. / 0 ✓
# Test: 4000  4% (3m 34s) average_accuracy=0.4530 average_loss=0.9613 Press Secretary Sarah Sanders said that President Trump's tax returns were being kept "underneath President Obama’s college records" and "his passport application" where nobody would find them. / 0 ✓
# Train: 5000  5% (4m 28s) average_accuracy=0.4590 average_loss=0.9853 The NFL's rulebook contains a regulation specifically requiring players to stand on the sideline during the pre-game playing of the U.S. national anthem. / 0 ✗ (1)
# Test: 5000  5% (4m 28s) average_accuracy=0.4620 average_loss=0.9567 The name of the make-believe land featured in L. Frank Baum’s series of Oz books was taken from a file cabinet drawer labeled O – Z. / 0 ✓
# Train: 6000  6% (5m 21s) average_accuracy=0.4840 average_loss=0.9635  "BREAKING: Kaepernick Arrested for Publicity Stunt During Anthem in San Fran"  / 1 ✗ (0)
# Test: 6000  6% (5m 21s) average_accuracy=0.4650 average_loss=0.9755 Fireball whisky is being recalled due to concerns over a dangerous ingredient.
#
#
#
#
# 						See Example(s)
#
#
#
#
# 									There is some information coming through from unknown media sources and social media (namely, Facebook), that Fireball Whiskey is being pulled from shelves in Europe do to high levels of propylene glycol in the beverage.																			Collected via e-mail, October 2014 / 1 ✓
# Train: 7000  7% (6m 15s) average_accuracy=0.4370 average_loss=0.9839 Rick Scott  "invested $38 million in the Port of Jacksonville's vital Mile Point Project," which "covered missing federal funds for the project." / 0 ✗ (1)
# Test: 7000  7% (6m 15s) average_accuracy=0.4670 average_loss=0.9627 "The #irandeal ultimately would have guaranteed Iran a nuclear bomb capable of reaching the US." / 0 ✓
# Train: 8000  8% (7m 9s) average_accuracy=0.4800 average_loss=0.9718 "We really have done a great job. We’re actually taking people that are criminals — very, very, hardened criminals in some cases with a tremendous track record of abuse and problems — and we’re getting them out and that’s what I said I would do." / 0 ✗ (1)
# Test: 8000  8% (7m 9s) average_accuracy=0.5000 average_loss=0.9566 A 2013 state law would allow the operator of an iron ore mine in northern Wisconsin to "fill in pristine streams and ponds with mine waste." / 0 ✗ (1)
# Train: 9000  9% (8m 3s) average_accuracy=0.4350 average_loss=0.9765 Texas agriculture is "at 98 percent efficiency" in water use and "just about maxed out as to what we can do on the conservation end of it." / 0 ✗ (1)
# Test: 9000  9% (8m 3s) average_accuracy=0.4680 average_loss=0.9590 "That's legal: If you find out about somebody else's salary even if you're doing exactly the same job, you can be retaliated against, including being fired, in most places." / 0 ✗ (1)
# Train: 10000  10% (8m 56s) average_accuracy=0.4730 average_loss=0.9575 Says "over 40 percent of recent county bonds are for Precinct One, northeast Travis County," because he "is quick to identify projects that help make the East Side a desirable place to live." / 0 ✗ (1)
# Test: 10000  10% (8m 56s) average_accuracy=0.4450 average_loss=0.9560 The federal health care plan "costs Texas taxpayers $2.4 billion per year." / 0 ✗ (1)
# Train: 11000  11% (9m 51s) average_accuracy=0.4820 average_loss=0.9663  Sayfullo Saipov, the Uzbekistan national who was arrested in a terrorist attack in New York City last year, "brought a lot of people with him. They say 22 people."  / 0 ✓
# Test: 11000  11% (9m 51s) average_accuracy=0.4910 average_loss=0.9527 Democratic gubernatorial candidate Stacey Abrams burned the Georgia state flag during a protest in 1992. / 0 ✗ (1)
# Train: 12000  12% (10m 45s) average_accuracy=0.4690 average_loss=0.9338 "As Secretary of State, Hillary Clinton laundered money to Bill Clinton through Laureate Education, while Bill Clinton was an honorary chairman of the group." / 0 ✓
# Test: 12000  12% (10m 45s) average_accuracy=0.4630 average_loss=0.9802 Former President George W. Bush and former Vice President Dick Cheney are "unable to visit Europe due to outstanding warrants." / 0 ✓
# Train: 13000  13% (11m 39s) average_accuracy=0.4740 average_loss=0.9918 Donald Trump donated food and supplies to Lumberton, North Carolina, and other towns ravaged by Hurricane Matthew.
#
#
#
#
# 						See Example(s)
#
#
#
#
# 									I would like to know if this is true or fake. Thank you for your time.
#
# Donald Trump brought food and supplies to Lumberton, NC and to 3 other towns ravaged by Hurricane Matthew.. you won't see this one in the news, they are too busy making up trash on him.. thank you Donald, this is what a real leader looks like people! Feel free to share this great story!																			Collected via e-mail, October 2016 / 0 ✗ (2)
# Test: 13000  13% (11m 39s) average_accuracy=0.4590 average_loss=0.9652 Barack Obama said "he's going to attack Pakistan and embrace (Iranian President Mahmoud) Ahmadinejad." / 0 ✓
# Train: 14000  14% (12m 33s) average_accuracy=0.4620 average_loss=0.9563 Attorney General Jeff Sessions said using marijuana leads to more sex, thus causing more unwanted pregnancies and more abortions. / 0 ✓
# Test: 14000  14% (12m 33s) average_accuracy=0.4690 average_loss=0.9716 Kenyan court convicted 11 people of cannibalism / 0 ✓
# Train: 15000  15% (13m 28s) average_accuracy=0.4790 average_loss=0.9621 "A government panel that didn't include cancer specialists says women shouldn't  receive mammograms until age 50...If government takes over health care,  recommendations like these could become the law for all kinds of diseases." / 0 ✓
# Test: 15000  15% (13m 28s) average_accuracy=0.4450 average_loss=0.9725 China Exim Bank has taken ‘absolute control of Eskom power facility in South Africa’ / 0 ✓
# Train: 16000  16% (14m 22s) average_accuracy=0.4870 average_loss=0.9436 "There are at least 2 million ... criminal aliens now inside of our country" and 300,000 have returned to community. / 0 ✗ (1)
# Test: 16000  16% (14m 22s) average_accuracy=0.4740 average_loss=0.9580 Of the 98 top oxycodone-dispensing doctors who used to live in Florida, "today, there are none." / 0 ✗ (1)
# Train: 17000  17% (15m 16s) average_accuracy=0.4890 average_loss=0.9424 Says the United States has "treaties with apparently 69 countries where we are obligated to defend their borders. And these were treaties that were executive treaties, not authorized by Congress." / 1 ✓
# Test: 17000  17% (15m 16s) average_accuracy=0.4760 average_loss=0.9644 Says Howard Zinn, "an anti-American Marxist," wrote "the most popular textbook that's taught in our high schools in America." / 0 ✗ (1)
# Train: 18000  18% (16m 10s) average_accuracy=0.4620 average_loss=0.9679 Elizabeth Warren "took a bogus DNA test and it showed that she may be 1/1024, far less than the average American.” / 0 ✗ (1)
# Test: 18000  18% (16m 10s) average_accuracy=0.4910 average_loss=0.9481 Middle Eastern men purchased dozens of burner cell phones at Walmarts in and around Lebanon, Missouri (ostensibly to carry out terror attacks); at the same time, multiple stores reported propane tank thefts.
#
#
#
#
# 						See Example(s)
#
#
#
#
#
# A large portion of the phones were bought by “three men with accents” at one Walmart near the town of Lebanon,... https://t.co/L4KP94rUYD
# — Anthony J Hilder (@anthonyjhilder) December 11, 2015
#
#
# Lebanon: "Foreign-Speaking" Men Walked Into US Walmart At 3 AM; Bought 60 Phones. https://t.co/0WHllSOfrn Cops questioned & Released — IWantFacts (@sjh2222) December 11, 2015
#
#
#
# You won't hear this on the news! Lebanon, MO #walmart #muslims enter at 4:30 am and try to buy 60 cellphones. #WakeUpAmerica
# — Trickdarter (@Trickdarter) December 5, 2015
#
#
# I first heard it was at a Lebanon MO Walmart, but it's starting to be evident that it has happened at walmarts... https://t.co/Pmg4ck8MGP — gobrendon (@gobrendon) December 10, 2015
#
#
#
# Ones casualities start coming in due to your blatant disregard and obvious knowing of those Muslim extremists buying those burner phones, we the people will blame you. There was more than enough reasonable suspicion to arrest those foreigners on a probable threat of terrorism. THey are not US citizens, they don't need due process like AMericans. You're just as bad as the UK police and too intimidated to do a damn thing about it! Now they are gone....and we have NO IDEA what they are planning, whether its suicide bombing or somethng else. THANKS, YOU GUYS DID A BANGUP JOB!!! You're idiots!
#
# ____________________________________________________________________________________
#
# Published on Dec 11, 2015 www.undergroundworldnews.com
# The FBI has launched an investigation after 150 prepaid mobile phones were bought from local Walmarts in Missouri. This comes after the theft of dozens of propane tanks in the area.
#
# The large number of purchases took place at six Missouri Walmarts at least, authorities say, according to KRCG13.																			Collected via Twitter and Facebook, December 2015 / 0 ✗ (1)
# Train: 19000  19% (17m 4s) average_accuracy=0.4660 average_loss=0.9933 “After decreasing for nearly 20 years because of the hard but necessary work our country started in the 1980s, violent crime is back with a vengeance.” / 0 ✓
# Test: 19000  19% (17m 4s) average_accuracy=0.4800 average_loss=0.9536 Says "Mike Madigan and Kwame Raoul team up to raise property taxes." / 0 ✗ (1)
# Train: 20000  20% (17m 58s) average_accuracy=0.4870 average_loss=0.9634 Says Scott Walker "wants state taxpayers to dole out up to $250 million annually in incentives" to Foxconn "to lure a manufacturing plant to Wisconsin that he claims will generate $181 million in tax revenue." / 0 ✗ (1)
# Test: 20000  20% (17m 58s) average_accuracy=0.4450 average_loss=0.9788 Says a man opted out of Obamacare after the marketplace launched on Oct. 1, 2013, and was informed he owed a $4,000 fine. / 0 ✓
# Train: 21000  21% (18m 51s) average_accuracy=0.4650 average_loss=0.9751 "New reports show Kevin Nicholson made over $1 million advising companies that shut down Wisconsin plants and laid off 1,900 people." / 0 ✗ (1)
# Test: 21000  21% (18m 51s) average_accuracy=0.4660 average_loss=0.9543 In February 2018, Amnesty International officially declared U.S. President Donald Trump a "human rights violator." / 0 ✗ (1)
# Train: 22000  22% (19m 45s) average_accuracy=0.4690 average_loss=0.9523 "Facts have come to light that indicate that a pivotal, close election was likely changed through voter fraud on November 8, 2016: New Hampshire’s U.S. Senate Seat, and perhaps also New Hampshire’s four Electoral College votes in the presidential election." / 0 ✓
# Test: 22000  22% (19m 45s) average_accuracy=0.4720 average_loss=0.9712 Recent solar energy policies in Georgia "have resulted in rate hikes and did not result in solar becoming any more economically viable." / 0 ✓
# Train: 23000  23% (20m 38s) average_accuracy=0.4330 average_loss=0.9953 Says he "turned down a Medicaid expansion under Obamacare," but because of actions he took, for the first time in Wisconsin's history "everyone living in poverty is covered under Medicaid." / 0 ✗ (1)
# Test: 23000  23% (20m 38s) average_accuracy=0.4670 average_loss=0.9640 Cervical cancer in Africa is "fully preventable with basic education, screening and vaccines." / 0 ✗ (1)
# Train: 24000  24% (21m 32s) average_accuracy=0.5180 average_loss=0.9495 "The last Christians are about to leave" Iraq. / 0 ✓
# Test: 24000  24% (21m 32s) average_accuracy=0.4650 average_loss=0.9575 Fox News included an image of singer Patti LaBelle instead of Aretha Franklin in a tribute piece after the latter's passing. / 0 ✗ (2)
# Train: 25000  25% (22m 25s) average_accuracy=0.4660 average_loss=0.9780 “Brussels surely understands that replacing the Russian pipeline gas with American LNG does not increase, but reduces the energy security of the EU.” / 0 ✓
# Test: 25000  25% (22m 25s) average_accuracy=0.4650 average_loss=0.9512 Says Target installed urinals in a women’s bathroom to "accommodate the ones who have giblets." / 0 ✓
# Train: 26000  26% (23m 18s) average_accuracy=0.4410 average_loss=0.9836 "Ken Starr’s plane just disappeared on his way to D.C. to testify against Hillary (Clinton)." / 0 ✓
# Test: 26000  26% (23m 18s) average_accuracy=0.4500 average_loss=0.9472 "Of the 25 wealthiest nations, we're the only one that doesn't provide basic health coverage." / 0 ✗ (2)
# Train: 27000  27% (24m 11s) average_accuracy=0.4430 average_loss=0.9913 A photograph shows a rhino that was given a pink horn to prevent poaching. / 0 ✗ (1)
# Test: 27000  27% (24m 11s) average_accuracy=0.4580 average_loss=0.9374 A  video shows a "weather reporter" getting smacked in the face by a flying fish during a television segment. / 0 ✗ (1)
# Train: 28000  28% (25m 4s) average_accuracy=0.5000 average_loss=0.9747 “You have to commit a criminal offence” to fall within the scope of C-51 powers / 0 ✓
# Test: 28000  28% (25m 4s) average_accuracy=0.4600 average_loss=0.9447  “Student loan interest, medical expenses, property taxes" aren't tax deductible this year.  / 0 ✓
# Train: 29000  28% (25m 57s) average_accuracy=0.4840 average_loss=0.9632 Jill Stein endorsed Donald Trump for President. / 0 ✓
# Test: 29000  28% (25m 57s) average_accuracy=0.4770 average_loss=0.9598 Average water consumption in South Africa is 235 litres per capita per day / 0 ✗ (1)
# Train: 30000  30% (26m 51s) average_accuracy=0.4790 average_loss=0.9615 The Women's March on Washington is tallying attendees by asking them to text "COUNT ME" to 89800.
#
#
#
#
# 						See Example(s)
#
#
#
#
# 									People who marched in Saturday's Women's March on Washington (and elsewhere in the world) were encouraged to text "count me" to the number 898-00, ostensibly to get a headcount of marchers. Turns out it was propagated by It'sTime.org, which seems like a legitimate community organizing site. However there are rumors that it's really a phish.																			Collected via e-mail, January 2017 / 0 ✗ (1)
# Test: 30000  30% (26m 51s) average_accuracy=0.4660 average_loss=0.9774 A photograph shows a group of black brunch protesters at a KFC in New York City. / 0 ✓
# Train: 31000  31% (27m 45s) average_accuracy=0.4950 average_loss=0.9728 Billionaire political activist George Soros could go to prison for years because of $1.8 billion in "intercepted" campaign contributions to candidates in local district attorney elections. / 0 ✓
# Test: 31000  31% (27m 45s) average_accuracy=0.4620 average_loss=0.9703 “Canada spends $12 billion a year on oil from Saudi Arabia.” / 0 ✓
# Train: 32000  32% (28m 38s) average_accuracy=0.4680 average_loss=0.9738 A mother named her child "Le-a," which she insists be pronounced "Ledasha." / 0 ✓
# Test: 32000  32% (28m 38s) average_accuracy=0.4680 average_loss=0.9645 President Mutharika commissions a water tap / 0 ✗ (1)
# Train: 33000  33% (29m 31s) average_accuracy=0.4750 average_loss=0.9876 "Since World War II, only Gerald Ford and Bill Clinton have had worse ratings after seven months than President Obama." / 0 ✗ (2)
# Test: 33000  33% (29m 31s) average_accuracy=0.4340 average_loss=0.9627 "Pregnant women who stand for five to six hours at a time increase their risk of pre-term pregnancy by 80 percent." / 0 ✗ (1)
# Train: 34000  34% (30m 24s) average_accuracy=0.4700 average_loss=0.9396 ​​“The step (reducing U.S. Treasury Securities) is being considered a prudent approach directed towards insulating the country from the US attempt to weaponize the dollar.” / 0 ✓
# Test: 34000  34% (30m 24s) average_accuracy=0.4530 average_loss=0.9679 The official Campbell's customer service Facebook account insulted a customer after she complained about the brand's commercial featuring two dads. / 0 ✓
# Train: 35000  35% (31m 17s) average_accuracy=0.4710 average_loss=0.9570 “I know Governor Kasich isn’t with us, but I suspect that he’s very troubled to know that in Ohio alone, nearly 60,000 disabled citizens are stuck on waiting lists, leaving them without the care they need for months or even years.” / 0 ✓
# Test: 35000  35% (31m 17s) average_accuracy=0.4920 average_loss=0.9475 The claim that 97 percent of scientists believe humans are causing climate change has been debunked by the "head" of the United Nations Intergovernmental Panel on Climate Change. "That number was pulled out of thin air." / 0 ✓
# Train: 36000  36% (32m 11s) average_accuracy=0.4640 average_loss=0.9883 “On average, middle class families earning less than $86,000 would see a tax increase under the Republican 'tax reform' plan.” / 0 ✓
# Test: 36000  36% (32m 11s) average_accuracy=0.4930 average_loss=0.9396 “When I decided to just do it, I said to myself, I said, you know, this Russia thing with Trump and Russia is a made-up story." / 0 ✗ (1)
# Train: 37000  37% (33m 4s) average_accuracy=0.4740 average_loss=0.9573  Claims Hillary Clinton "even handed over American uranium rights to the Russians."  / 1 ✗ (0)
# Test: 37000  37% (33m 4s) average_accuracy=0.4540 average_loss=0.9513 Says the Obama administration "sold perhaps the best located and finest embassy in London ... only to build a new one in an off location for 1.2 billion dollars." / 1 ✓
# Train: 38000  38% (33m 58s) average_accuracy=0.4680 average_loss=0.9716 Say "71 percent of doctors say Hillary's health concerns are 'serious' and 'could be disqualifying.' " / 0 ✓
# Test: 38000  38% (33m 58s) average_accuracy=0.4610 average_loss=0.9574 "Ashley Moody was a lifelong Democrat." ​ / 0 ✓
# Train: 39000  39% (34m 52s) average_accuracy=0.4270 average_loss=0.9719 Says Supreme Court rival Michael Screnock "is running with the Koch brothers support." / 0 ✗ (1)
# Test: 39000  39% (34m 52s) average_accuracy=0.4750 average_loss=0.9578 Insurance companies "have made a fortune with Obamacare." / 0 ✓
# Train: 40000  40% (35m 46s) average_accuracy=0.4870 average_loss=0.9814 Civil rights activist DeRay Mckesson made and quickly deleted a tweet in which he said he had "no problem" with a contemporaneous viral Facebook Live crime in Chicago.
#
#
#
#
# 						See Example(s)
#
#
#
#
# 									This screenshot has been circulating on Tumblr; it's currently at 735 notes. Some people are using it against BLM since Deray McKesson is one of the movement's leaders, but others are saying either the screenshot is fake or it's a fake account.
# 																			Collected via e-mail and Twitter, January 2017 / 0 ✓
# Test: 40000  40% (35m 46s) average_accuracy=0.4540 average_loss=0.9881 "The pastor McCain calls his 'spiritual guide,' Rod Parsley, believes America's founding mission is to destroy Islam, which he calls a 'false religion.' " / 0 ✗ (1)
# Train: 41000  41% (36m 39s) average_accuracy=0.4930 average_loss=0.9686 Says a "lawmaker seeks to defund Planned Parenthood for ‘cutting children into small pieces.’" / 0 ✗ (1)
# Test: 41000  41% (36m 39s) average_accuracy=0.4690 average_loss=0.9525 "2.4 million people in Wisconsin have pre-existing conditions" and Leah Vukmir supports letting insurance companies "deny coverage to people with pre-existing conditions." / 0 ✗ (1)
# Train: 42000  42% (37m 32s) average_accuracy=0.5060 average_loss=0.9636 "Colin Kaepernick immediately loses Nike endorsement after anti-white rant." / 0 ✓
# Test: 42000  42% (37m 32s) average_accuracy=0.4950 average_loss=0.9431 A woman seeking to bring her peacock along on a flight as an emotional support animal was denied permission to do so by United Airlines. / 0 ✗ (2)
# Train: 43000  43% (38m 24s) average_accuracy=0.4700 average_loss=0.9666 Scammers dupe victims into paying "security keeping fees" to receive courier parcels supposedly containing large checks or other valuables. / 0 ✓
# Test: 43000  43% (38m 24s) average_accuracy=0.4660 average_loss=0.9653 "At the end of 2016, there were 23 percent fewer federal prosecutions than in 2011, so (prosecutors) looked at this scourge (opioid deaths) and they let it go by." / 0 ✗ (1)
# Train: 44000  44% (39m 17s) average_accuracy=0.5000 average_loss=0.9600 "If you pass the so-called Dream Act, it will be the single biggest amnesty in the history of the United States, even bigger than the 1986 amnesty." / 0 ✗ (1)
# Test: 44000  44% (39m 17s) average_accuracy=0.4690 average_loss=0.9576 In the stimulus, "$15 million dollars  went to 'build a bigger, better airport' for the town of Ouzinkie, Alaska,  population 165." / 0 ✗ (2)
# Train: 45000  45% (40m 10s) average_accuracy=0.4740 average_loss=0.9766 Musician Neko Case's Vermont farmhouse was badly damaged in a fire in September 2017. / 0 ✗ (2)
# Test: 45000  45% (40m 10s) average_accuracy=0.4410 average_loss=0.9635 "Most of these mass shootings take place in (areas) where you're not allowed to have a concealed weapons permit." / 0 ✗ (1)
# Train: 46000  46% (41m 3s) average_accuracy=0.4730 average_loss=0.9690 Says Congressman Tom McClintock, R-Calif., "has authored three laws since he’s been in office; two renamed post offices." / 0 ✓
# Test: 46000  46% (41m 3s) average_accuracy=0.4750 average_loss=0.9521 "In 1984, the New York Times said Trump would be our BEST president." / 0 ✓
# Train: 47000  47% (41m 56s) average_accuracy=0.4830 average_loss=0.9795 The University of Wisconsin-Milwaukee has "2.8 students per faculty" member, "tied for second-lowest in its history since 1994." / 0 ✓
# Test: 47000  47% (41m 56s) average_accuracy=0.4670 average_loss=0.9569 "If you don't pay income taxes ... you'll have more money" under the Republican tax plan. / 0 ✓
# Train: 48000  48% (42m 49s) average_accuracy=0.4820 average_loss=0.9600  Implies former Ohio Gov. Ted Strickland called his own record on taxes and jobs “mixed and spotty.”  / 0 ✓
# Test: 48000  48% (42m 49s) average_accuracy=0.4690 average_loss=0.9585 Says President Barack Obama "has not condemned" shootings targeting police. / 0 ✓
# Train: 49000  49% (43m 42s) average_accuracy=0.4840 average_loss=0.9630 U.S. Sen. John McCain "was singlehandedly responsible for starting a fire on (the) USS Forrestal aircraft carrier." / 0 ✓
# Test: 49000  49% (43m 42s) average_accuracy=0.4830 average_loss=0.9434  “Sharia law now in full effect in one state after what judge gave Muslim rapist special permission to do.”  / 0 ✓
# Train: 50000  50% (44m 35s) average_accuracy=0.4420 average_loss=0.9588 "More than a million Wisconsinites have voted to raise their own property taxes because Republicans have failed to fully fund our public schools for the past eight years." / 0 ✗ (1)
# Test: 50000  50% (44m 35s) average_accuracy=0.4590 average_loss=0.9702 "Bill Gates Outlines 2018 Plan To Depopulate The Planet." / 0 ✓
# Train: 51000  51% (45m 28s) average_accuracy=0.4430 average_loss=0.9905  “My agency experts have told me that we’re going to get a 34 percent reduction in CO2 based on 2005 levels once the ACE regulation is fully implemented.”  / 0 ✓
# Test: 51000  51% (45m 28s) average_accuracy=0.4940 average_loss=0.9396 "A part-time Congress with half the pay would still make $38,000 a year more than the average American family." / 0 ✗ (1)
# Train: 52000  52% (46m 21s) average_accuracy=0.4780 average_loss=0.9652  Donald Trump Jr. said, "Let California burn. It’s what they voted for. Notice no fires in red states.”  / 0 ✓
# Test: 52000  52% (46m 21s) average_accuracy=0.4970 average_loss=0.9506 Says Pat Toomey visited Joe Sestak and other veterans in 2002 "and then came home and voted against every veterans appropriations bill." / 0 ✗ (1)
# Train: 53000  53% (47m 14s) average_accuracy=0.4400 average_loss=0.9583 The new Arizona immigration law "says that any police officer can stop anyone who appears to them to be reasonably suspicious of being an undocumented person." / 0 ✗ (1)
# Test: 53000  53% (47m 14s) average_accuracy=0.4410 average_loss=0.9694 "In fact, oil spills from tankers are far more common than the very rare leaks from rigs or pipelines." / 0 ✗ (1)
# Train: 54000  54% (48m 8s) average_accuracy=0.5130 average_loss=0.9715 Says he "voted to remove Common Core from our schools." / 0 ✗ (1)
# Test: 54000  54% (48m 8s) average_accuracy=0.4820 average_loss=0.9495 "Constituents now face reality that all their personal issues will be made public" under Clean Missouri. / 0 ✗ (1)
# Train: 55000  55% (49m 1s) average_accuracy=0.4960 average_loss=0.9571 Tornado carries mobile home 130 miles, family inside unharmed. / 0 ✓
# Test: 55000  55% (49m 1s) average_accuracy=0.4930 average_loss=0.9544 Due to a year-over-year decline in overall viewership during the second week of May 2018, CNN is on the verge of permanently closing its doors. / 0 ✓
# Train: 56000  56% (49m 54s) average_accuracy=0.4700 average_loss=0.9506 As state Commerce secretary, Mary Burke drafted, sponsored and promoted "budgets that raised taxes by billions, created high structural deficits and raided funds to finance huge spending hikes." / 0 ✗ (1)
# Test: 56000  56% (49m 54s) average_accuracy=0.4470 average_loss=0.9447 "You know, the border’s down 78 percent. Under past administrations, the border didn’t go down, it went up." / 0 ✓
# Train: 57000  56% (50m 47s) average_accuracy=0.4680 average_loss=0.9633 A photograph shows a giant blue whale spotted near Jennette's Pier in North Carolina. / 0 ✓
# Test: 57000  56% (50m 47s) average_accuracy=0.5030 average_loss=0.9356 Marco Rubio said the Orlando shooting was a clear signal that God wanted him to serve in the Senate.
#
#
#
#
# 						See Example(s)
#
#
#
#
# 									Wanted to know if this was true? http://politicalo.com/rubio-god-killed-gays-orlando-signal-needs-back-senate/
#
# Rubio: “God Killed Those Gays In Orlando To Signal He Needs Me Back In The Senate” - Newslo https://t.co/TfRgLowtTB
# — Shane Worth (@tatzanx) June 20, 2016
#
#
# This link is making the rounds on Facebook. http://politicops.com/rubio-god-killed-gays-orlando-signal-needs-back-senate/																			Collected via e-mail and Twitter, June 2016 / 0 ✓
# Train: 58000  57% (51m 41s) average_accuracy=0.5110 average_loss=0.9520 "Sen. Richard Blumenthal, who never fought in Vietnam when he said for years he had (major lie),now misrepresents what Judge Gorsuch told him?" / 0 ✓
# Test: 58000  57% (51m 41s) average_accuracy=0.4590 average_loss=0.9551 "Youth unemployment in minority communities is about 40 to 45 percent." / 0 ✗ (1)
# Train: 59000  59% (52m 34s) average_accuracy=0.4770 average_loss=0.9544 “Trudeau’s carbon tax will raise gas prices by 11 cents/litre.” / 0 ✗ (1)
# Test: 59000  59% (52m 34s) average_accuracy=0.4490 average_loss=0.9491 “The median pay for a McDonald’s worker was $7,000 in 2017. And that is the pay gap between the CEO that’s making 21.8 [million] to the 7,000 [dollars] that a worker who has put in 40 hours [a week] gets paid." / 0 ✗ (1)
# Train: 60000  60% (53m 27s) average_accuracy=0.4660 average_loss=0.9727 "...Secret documents reveal that Iran could obtain a nuclear weapon far sooner than we were told. And Tammy Duckworth voted ‘yes’ (on the Iran nuclear deal)." / 0 ✗ (1)
# Test: 60000  60% (53m 27s) average_accuracy=0.4500 average_loss=0.9703 A new, rare tick burrows under your skin and moves about undetected. / 0 ✓
# Train: 61000  61% (54m 21s) average_accuracy=0.4800 average_loss=0.9582 My office sends federal "money back every year." / 0 ✗ (2)
# Test: 61000  61% (54m 21s) average_accuracy=0.4760 average_loss=0.9834 Actress Catherine Bell correctly predicted the results of the 2002 Super Bowl prior to the start of the 2001 NFL season. / 0 ✓
# Train: 62000  62% (55m 14s) average_accuracy=0.4550 average_loss=0.9578 A new study reporting on the 2015 death of a Colorado infant claims the event was the world’s first documented pot overdose. / 0 ✓
# Test: 62000  62% (55m 14s) average_accuracy=0.4710 average_loss=0.9566 Claims made in a widely-shared 2018 meme about the personal and family history of Congressman Beto O'Rourke are accurate. / 0 ✗ (1)
# Train: 63000  63% (56m 7s) average_accuracy=0.4630 average_loss=0.9729 "It takes almost a year for a refugee to be processed in the United States." / 0 ✗ (1)
# Test: 63000  63% (56m 7s) average_accuracy=0.4690 average_loss=0.9599 "In year No. 1, 14 million Americans lose coverage," according to the CBO. / 0 ✗ (1)
# Train: 64000  64% (57m 0s) average_accuracy=0.4780 average_loss=0.9668 Says U.S. House candidate Carlos Curbelo "opposes the repeal of Obamacare." / 0 ✗ (1)
# Test: 64000  64% (57m 0s) average_accuracy=0.4610 average_loss=0.9877 Police opened fire on a store mannequin after it failed to follow their orders.
#
#
#
#
# 						See Example(s)
#
#
#
#
# 									In Scranton, PA there is a story that police shot a mannequin 67 times because it did not respond to [police requests. Is this true.																			Collected via e-mail, August 2016 / 0 ✓
# Train: 65000  65% (57m 53s) average_accuracy=0.4950 average_loss=0.9432 A provision of “Obamacare” health care legislation creates a 3.8% Medicare tax on real estate transactions. / 0 ✗ (1)
# Test: 65000  65% (57m 53s) average_accuracy=0.4860 average_loss=0.9463 A 0.05 standard for drunken driving means having a glass of wine at dinner could make a person drunk. / 0 ✗ (1)
# Train: 66000  66% (58m 45s) average_accuracy=0.4670 average_loss=0.9808 WikiLeaks documents revealed campaign head John Podesta unflatteringly described Hillary Clinton's personal hygiene and intellect. / 0 ✓
# Test: 66000  66% (58m 45s) average_accuracy=0.4850 average_loss=0.9655 Says Bernie Sanders is going to "tax you people at 90 percent." / 0 ✓
# Train: 67000  67% (59m 38s) average_accuracy=0.4560 average_loss=0.9776 A photograph shows Donald Trump's father posing with Chinese revolutionary Mao Zedong.
#
#
#
#
# 						See Example(s)
#
#
#
#
# 									Donald Trumps father in photo with Mao Zedong circa 1964.
#
# 																			Collected via Reddit, January 2016 / 0 ✓
# Test: 67000  67% (59m 38s) average_accuracy=0.4850 average_loss=0.9637 “A bill of [the] Verkhovna Rada that restricts the rights of observers at the elections of the President of Ukraine violates the international law.” / 0 ✓
# Train: 68000  68% (60m 31s) average_accuracy=0.4690 average_loss=0.9816 Says Hillary Clinton's "been very clear where she stands on trade." / 0 ✗ (1)
# Test: 68000  68% (60m 31s) average_accuracy=0.4380 average_loss=0.9661 "The port provides more than 297,000 jobs directly to the state of Georgia." / 0 ✗ (1)
# Train: 69000  69% (61m 23s) average_accuracy=0.4600 average_loss=0.9899 "Lyin’ Bryan Steil has not manufactured anything in his life. ... [He] worked to send Wisconsin jobs overseas.” / 0 ✗ (1)
# Test: 69000  69% (61m 23s) average_accuracy=0.4820 average_loss=0.9364 "Obama's Ten Point Plan to 'Change' The Second Amendment….Ban the manufacture, sale and possession of handguns." / 0 ✓
# Train: 70000  70% (62m 16s) average_accuracy=0.4760 average_loss=0.9993 "No other country has a constitutional right" like the Second Amendment. / 0 ✗ (1)
# Test: 70000  70% (62m 16s) average_accuracy=0.4720 average_loss=0.9416 "The majority of the people that are coming to Arizona and trespassing are now becoming drug mules." / 0 ✓
# Train: 71000  71% (63m 9s) average_accuracy=0.4930 average_loss=0.9661 "Each vegan spares more than 100 animals every year." / 0 ✗ (1)
# Test: 71000  71% (63m 9s) average_accuracy=0.4660 average_loss=0.9670 Austin school district "teachers are the lowest paid of any urban" Texas district and the "lowest paid of any surrounding school district." / 0 ✗ (1)
# Train: 72000  72% (64m 2s) average_accuracy=0.4740 average_loss=0.9662 "Today, 27 million people .. are enslaved." / 0 ✗ (1)
# Test: 72000  72% (64m 2s) average_accuracy=0.4580 average_loss=0.9533 Says Donald Trump "was a Democrat longer in the last decade than he was a Republican." / 0 ✗ (1)
# Train: 73000  73% (64m 54s) average_accuracy=0.4690 average_loss=0.9784 The Obama administration has “filed federal charges against George Zimmerman.” / 0 ✓
# Test: 73000  73% (64m 54s) average_accuracy=0.4650 average_loss=0.9812 The federal tax code includes "deductions for birds flying across America." / 0 ✗ (2)
# Train: 74000  74% (65m 47s) average_accuracy=0.4450 average_loss=0.9614 I “got the treaty cutting Russia’s nuclear arms” / 0 ✗ (1)
# Test: 74000  74% (65m 47s) average_accuracy=0.4710 average_loss=0.9284 Federal agents raided a mosque near Dearborn, MIchigan and arrested several ISIS combatants planning suicide attacks. / 0 ✓
# Train: 75000  75% (66m 39s) average_accuracy=0.4490 average_loss=0.9911 President Trump lifted sanctions against Russia as a "gift" to Putin. / 0 ✗ (1)
# Test: 75000  75% (66m 39s) average_accuracy=0.4680 average_loss=0.9502  "More than half of older workers have no retirement savings – zero."  / 0 ✓
# Train: 76000  76% (67m 32s) average_accuracy=0.4620 average_loss=0.9797 "Over the last 40 years, real wage growth has been flatlined because of the policies of the Federal Reserve ... It was all driven by the Federal Reserve." / 0 ✗ (1)
# Test: 76000  76% (67m 32s) average_accuracy=0.4660 average_loss=0.9758  "It’s time that a president stepped up" to address gun violence. "And I’m talking Democrat and Republican presidents. They have not stepped up."  / 0 ✓
# Train: 77000  77% (68m 25s) average_accuracy=0.5000 average_loss=0.9592 "Iowa's Republican caucus stopped mattering years ago. It in no way determines the party nominee." / 0 ✗ (1)
# Test: 77000  77% (68m 25s) average_accuracy=0.4800 average_loss=0.9566 The Trump Administration is seeking to monitor social media posts of disability recipients. / 0 ✗ (2)
# Train: 78000  78% (69m 17s) average_accuracy=0.4710 average_loss=0.9758 "I never considered myself a maverick." / 0 ✓
# Test: 78000  78% (69m 17s) average_accuracy=0.4460 average_loss=0.9731 Vermont had to "scrap" its single-payer health insurance program because it was "going bankrupt." / 0 ✓
# Train: 79000  79% (70m 9s) average_accuracy=0.4840 average_loss=0.9511 An image comparison shows Donald Trump and various politicians in similar poses to characters from the movie "Back to the Future." / 0 ✗ (2)
# Test: 79000  79% (70m 9s) average_accuracy=0.4630 average_loss=0.9737 “As many already said, certainly, this was the most transparent and clean election in the history of our country.” / 0 ✓
# Train: 80000  80% (71m 2s) average_accuracy=0.4640 average_loss=0.9490 'The Daily Stormer' called for a retaliatory 'troll storm' against Jews in Whitefish, Montana, whom they accused of causing economic hardship to the parents of white supremacist Richard Spencer.
#
#
#
#
# 						See Example(s)
#
#
#
#
# 									Is this true: "A white supremacist website has issued a call for online attacks against the Jewish community in the town of Whitefish, where white supremacist Richard Spencer’s mother lives."																			Collected via e-mail, December 2016 / 0 ✗ (2)
# Test: 80000  80% (71m 2s) average_accuracy=0.4570 average_loss=0.9453 Miller County Judge Roy John McNatt wrote a racist memo about black people. / 0 ✓
# Train: 81000  81% (71m 55s) average_accuracy=0.4660 average_loss=0.9705 Michael Brown’s mother posted comments on social media celebrating the shooting of two Ferguson police officers. / 0 ✓
# Test: 81000  81% (71m 55s) average_accuracy=0.4730 average_loss=0.9444 "The overwhelming majority of America’s elite universities, they no longer require history majors to take a single course in American history." / 0 ✗ (1)
# Train: 82000  82% (72m 48s) average_accuracy=0.5060 average_loss=0.9516 Science is "very certain" that the measles vaccine doesn't cause autism. / 0 ✗ (2)
# Test: 82000  82% (72m 48s) average_accuracy=0.4790 average_loss=0.9617 Former President Richard Nixon sent a letter to Trump predicting he would be a successful politician whenever he decided to run for office. / 0 ✗ (2)
# Train: 83000  83% (73m 41s) average_accuracy=0.4960 average_loss=0.9363  "We don't understand why the Democrats are so wholeheartedly against [President Trump's border wall]. They voted for it in 2006."  / 0 ✓
# Test: 83000  83% (73m 41s) average_accuracy=0.4860 average_loss=0.9385 Jill Stein was arrested and charged with embezzling money raised for 2016 recount efforts in order to throw a "marijuana dinner party."
#
#
#
#
# 						See Example(s)
#
#
#
#
#
# https://t.co/phwPfiK6qE "We're all upset that Jill Stein is taking money from Hillary supporters and likely embezzling most of it."
# — ??ChristianPatriot (@SavetheUSNation) November 25, 2016
# 																			Collected via Twitter, November 2016 / 0 ✓
# Train: 84000  84% (74m 33s) average_accuracy=0.4980 average_loss=0.9498  A meme claims Ilhan Omar said that "all white men should be put in chains as slaves because they will never submit to Islam.”  / 0 ✓
# Test: 84000  84% (74m 33s) average_accuracy=0.4880 average_loss=0.9517 "He (Obama) chairs the subcommittee on Europe. ... He's held not one substantive hearing to do oversight." / 0 ✗ (2)
# Train: 85000  85% (75m 25s) average_accuracy=0.4810 average_loss=0.9431 Drivers should be on the lookout for face-slashing car thieves posing as individuals seeking directions.
#
#
#
#
# 						See Example(s)
#
#
#
#
# 									I've just seen a post on Facebook that immediately seemed untrue, and has already been shared by a lot of friends. This is the post...
#
# Just now, according to info received from a traffic police friend, there are already six car owners made police reports, if there is someone holding a name card and knock at your car window asking for direction. Please do not open your car window, as there is a cutter placed under the name card which is used for slashing victim's face and rob. Please be extra careful! Kindly convey this message! Please also send to those who are not driving too, for the sake of their friends who are driving!
#
# There was no location mentioned and a lot of bad grammar and spelling. There was also a photo used which looks like legit at 1st glance but there are other injuries on the guys neck that don't add up. Was hoping you could clear this one up for me as you are usually the first place I go to try and stop stupid posts from being shared!																			Collected via e-mail, January 2016 / 0 ✓
# Test: 85000  85% (75m 25s) average_accuracy=0.4800 average_loss=0.9622 The boots on Neil Armstrong's spacesuit don't match up with the "footprints" supposedly he left on the moon. / 0 ✓
# Train: 86000  86% (76m 17s) average_accuracy=0.4970 average_loss=0.9392 "The average time someone used to hold a share of stock back in the ’60s was eight years. Now, the average time is four months." / 0 ✗ (1)
# Test: 86000  86% (76m 17s) average_accuracy=0.4340 average_loss=0.9524 "Almost half of all vehicles stolen in Texas each year had keys left inside." / 0 ✓
# Train: 87000  87% (77m 9s) average_accuracy=0.4840 average_loss=0.9701 Ken Lanci is a lifelong Clevelander / 0 ✗ (1)
# Test: 87000  87% (77m 9s) average_accuracy=0.4640 average_loss=0.9412  "Actress Sandra Bullock: 'Donald Trump Is Doing Everything To Improve Our Nation, If You Don’t Like Him Just…'"  / 0 ✓
# Train: 88000  88% (78m 1s) average_accuracy=0.4640 average_loss=0.9739 "Pence: ‘Michelle Obama Is The Most Vulgar First Lady We’ve Ever Had’" / 0 ✓
# Test: 88000  88% (78m 1s) average_accuracy=0.4840 average_loss=0.9433 Crystal Griner, the officer who saved Steve Scalise, is a lesbian (and the congressman is anti-gay rights). / 0 ✗ (1)
# Train: 89000  89% (78m 53s) average_accuracy=0.4750 average_loss=0.9566 "Jefferson Davis statue to be replaced with Obama likeness." / 0 ✓
# Test: 89000  89% (78m 53s) average_accuracy=0.4600 average_loss=0.9666 Says in Texas "it's legal to shoot someone who's committing a ‘public nuisance’ under the cover of dark." / 0 ✓
# Train: 90000  90% (79m 45s) average_accuracy=0.4860 average_loss=0.9763 "[A]t his current rate, President Obama will have added more debt to the United State of America by the end of his first term than each of the previous 43 presidents -- combined!" / 0 ✗ (1)
# Test: 90000  90% (79m 45s) average_accuracy=0.4650 average_loss=0.9455 "New Jersey's citizens are working at the highest rate in three years." / 0 ✓
# Train: 91000  91% (80m 37s) average_accuracy=0.4750 average_loss=0.9725 "Chicago is experiencing right now the highest employment since 1950." / 0 ✓
# Test: 91000  91% (80m 37s) average_accuracy=0.4720 average_loss=0.9696 Cards from a "Parcel Delivery Service" notifying recipients of parcels awaiting delivery are part of a premium rate telephone scam. / 0 ✓
# Train: 92000  92% (81m 29s) average_accuracy=0.5070 average_loss=0.9384 In the first 45 days of 2017, 179 children went missing in the state of Indiana. / 0 ✗ (1)
# Test: 92000  92% (81m 29s) average_accuracy=0.4790 average_loss=0.9543 [The railway] has been in the books of our government for 30 years – it was not built. / 0 ✓
# Train: 93000  93% (82m 21s) average_accuracy=0.4590 average_loss=0.9538 "Washington politicians are paid over $200,000 an hour for speeches." / 0 ✗ (1)
# Test: 93000  93% (82m 21s) average_accuracy=0.4880 average_loss=0.9418 A phone number posted on a "consumer watchdog" site belongs to a college loan servicer.
#
#
#
#
# 						See Example(s)
#
#
#
#
# 																												Collected via e-mail, October 2016 / 0 ✓
# Train: 94000  94% (83m 13s) average_accuracy=0.4600 average_loss=0.9609 An image comparison shows Donald Trump and various politicians in similar poses to characters from the movie "Back to the Future." / 0 ✗ (2)
# Test: 94000  94% (83m 13s) average_accuracy=0.4430 average_loss=0.9825 "Sex roulette" is a new sexual trend in which one attendee at an orgy is HIV-positive.
#
#
#
#
# 						See Example(s)
#
#
#
#
# 									Can this be true??!!
#
# Sex roulette parties where one person is secretly HIV+ and nobody is allowed to use condoms are on the rise, warn doctors
#
# (Video) People In Spain Partake In ‘Sex Roulette’ Where Someone Secretly Has HIV https://t.co/oB0LRrT6D7 https://t.co/s0E0hMmso9
# — Funk Flex !!!!! (@funkflex) May 18, 2016
# Hi Snopes, I have seen stories floating around Facebook (as well as a couple of sensationalist British newspapers) claiming that 'sex roulette parties'involving a hiv positive participant are on the rise. Is there any truth to this or is it fake news being mistaken for the truth?																			Collected via e-mail and Twitter, May 2016 / 0 ✓
# Train: 95000  95% (84m 5s) average_accuracy=0.4790 average_loss=0.9679 El Paso was one of the U.S. most dangerous cities before a border fence was built there. / 0 ✓
# Test: 95000  95% (84m 5s) average_accuracy=0.4830 average_loss=0.9687 Says that in Texas, "you can be too gay to adopt" a foster child "who needs a loving home." / 0 ✗ (1)
# Train: 96000  96% (84m 57s) average_accuracy=0.4500 average_loss=0.9565 A sea monster of giant size was spotted near Antarctica.
#
#
#
#
# 						See Example(s)
#
#
#
#
# 									Giant sea creature Antarctica. Seems silly, but I'm curious what the picture actually is.
#
#
# 																			Collected via Email, June 2016 / 0 ✓
# Test: 96000  96% (84m 57s) average_accuracy=0.4730 average_loss=0.9459 Photograph shows Michelle Obama texting at the White House Correspondents' Dinner while other guests have their hands over their hearts. / 0 ✓
# Train: 97000  97% (85m 49s) average_accuracy=0.4560 average_loss=0.9677 An image shows President Donald Trump's report card from Fordham University. / 0 ✓
# Test: 97000  97% (85m 49s) average_accuracy=0.4530 average_loss=0.9422 Says Chuck Todd said the Roy Moore story "felt completely orchestrated." / 0 ✓
# Train: 98000  98% (86m 41s) average_accuracy=0.4800 average_loss=0.9729 A woman who rinsed her nasal passages using a neti pot filled with tap water contracted a fatal “brain-eating” amoeba infection. / 0 ✗ (2)
# Test: 98000  98% (86m 41s) average_accuracy=0.4510 average_loss=0.9755 The news media ignored the Young Black Leadership Summit event held in Washington, D.C., in October 2018. / 0 ✓
# Train: 99000  99% (87m 33s) average_accuracy=0.4770 average_loss=0.9678 Says Roy Moore said a "practicing Muslim should not be a member of Congress because of his faith." / 0 ✗ (2)
# Test: 99000  99% (87m 33s) average_accuracy=0.4670 average_loss=0.9572 "The largest enterprise in the world is the federal government of the United States of America" / 0 ✗ (1)
# Train: 100000  100% (88m 25s) average_accuracy=0.5080 average_loss=0.9492 "From 1972 until 2011, the number of EPA employees increased by 107 percent while the number of total federal personnel decreased by 15 percent." / 0 ✗ (2)
# Test: 100000  100% (88m 25s) average_accuracy=0.4680 average_loss=0.9547 An eclipse is going to cause an earthquake, which will in turn cause a devastating tsunami, on 22 July 2009. / 0 ✓

# %%
#Saving data
import json
with open('A5Q2A_all_train_accuracies_iii.json', 'w') as f:
    json.dump(all_train_accuracies_iii, f)
    
with open('A5Q2A_all_test_accuracies_iii.json', 'w') as f:
    json.dump(all_test_accuracies_iii, f)

# %%
#Loading Data
import json
with open('A5Q2A_all_train_accuracies_iii.json', 'r') as f:
   all_train_accuracies_iii = json.load(f)
    
with open('A5Q2A_all_test_accuracies_iii.json', 'r') as f:
   all_test_accuracies_iii = json.load(f)

# %%
plt.figure(figsize = (12,4))
plt.subplot(1,2,1)
plt.plot(all_train_accuracies, label = 'Train Accuracy (claim only)')
plt.plot(all_train_accuracies_ii, label = 'Train Accuracy_ii (claim & claimant)')
plt.plot(all_train_accuracies_iii, label = 'Train Accuracy_Iii (claim & claimant & sample sentences)')
plt.xlabel('No. of Iterations')
plt.ylabel('Train Accuracy')

plt.legend()

plt.subplot(1,2,2)
plt.plot(all_test_accuracies, label = 'Test Accuracy (claim only)')
plt.plot(all_test_accuracies_ii, label = 'Test Accuracy_ii (claim & claimant)')
plt.plot(all_test_accuracies_iii, label = 'Test Accuracy_iiI (claim & claimant & sample sentences)')
plt.xlabel('No. of Iteration')
plt.ylabel('Test Accuracy')
plt.legend()

# %% [markdown]
# ## Q2a) iii
# ### Changing the order of inputs (5 Sentences as the first input)

# %%
def train_iv(category_tensor, line_tensor, update=True):
    rnnOptimizer.zero_grad()
    classifierOptimizer.zero_grad()

    hidden = rnn_iv.initHidden()
    for i in range(line_tensor.size()[0]):
        hidden = rnn_iv(line_tensor[i], hidden)
    output = classifier_iv(hidden)

    loss = criterion(output, category_tensor)
    if update:
        loss.backward()
        rnnOptimizer.step()
        classifierOptimizer.step()
        
    return output, loss.item()

# %%
import time
import math

n_hidden = 128
n_categories = 3
rnn_iv = RNN(n_embedding_dims, n_hidden) #multiplied by 2 for claim+claimant
classifier_iv = Classifier(n_hidden, n_categories)

criterion = nn.NLLLoss()
learning_rate = 1e-4
rnnOptimizer = torch.optim.Adam(rnn_iv.parameters(), lr=learning_rate)
classifierOptimizer = torch.optim.Adam(classifier_iv.parameters(), lr=learning_rate)

n_iters = 100000
plot_every = 1000

# Keep track of losses for plotting
current_loss = 0
all_losses = []

def timeSince(since):
    now = time.time()
    s = now - since
    m = math.floor(s / 60)
    s -= m * 60
    return '%dm %ds' % (m, s)

start = time.time()

train_data = metadata[:10000]
test_data = metadata[10000:]
train_cumulative_loss = 0
test_cumulative_loss = 0
average_train_accuracy = 0
average_test_accuracy = 0
all_train_losses = []
all_train_accuracies_iv = []
all_test_losses = []
all_test_accuracies_iv = []
count = 0
for iter in range(1, n_iters + 1):
    train_claim_tensor, train_category_tensor, train_claim, train_category, train_id = sampleClaim(train_data)
    train_claimant_tensor, train_claimant = sampleClaimant(train_id)
    
    train_sentences_tensor, train_sentences = sampleSentences(train_id)
    
    train_line_tensor = torch.cat((train_sentences_tensor, train_claim_tensor, train_claimant_tensor), 0)
    
     
    train_output, train_loss = train_iv(train_category_tensor, train_line_tensor)    
    top_train_value, top_train_index = train_output.topk(1)
    train_guess_category = top_train_index[0].item()
    train_cumulative_loss += train_loss
    train_accuracy = 1 if train_guess_category == train_category else 0
    average_train_accuracy = (average_train_accuracy * count + train_accuracy) / (count+1)
    
    test_claim_tensor, test_category_tensor, test_claim, test_category, test_id = sampleClaim(test_data)
    test_claimant_tensor, test_claimant = sampleClaimant(test_id)
    test_sentences_tensor, test_sentences = sampleSentences(test_id)
    test_line_tensor = torch.cat(( test_sentences_tensor, test_claim_tensor, test_claimant_tensor), 0)
        
    test_output, test_loss = train_iv(test_category_tensor, test_line_tensor, update=False)
    
    top_test_value, top_test_index = test_output.topk(1)
    test_guess_category = top_test_index[0].item()
    test_cumulative_loss += test_loss
    test_accuracy = 1 if test_guess_category == test_category else 0
    average_test_accuracy = (average_test_accuracy * count + test_accuracy) / (count+1)
    count += 1

    # Add current loss avg to list of losses
    if iter % plot_every == 0:
        train_correct = '✓' if train_guess_category == train_category else '✗ (%s)' % train_category
        print('Train: %d  %d%% (%s) average_accuracy=%.4f average_loss=%.4f %s / %s %s' % (iter, iter / n_iters * 100, timeSince(start), average_train_accuracy, train_cumulative_loss / plot_every, train_claim, train_guess_category, train_correct))
        test_correct = '✓' if test_guess_category == test_category else '✗ (%s)' % test_category
        print('Test: %d  %d%% (%s) average_accuracy=%.4f average_loss=%.4f %s / %s %s' % (iter, iter / n_iters * 100, timeSince(start), average_test_accuracy, test_cumulative_loss / plot_every, test_claim, test_guess_category, test_correct))
        all_train_losses.append(train_cumulative_loss / plot_every)
        all_train_accuracies_iv.append(average_train_accuracy)
        all_test_losses.append(test_cumulative_loss / plot_every)
        all_test_accuracies_iv.append(average_test_accuracy)
        train_cumulative_loss = 0
        average_train_accuracy = 0
        test_cumulative_loss = 0
        average_test_accuracy = 0
        count = 0
        
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker

plt.figure()
plt.plot(all_train_accuracies_iv)
# Out:
# Train: 1000  1% (0m 38s) average_accuracy=0.5170 average_loss=0.9688 Message from Starbucks Chairman Howard Schultz extols the company’s contributions to Israel. / 0 ✓
# Test: 1000  1% (0m 38s) average_accuracy=0.4300 average_loss=0.9976 "All these cases have been branded ‘likes and reposts cases’ … We must draw the line here - we do have [criminal cases opened] for reposts, because reposts mean information is uploaded, but no criminal cases have been opened for ‘likes.’" / 1 ✓
# Train: 2000  2% (1m 14s) average_accuracy=0.5770 average_loss=0.9275 New carbon regulations will increase electric bills by "$17 billion every year" and "potentially put an average of 224,000 more people out of work every year." / 1 ✗ (0)
# Test: 2000  2% (1m 14s) average_accuracy=0.4780 average_loss=0.9589 "A miscarriage is considered an abortion." / 0 ✗ (1)
# Train: 3000  3% (1m 50s) average_accuracy=0.5740 average_loss=0.9138 Bernie Sanders was omitted from the Chicago primary ballot.
#
#
#
#
# 						See Example(s)
#
#
#
#
# 									A group called "The People for Bernie Sanders" have sent out a picture on Facebook of a "sample ballot" for the Illinois primary in Chicago's 13th Ward that does not list Sanders as a presidential candidate. The document supposedly was sent out by the Chicago Democratic Party. Is this true?
#
#
#
# Bernie Sanders OMITTED From Chicago Democratic Sample Ballot... More Shenanigans... - Democratic Underground https://t.co/itX76puhIW
# — Thom Hartmann (@Thom_Hartmann) March 6, 2016
# 																			Collected via e-mail, Facebook, and Twitter, March 2016 / 0 ✓
# Test: 3000  3% (1m 50s) average_accuracy=0.4710 average_loss=1.0022 Parents should be aware that a code for pedophiles inexplicably showed up on a children's toy at motorsport event Monster Jam.
#
#
#
#
# 						See Example(s)
#
#
#
#
# 									The local news outlet posted this story. It seems far-fetched. Is there any truth here about these symbols?
#
#
#
# Reports obscure symbol on child's toy is a secret way to know when a child is ready to be sold into sex trade by pedophiles.
#
# True or Fake?																			Collected via e-mail and Facebook, March 2016 / 1 ✓
# Train: 4000  4% (2m 26s) average_accuracy=0.6200 average_loss=0.8965  "Judge Kavanaugh's mother foreclosed on Christine Blasey Ford's parents' home"  / 0 ✓
# Test: 4000  4% (2m 26s) average_accuracy=0.4480 average_loss=1.0401 "Calling for the assassination of the president is a federal crime." / 0 ✗ (1)
# Train: 5000  5% (3m 1s) average_accuracy=0.6000 average_loss=0.9057 “Trump has made his plans for immigrants and their families clear.” / 1 ✓
# Test: 5000  5% (3m 1s) average_accuracy=0.4680 average_loss=1.0104  “Sharia law now in full effect in one state after what judge gave Muslim rapist special permission to do.”  / 0 ✓
# Train: 6000  6% (3m 36s) average_accuracy=0.5830 average_loss=0.8874 Donald Trump removed the terms "LGBT" and "climate change" from the White House web site. / 0 ✗ (1)
# Test: 6000  6% (3m 36s) average_accuracy=0.4590 average_loss=1.0222 Changing your Twitter profile's country setting to Germany will cause Nazi-related accounts to be blocked from view. / 1 ✓
# Train: 7000  7% (4m 12s) average_accuracy=0.6320 average_loss=0.8500 "Very little of (the defense) budget — less than 10 percent — actually goes into fighting ISIS and international terrorism." / 1 ✓
# Test: 7000  7% (4m 12s) average_accuracy=0.4580 average_loss=1.0070 "Part of the increase in the cost (of higher education) has been because state support has dropped. We now spend, under Governor Walker, more on corrections than we do on higher education." / 0 ✗ (1)
# Train: 8000  8% (4m 47s) average_accuracy=0.5980 average_loss=0.8729 Says the media distorted what happened with a baby at his rally. / 0 ✗ (2)
# Test: 8000  8% (4m 47s) average_accuracy=0.4610 average_loss=1.0157 Says Barack Obama found out about Russia "in August. Now, the election was in November. That's a lot of time. He did nothing about it." / 1 ✓
# Train: 9000  9% (5m 22s) average_accuracy=0.6110 average_loss=0.8747 Says as a Schedule 1 drug, marijuana carries a designation that means it "should not be researched" / 1 ✓
# Test: 9000  9% (5m 22s) average_accuracy=0.4640 average_loss=0.9980 President Trump filed for re-election early, which means non-profits can't criticize him without losing their tax-exempt status. / 0 ✓
# Train: 10000  10% (5m 58s) average_accuracy=0.6100 average_loss=0.8689 Dairy Queen is hosting 'Free Cone Day' on 20 March 2017.
#
#
#
#
# 						See Example(s)
#
#
#
#
# 									I've seen on social media that Dairy Queen will be giving away free ice cream cones on March 20th. Typical of viral posts, there's a link that says "click for details," but I didn't in case it's some sort of spam. The Dairy Queen website says nothing of this. Can you confirm or deny?
#
# 																			Collected via e-mail, March 2017 / 0 ✗ (1)
# Test: 10000  10% (5m 58s) average_accuracy=0.5130 average_loss=0.9868 There were more people on welfare than working in 2013. / 0 ✓
# Train: 11000  11% (6m 34s) average_accuracy=0.6190 average_loss=0.8896 "Florida led the nation in job creation" while Bush was governor. / 1 ✓
# Test: 11000  11% (6m 34s) average_accuracy=0.4950 average_loss=1.0117 Ed Gillespie "supports a personhood amendment." / 1 ✗ (0)
# Train: 12000  12% (7m 9s) average_accuracy=0.6020 average_loss=0.8865 The presidential practice of pardoning a live turkey before Thanksgiving originated with President Harry Truman in 1947. / 0 ✓
# Test: 12000  12% (7m 9s) average_accuracy=0.4770 average_loss=1.0070 President Donald Trump ordered that the name of Florida's "Obama Highway" be changed back to the "Old Dixie Highway." / 1 ✗ (0)
# Train: 13000  13% (7m 44s) average_accuracy=0.6420 average_loss=0.8340 This image shows the effects of drug-laced sweets on children / 0 ✓
# Test: 13000  13% (7m 44s) average_accuracy=0.4600 average_loss=1.0393 There is a point in the middle of the Pacific Ocean so far from land that it’s likely the closest humans to it are aboard the International Space Station. / 1 ✗ (2)
# Train: 14000  14% (8m 20s) average_accuracy=0.6290 average_loss=0.8500 The average fast food worker is 29, and most fast food workers "are on some form of public assistance." / 1 ✓
# Test: 14000  14% (8m 20s) average_accuracy=0.4840 average_loss=1.0170 There are more museums in the United States than McDonald’s and Starbucks outlets combined. / 0 ✗ (1)
# Train: 15000  15% (8m 56s) average_accuracy=0.6080 average_loss=0.8691 Congresswoman Alexandria Ocasio-Cortez has experienced two "sheriff evictions," two closed checking accounts, and a credit score of 430. / 1 ✗ (0)
# Test: 15000  15% (8m 56s) average_accuracy=0.4470 average_loss=1.0383 Says the American public "overwhelmingly opposed" Democratic-steered health care plan. / 1 ✓
# Train: 16000  16% (9m 31s) average_accuracy=0.6360 average_loss=0.8683 Leaked conversations revealed that President Trump planned on signing an executive order to abolish impeachment. / 0 ✓
# Test: 16000  16% (9m 31s) average_accuracy=0.4590 average_loss=1.0461 Miller County Judge Roy John McNatt wrote a racist memo about black people. / 1 ✗ (0)
# Train: 17000  17% (10m 7s) average_accuracy=0.6140 average_loss=0.8605 "To be clear, all my investments are in a trust that I don’t control." / 0 ✗ (1)
# Test: 17000  17% (10m 7s) average_accuracy=0.4880 average_loss=0.9893 “The media is fake. . . . The media is really the word — I think one of the greatest of all terms I’ve come up with is fake. I guess other people have used it perhaps over the years, but I’ve never noticed it.” / 0 ✗ (1)
# Train: 18000  18% (10m 43s) average_accuracy=0.6000 average_loss=0.8670 Mia Khalifa was diagnosed with human immunodeficiency virus, or HIV. / 0 ✓
# Test: 18000  18% (10m 43s) average_accuracy=0.4670 average_loss=1.0295 "We are the only industrialized nation that doesn't guarantee workers paid family leave." / 1 ✓
# Train: 19000  19% (11m 19s) average_accuracy=0.6430 average_loss=0.8061 The Republican tax bill "lets every American keep more of what they earned." / 1 ✗ (0)
# Test: 19000  19% (11m 19s) average_accuracy=0.4600 average_loss=1.0592 A total of 58 peer-reviewed papers published in the first half of 2017 conclude that global warming is a myth. / 0 ✓
# Train: 20000  20% (11m 54s) average_accuracy=0.5680 average_loss=0.9101  "U.S. Steel is opening up seven plants."  / 0 ✓
# Test: 20000  20% (11m 54s) average_accuracy=0.5010 average_loss=0.9836 “For six months we have been demanding, asking, and citing the legal grounds for getting consular access to the Russian citizen Yulia Skripal. In various forms, on various obviously far-fetched pretexts, we are not allowed to do this.” / 0 ✗ (1)
# Train: 21000  21% (12m 29s) average_accuracy=0.6240 average_loss=0.8409 “$110 billion in purchasing. It’s 500,000 jobs, American jobs. Everything’s made here.” / 0 ✓
# Test: 21000  21% (12m 29s) average_accuracy=0.5070 average_loss=0.9882 A three-cents-per-ounce soda tax in Philadelphia "would result in the loss of 2,000 family-sustaining Teamster Union jobs and countless other jobs in the beverage industry." / 1 ✗ (0)
# Train: 22000  22% (13m 4s) average_accuracy=0.6270 average_loss=0.8470 A recent international investigation resulted in the shutting down of an online pedophilia forum with some 70,000 members worldwide. / 0 ✗ (1)
# Test: 22000  22% (13m 4s) average_accuracy=0.5240 average_loss=1.0012 "80 percent of impeachments in Missouri have been against judges." / 1 ✓
# Train: 23000  23% (13m 40s) average_accuracy=0.6350 average_loss=0.8384  "We have created 5.3 million new jobs and importantly added 600,000 new manufacturing jobs."  / 1 ✗ (0)
# Test: 23000  23% (13m 40s) average_accuracy=0.4970 average_loss=1.0151 Says Adam Schiff used taxpayer money to "reach a sexual harassment settlement with a 19-year-old male." / 1 ✗ (0)
# Train: 24000  24% (14m 16s) average_accuracy=0.6390 average_loss=0.8338 A Syrian refugee receives close to $400,000 in benefits a year from the German government in order to take care of his wives and children. / 0 ✗ (1)
# Test: 24000  24% (14m 16s) average_accuracy=0.4930 average_loss=1.0009 "The primary financing mechanism of the Affordable Care Act is a tax on wealthy people." / 0 ✗ (1)
# Train: 25000  25% (14m 51s) average_accuracy=0.6260 average_loss=0.8581 “A Spanish fighter recently accidentally fired an air-to-air missile in Estonia. Thank God, it didn’t kill anyone. What if it fell on our soil rather than in Estonia? After all, it was very close." / 1 ✓
# Test: 25000  25% (14m 51s) average_accuracy=0.5060 average_loss=0.9957 Mel Gibson was the inspiration for the film "The Man Without a Face." / 0 ✓
# Train: 26000  26% (15m 26s) average_accuracy=0.6140 average_loss=0.8759 "We are giving almost $2 billion of taxpayer money to the junk food and fast food industries every year to make the (childhood obesity) epidemic worse." / 1 ✗ (0)
# Test: 26000  26% (15m 26s) average_accuracy=0.4880 average_loss=1.0052 Brenda Lee was forcibly removed from Air Force One by order of President Obama due to her pro-life views. / 0 ✓
# Train: 27000  27% (16m 2s) average_accuracy=0.6420 average_loss=0.8383 The United States "is not building the aircraft, the long-range bombers, the additional aircraft carriers, the nuclear submarines." / 1 ✗ (0)
# Test: 27000  27% (16m 2s) average_accuracy=0.4880 average_loss=1.0131 Says former North Carolina elections board chairman "tried to drag a cancer-stricken woman out of her hospital bed to testify at her son’s hearing on the first day of early voting over a bogus complaint that the board hadn’t even fully investigated." / 0 ✗ (1)
# Train: 28000  28% (16m 38s) average_accuracy=0.6090 average_loss=0.8553 An x-ray image shows a live cockroach in a patient's chest in Zimbabwe / 0 ✓
# Test: 28000  28% (16m 38s) average_accuracy=0.5120 average_loss=0.9847 "I was raised by a single mom, public school teacher on the South Side of Chicago.” / 0 ✗ (1)
# Train: 29000  28% (17m 13s) average_accuracy=0.6250 average_loss=0.8614 "More people are struck by lightning than commit in-person voter fraud" by impersonation. / 1 ✗ (2)
# Test: 29000  28% (17m 13s) average_accuracy=0.5070 average_loss=0.9902 An animated GIF shows a wind-blown stop sign hitting a weather reporter. / 0 ✓
# Train: 30000  30% (17m 48s) average_accuracy=0.6270 average_loss=0.8315 Woman gives birth to puppies in Western Cape / 0 ✓
# Test: 30000  30% (17m 48s) average_accuracy=0.5010 average_loss=1.0023 Visitors to Hollywood's Walk of Fame regularly defecate on Donald Trump's star.
#
#
#
#
# 						See Example(s)
#
#
#
#
#
# People keep pooping on it so Donald Trump's Walk of Fame Star May Be Removed https://t.co/im4v9xEUgy
# — Ear Goggles Podcast (@eargogglesnet) April 4, 2016
# 																			Collected via Twitter, April 2016 / 0 ✓
# Train: 31000  31% (18m 25s) average_accuracy=0.5860 average_loss=0.8989 Every time a particular message is shared, a company will donate money towards the medical care of a 14-year-old boy who was shot by his stepfather while he was defending his 2-year-old sister from rape. / 0 ✓
# Test: 31000  31% (18m 25s) average_accuracy=0.4940 average_loss=0.9992  A meme quotes Cory Booker as saying "We’re sick and tired of the Constitution sitting in the National Archives, manipulating everything we do."  / 0 ✓
# Train: 32000  32% (19m 0s) average_accuracy=0.5880 average_loss=0.8762 "Senator McCain voted against the Bush tax cuts. Now he's for them." / 1 ✗ (2)
# Test: 32000  32% (19m 0s) average_accuracy=0.4960 average_loss=1.0195 "In 2018, we endured a school shooting nearly once a week." / 1 ✓
# Train: 33000  33% (19m 35s) average_accuracy=0.6280 average_loss=0.8726 Fewer Democrats were on the Georgia general election ballot in 2012 than in more than 100 years. / 1 ✓
# Test: 33000  33% (19m 35s) average_accuracy=0.4610 average_loss=1.0514 "(Flint, Mich., is) paying three times more for poison water than I am paying in Burlington, Vt., for clean water." / 1 ✓
# Train: 34000  34% (20m 10s) average_accuracy=0.5890 average_loss=0.8994 A company is developing a lab-grown chicken nugget made from feathers. / 0 ✗ (1)
# Test: 34000  34% (20m 10s) average_accuracy=0.4870 average_loss=1.0123 Timberland is owned by the Ku Klux Klan, a situation lamented in a poem by Maya Angelou. / 1 ✗ (0)
# Train: 35000  35% (20m 45s) average_accuracy=0.6380 average_loss=0.8264 Women "own just 1 percent of the world’s land." / 0 ✓
# Test: 35000  35% (20m 45s) average_accuracy=0.4550 average_loss=1.0470 Sweden has the highest rate of rape among European countries. / 0 ✓
# Train: 36000  36% (21m 20s) average_accuracy=0.5930 average_loss=0.8584 Sleeping morgue employee ‘cremated by mistake’ / 0 ✓
# Test: 36000  36% (21m 20s) average_accuracy=0.5100 average_loss=0.9939 "Mark Kirk: Lied about going to war. Opposed middle class tax cuts. And said unemployment’s not that big an issue." / 1 ✓
# Train: 37000  37% (21m 54s) average_accuracy=0.6000 average_loss=0.8833 Barack Obama's network of small donors constitutes a "parallel public financing system." / 1 ✓
# Test: 37000  37% (21m 54s) average_accuracy=0.5080 average_loss=0.9859 “Director Comey said my answers were truthful, and what I’ve said is consistent with what I have told the American people." / 0 ✓
# Train: 38000  38% (22m 29s) average_accuracy=0.6130 average_loss=0.8447 Use of the Facebook Messenger app requires user acceptance of many privacy-violating conditions.
#
#
#
#
# 						See Example(s)
#
#
#
#
# 									There are many articles circulating about all the privacy incursions of Facebooks new messenger app but I don't think they could all
# be true.																			Collected via Email, August 2014 / 0 ✗ (1)
# Test: 38000  38% (22m 29s) average_accuracy=0.4920 average_loss=0.9802 "The majority of the people that are coming to Arizona and trespassing are now becoming drug mules." / 0 ✓
# Train: 39000  39% (23m 5s) average_accuracy=0.6150 average_loss=0.8709 A new California law bars employers from inquiring about criminal backgrounds. / 0 ✗ (1)
# Test: 39000  39% (23m 5s) average_accuracy=0.4560 average_loss=1.0582 NASA admitted that they were in contact with aliens but failed to officially disclose that information, presuming everyone already knew about it.
#
#
#
#
# 						See Example(s)
#
#
#
#
# 									A few articles have claimed that a NASA spokesperson admitted that there have been aliens visiting the Earth for thousands of years, and NASA assumed that everybody already knew that aliens were real because of all of the science fiction about them.																			Collected via e-mail, September 2016 / 1 ✗ (0)
# Train: 40000  40% (23m 40s) average_accuracy=0.5990 average_loss=0.8561 "There’s more union jobs growing in Texas, which is a right-to-work state, than in Illinois, and factory workers make more money in Texas than they do in Illinois." / 1 ✓
# Test: 40000  40% (23m 40s) average_accuracy=0.4900 average_loss=0.9934 "Hate crimes against American Muslims and mosques have tripled after Paris and San Bernardino." / 1 ✓
# Train: 41000  41% (24m 15s) average_accuracy=0.6140 average_loss=0.8597 Polls show that Americans "overwhelmingly" support "expanding background checks." / 1 ✗ (2)
# Test: 41000  41% (24m 15s) average_accuracy=0.4950 average_loss=0.9787  Said “more than 30 million” small businesses get “a 40 percent cut" in their tax rate.  / 1 ✗ (0)
# Train: 42000  42% (24m 50s) average_accuracy=0.6220 average_loss=0.8619 The streets in some parts of Dhaka, Bangladesh were awash in bloody water after mass animal sacrifices took place on the Islamic holiday Eid al-Adha.
#
#
#
#
# 						See Example(s)
#
#
#
#
# 									BANGLADESH: Rivers of Blood fill streets as Muslims celebrate Eid-al-Adha by cutting the throats of fully-conscious terrified animals, letting them bleed to death in agony. Pouring rains coupled with this massive and barbaric animal sacrifice ritual on the streets of Dhaka have flooded many areas of the capital, creating a gory and horrific scene of red rivers of blood and waste.																			Collected via e-mail, September 2016 / 0 ✗ (2)
# Test: 42000  42% (24m 50s) average_accuracy=0.4960 average_loss=0.9964 A video shows a bridesmaid making an athletic move to catch a bouquet of flowers. / 0 ✓
# Train: 43000  43% (25m 25s) average_accuracy=0.6290 average_loss=0.8371 Chlorpyrifos, an insecticide with alleged origins in Nazi Germany, was set to be banned by the EPA over health and environmental safety concerns; but President Trump reversed this decision after Dow Chemicals, a manufacturer of the chemical, donated one million dollars to his inauguration fund. / 0 ✗ (1)
# Test: 43000  43% (25m 25s) average_accuracy=0.5270 average_loss=0.9906 “Our desire is to create favorable conditions for the work of the OSCE mission, full cooperation. I would like the whole world to know what is happening in the DPR.” / 1 ✗ (0)
# Train: 44000  44% (26m 0s) average_accuracy=0.6160 average_loss=0.8653 "Last year, I stopped an Obamacare bailout and saved taxpayers $2.5 billion." / 1 ✓
# Test: 44000  44% (26m 0s) average_accuracy=0.4950 average_loss=1.0250 Texas "children may have a teacher who never spent one minute practicing teaching." / 2 ✓
# Train: 45000  45% (26m 35s) average_accuracy=0.5980 average_loss=0.8887 The increase in the current state budget was greater than the inflation rate and the rate of population growth in Georgia. / 1 ✓
# Test: 45000  45% (26m 35s) average_accuracy=0.4920 average_loss=1.0155 "Of the 25 wealthiest nations, we're the only one that doesn't provide basic health coverage." / 1 ✗ (2)
# Train: 46000  46% (27m 10s) average_accuracy=0.6100 average_loss=0.8652 "The U.S. State Department has ordered 160,000 Hazmat suits for Ebola, prompting concerns that the federal government is anticipating the rapid spread" of the virus. / 0 ✗ (1)
# Test: 46000  46% (27m 10s) average_accuracy=0.5380 average_loss=0.9784 The United States has "the most number of deductions available to corporations" for the corporate income tax. / 1 ✗ (0)
# Train: 47000  47% (27m 46s) average_accuracy=0.6150 average_loss=0.8611 Ann Scott, the wife of Florida's governor, owns a Zika mosquito spraying business.
#
#
#
#
# 						See Example(s)
#
#
#
#
# 									If you’ve been trying to connect the Zika Virus mayhem dots, well, this latest news certainly might help you along. Florida Gov. Rick Scott is apparently reaping financial interest from the Zika mosquito business. Scott’s wife, Florida First Lady Ann Scott, has a multi-million dollar investment into a mosquito control service.
#
# The company is Mosquito Control Services LLC of Metairie, LA. According to its website, MCS “is a fully-certified team of mosquito control experts — licensed throughout the Gulf Coast, including Louisiana, Georgia, Mississippi, Alabama and Florida.”																			Collected via the Internet, August 2016 / 0 ✗ (1)
# Test: 47000  47% (27m 46s) average_accuracy=0.5020 average_loss=0.9999 Queen Elizabeth is so upset at public comments made by royal bride-to-be Meghan Markle that she has suspended or threatened to suspend Prince Harry's wedding. / 0 ✓
# Train: 48000  48% (28m 22s) average_accuracy=0.6290 average_loss=0.8372 Venomous 'two-striped telamonia' spiders are lurking beneath toilet seats in public restrooms. / 0 ✓
# Test: 48000  48% (28m 22s) average_accuracy=0.4960 average_loss=1.0316 "The American people don't want us to raise taxes." / 0 ✗ (1)
# Train: 49000  49% (28m 57s) average_accuracy=0.6280 average_loss=0.8512 "Thanks to President Trump and Republican leadership, the number of people collecting food stamps has declined by more than two million." / 1 ✓
# Test: 49000  49% (28m 57s) average_accuracy=0.4690 average_loss=1.0235 Says Ted Cruz said, "When gays stayed hidden we had no mass shootings; we had no public nudity. Society was polite. Now anything and everything goes and I blame them." / 0 ✓
# Train: 50000  50% (29m 33s) average_accuracy=0.6120 average_loss=0.8661 A photograph shows actor Bill Murray and a crying baby. / 0 ✗ (2)
# Test: 50000  50% (29m 33s) average_accuracy=0.5030 average_loss=1.0224 Says a Senate resolution would restore $140 in monthly general assistance payments and prevent people from committing crime. / 1 ✗ (0)
# Train: 51000  51% (30m 8s) average_accuracy=0.6090 average_loss=0.8589 Democrats on the House Ways and Means Committee weren’t "even entitled to bring an expert witness on any aspect of the tax code that affects 100 percent of our economy." / 1 ✓
# Test: 51000  51% (30m 8s) average_accuracy=0.4720 average_loss=1.0193 There are more museums in the United States than McDonald’s and Starbucks outlets combined. / 0 ✗ (1)
# Train: 52000  52% (30m 44s) average_accuracy=0.6210 average_loss=0.8702 A Harvard study proved that “unvaccinated children pose no risk” to other kids. / 0 ✗ (1)
# Test: 52000  52% (30m 44s) average_accuracy=0.5190 average_loss=1.0405 "Every one of the financial bad management practices that I inherited, every one of them, have either been eliminated or cut significantly." / 1 ✓
# Train: 53000  53% (31m 20s) average_accuracy=0.5800 average_loss=0.8864 "Over the last six years, the state of Illinois spent about $320 million on illegal immigrants." / 1 ✗ (2)
# Test: 53000  53% (31m 20s) average_accuracy=0.5300 average_loss=0.9830 A judge told an atheist plaintiff who challenged religious holidays that atheists already have their own holiday: April 1. / 1 ✗ (0)
# Train: 54000  54% (31m 56s) average_accuracy=0.6390 average_loss=0.8213 "In a period of roughly 72 hours, a small group of angry black students managed to force the resignation of the two highest ranking officials at that school." / 1 ✓
# Test: 54000  54% (31m 56s) average_accuracy=0.4880 average_loss=1.0442 "While southern Illinois families struggled," Mike Bost "voted to raise his own pay." / 1 ✓
# Train: 55000  55% (32m 31s) average_accuracy=0.6150 average_loss=0.8722 Says Donald Trump thinks "a grown man pretending to be a woman (should) be allowed to use the women's restroom." / 1 ✓
# Test: 55000  55% (32m 31s) average_accuracy=0.4790 average_loss=1.0125 President Trump has signed visa-free travel policies for residents of a number of different countries. / 0 ✓
# Train: 56000  56% (33m 6s) average_accuracy=0.6270 average_loss=0.8385 Mariah Carey recorded a cover of Dead Kennedys song "Nazi Punks Fuck Off," with proceeds going to support Antifa. / 0 ✓
# Test: 56000  56% (33m 6s) average_accuracy=0.4920 average_loss=1.0365 “It is unbelievable the Trump budget calls for ... $850 billion cut in Medicare.” / 0 ✗ (1)
# Train: 57000  56% (33m 42s) average_accuracy=0.6160 average_loss=0.8551 "I’ll be the only economist in the (U.S.) House." / 1 ✗ (2)
# Test: 57000  56% (33m 42s) average_accuracy=0.4970 average_loss=0.9965 Author Ingersoll Lockwood wrote the books "Baron Trump's Marvelous Underground Journey" and "1900: or, The Last President"  in the 1890s. / 0 ✗ (1)
# Train: 58000  57% (34m 17s) average_accuracy=0.6200 average_loss=0.8542 “[A]ll the targets were located out of settlements and in a safe distance from strongholds of the US SOF and Syrian Democratic Forces in the ISIS-controlled territories.” / 0 ✓
# Test: 58000  57% (34m 17s) average_accuracy=0.4840 average_loss=1.0029 There is debate among constitutional scholars about whether the First Amendment will continue to protect faith leaders from being forced to perform marriages against their religious beliefs. / 0 ✗ (1)
# Train: 59000  59% (34m 53s) average_accuracy=0.6070 average_loss=0.8602 Police discovered a drug lab in the back room of a Walmart in Decatur, Alabama. / 0 ✓
# Test: 59000  59% (34m 53s) average_accuracy=0.5030 average_loss=1.0148 "While we were in harm’s way in uniform, Kyrsten Sinema was protesting us in a pink tutu and denigrating our service." / 1 ✓
# Train: 60000  60% (35m 28s) average_accuracy=0.6270 average_loss=0.8454 The FCC raided CNN's head offices on the grounds that the TV news network was "violating press guidelines." / 0 ✓
# Test: 60000  60% (35m 28s) average_accuracy=0.5190 average_loss=0.9940 eSwatini passed a law to let its king marry ‘14-year-old virgins’ / 0 ✓
# Train: 61000  61% (36m 4s) average_accuracy=0.6180 average_loss=0.8418 From 2014 to 2015, Austin’s "murder rate is up a whopping 83 percent." / 1 ✓
# Test: 61000  61% (36m 4s) average_accuracy=0.4840 average_loss=1.0363 A new federal program provides subsidized "Obama phones" with 70 free minutes of cell phone service every month. / 1 ✓
# Train: 62000  62% (36m 39s) average_accuracy=0.6240 average_loss=0.8491 "...at least 6 million workers who are currently being paid below the national minimum wage level of R20 an hour.” / 1 ✗ (0)
# Test: 62000  62% (36m 39s) average_accuracy=0.4990 average_loss=1.0348  “Roy Moore’s accuser arrested and charged with falsification.”  / 0 ✓
# Train: 63000  63% (37m 14s) average_accuracy=0.6000 average_loss=0.8512 Chelsea Clinton wears an upside-down (inverted) cross that is symbolic of Satan worship. / 0 ✓
# Test: 63000  63% (37m 14s) average_accuracy=0.4950 average_loss=1.0011 A U.S. surgeon who exposed “Clinton Foundation corruption in Haiti” was found dead in his home under suspicious circumstances. / 0 ✓
# Train: 64000  64% (37m 50s) average_accuracy=0.6210 average_loss=0.8504 Says Mark Pocan’s proposal to eliminate the U.S. Immigration and Customs Enforcement (ICE) would "eliminate border enforcement." / 0 ✓
# Test: 64000  64% (37m 50s) average_accuracy=0.5110 average_loss=0.9988 "More than 66% of ALL births in California are to illegals on Medi-Cal." / 0 ✓
# Train: 65000  65% (38m 26s) average_accuracy=0.6220 average_loss=0.8596 In the U.S. Senate, Barack Obama "has not reached across party lines to get anything significant done." / 1 ✗ (0)
# Test: 65000  65% (38m 26s) average_accuracy=0.4850 average_loss=1.0106 "The budget submitted by Obama will add more to the debt than the outstanding debt of the previous 43 presidents combined." / 0 ✗ (2)
# Train: 66000  66% (39m 1s) average_accuracy=0.6090 average_loss=0.8512 Says Hillary Clinton called the Trans-Pacific Partnership "the gold standard. You called it the gold standard of trade deals. You said it’s the finest deal you’ve ever seen." / 0 ✗ (1)
# Test: 66000  66% (39m 1s) average_accuracy=0.4950 average_loss=1.0416 It is also sad to note that water sold in informal settlements is the most expensive water in Nairobi County. / 0 ✗ (2)
# Train: 67000  67% (39m 37s) average_accuracy=0.6020 average_loss=0.8638 Alison Alter "got an F in attendance in 2016" as an Austin parks board member "and was removed by a unanimous vote of the Austin City Council." / 1 ✗ (0)
# Test: 67000  67% (39m 37s) average_accuracy=0.5150 average_loss=1.0069 "95 percent of the world’s customers are … beyond our shores." / 1 ✓
# Train: 68000  68% (40m 12s) average_accuracy=0.6300 average_loss=0.8323 "President Trump’s wall costs less than the ObamaCare website." / 0 ✓
# Test: 68000  68% (40m 12s) average_accuracy=0.5080 average_loss=1.0133 "The average person only pays about $1,800 in state taxes — which is the lowest of all 50 states." / 1 ✓
# Train: 69000  69% (40m 48s) average_accuracy=0.6170 average_loss=0.8421 The Orange County, Florida, school board "voted to make it impossible for a student to receive a grade below 50." / 1 ✓
# Test: 69000  69% (40m 48s) average_accuracy=0.4660 average_loss=1.0710 Designer Tommy Hilfiger stated that blacks and Asians shouldn't wear his clothes. / 0 ✓
# Train: 70000  70% (41m 23s) average_accuracy=0.5940 average_loss=0.8556 “Detain, question, and return – it’s that simple.” / 1 ✓
# Test: 70000  70% (41m 23s) average_accuracy=0.4900 average_loss=0.9925 Says Beto O’Rourke's campaign "told Texas VFW to remove their American flag" because O'Rourke has "an aversion to the American flag and symbols of patriotism." / 0 ✗ (1)
# Train: 71000  71% (41m 58s) average_accuracy=0.6260 average_loss=0.8235 Unlike Benghazi, there were no investigations of the 1983 Beirut barracks bombing, none about key aspects of the 9/11 attacks and the Iraq War, and none about embassy attacks under George W. Bush. / 0 ✗ (1)
# Test: 71000  71% (41m 58s) average_accuracy=0.5070 average_loss=0.9926 "The Germans, the French, countries that opposed us in the (Iraq) war, all believed (Saddam Hussein) had weapons of mass destruction." / 0 ✗ (1)
# Train: 72000  72% (42m 33s) average_accuracy=0.6240 average_loss=0.8442 Thieves can steal cars by using VINs to obtain duplicate keys through auto dealerships. / 1 ✓
# Test: 72000  72% (42m 33s) average_accuracy=0.5090 average_loss=1.0440 Photographs and videos show pipe-bombing suspect Cesar Sayoc in attendance at Donald Trump rallies. / 0 ✗ (2)
# Train: 73000  73% (43m 8s) average_accuracy=0.6260 average_loss=0.8432 David Hogg stated that he believes that the enforced use of clear backpacks in school constitutes a violation of students' First Amendment rights, but he favors the abolition of the Second Amendment. / 0 ✗ (1)
# Test: 73000  73% (43m 8s) average_accuracy=0.4850 average_loss=1.0303 Says Michael Screnock "let a child predator walk without time and let a rapist who preyed on an underage girl go free after only an eight-month sentence." / 1 ✓
# Train: 74000  74% (43m 42s) average_accuracy=0.6190 average_loss=0.8385 Says Bernie Sanders marched with Fidel Castro and Che Guevara in Cuba. / 0 ✓
# Test: 74000  74% (43m 42s) average_accuracy=0.4800 average_loss=1.0455 A "Do Not Adopt a Pitbull" ad will be airing during Super Bowl LII in February 2018. / 0 ✓
# Train: 75000  75% (44m 17s) average_accuracy=0.6230 average_loss=0.8433 The American Psychiatric Association condones pedophilia and says it is normal to be sexually attracted to children. / 0 ✓
# Test: 75000  75% (44m 17s) average_accuracy=0.4860 average_loss=1.0310 Football player Michael Vick broke both his legs in an automobile accident. / 0 ✓
# Train: 76000  76% (44m 52s) average_accuracy=0.6230 average_loss=0.8356 "The waiting list for Pre-K is over in the House budget." / 1 ✗ (2)
# Test: 76000  76% (44m 52s) average_accuracy=0.5160 average_loss=0.9782 Pittsburgh Steelers coach Mike Tomlin "ripped" one of his players, Alejandro Villanueva, for standing near the sidelines during the playing of the national anthem before an NFL game. / 0 ✓
# Train: 77000  77% (45m 28s) average_accuracy=0.6260 average_loss=0.8482 Barack Obama will "raise Social Security taxes." / 1 ✓
# Test: 77000  77% (45m 28s) average_accuracy=0.4920 average_loss=1.0239 "Neighborhoods have become more violent" under President Barack Obama's "watch." / 0 ✗ (1)
# Train: 78000  78% (46m 3s) average_accuracy=0.6120 average_loss=0.8530 Tornado carries mobile home 130 miles, family inside unharmed. / 0 ✓
# Test: 78000  78% (46m 3s) average_accuracy=0.5240 average_loss=1.0043 Says Obama wants to redesign the American flag "to better offer our enemies hope and love." / 0 ✓
# Train: 79000  79% (46m 38s) average_accuracy=0.6110 average_loss=0.8680 Speaking at the University of California Berkeley in May 2018, Hillary Clinton warned about "Trump deplorables," calling them "the biggest threats to America." / 0 ✓
# Test: 79000  79% (46m 38s) average_accuracy=0.4800 average_loss=1.0247 The Southern Baptist Convention voted 13 years ago "that women were inferior and had to be subservient to their husbands." / 2 ✗ (1)
# Train: 80000  80% (47m 13s) average_accuracy=0.6220 average_loss=0.8399 Says Thom Tillis "has cut $500 million from public education." / 1 ✓
# Test: 80000  80% (47m 13s) average_accuracy=0.5310 average_loss=0.9775 A man got into five separate auto accidents shortly after receiving a woman's brain in a transplant. / 0 ✓
# Train: 81000  81% (47m 49s) average_accuracy=0.6080 average_loss=0.8463 The characteristics of stereotypical millennial liberals make them less competitive, because they are in discord with the natural world. / 0 ✓
# Test: 81000  81% (47m 49s) average_accuracy=0.4880 average_loss=1.0235 The U.S. government funded Mitch McConnell's care and rehabilitation when he had polio as a child. / 0 ✓
# Train: 82000  82% (48m 24s) average_accuracy=0.6250 average_loss=0.8358 Doctors concluded that a large spider made its way into a woman's uterus after it got stuck inside her tampon. / 0 ✓
# Test: 82000  82% (48m 24s) average_accuracy=0.4950 average_loss=1.0066 "Concerned Veterans for America is a political advocacy group funded by the Koch Brothers ... to push dangerous policies that would privatize the VA." / 0 ✗ (1)
# Train: 83000  83% (49m 0s) average_accuracy=0.6530 average_loss=0.8031 "We've cut taxes 50 times and look what has happened to our revenues. They've grown." / 1 ✓
# Test: 83000  83% (49m 0s) average_accuracy=0.5110 average_loss=1.0240 There have been 74 "school shootings in America since Sandy Hook." / 0 ✗ (1)
# Train: 84000  84% (49m 36s) average_accuracy=0.6160 average_loss=0.8394 Dr. Bandy Lee, who has warned the United States that Donald Trump is dangerously impaired, lacks a medical license. / 0 ✓
# Test: 84000  84% (49m 36s) average_accuracy=0.4960 average_loss=1.0109 An official report has confirmed that fidget spinners contain a deadly amount of lead. / 1 ✓
# Train: 85000  85% (50m 11s) average_accuracy=0.6110 average_loss=0.8350 Says Hillary Clinton’s energy agenda "will cost the U.S. economy over $5 trillion" / 1 ✗ (0)
# Test: 85000  85% (50m 11s) average_accuracy=0.4840 average_loss=1.0264 Portland Bureau of Transportation "barely break(s) even" ticketing motorists. / 0 ✗ (1)
# Train: 86000  86% (50m 46s) average_accuracy=0.5990 average_loss=0.8568 "We will be the first party to elect a bald guy to governor." / 1 ✗ (0)
# Test: 86000  86% (50m 46s) average_accuracy=0.4930 average_loss=1.0150 A leaked e-mail revealed Clinton aide Cheryl Mills calling the men who died in Benghazi "idiot soldiers" and saying she was glad they were tortured.
#
#
#
#
# 						See Example(s)
#
#
#
#
#
# @justinpetac pic.twitter.com/5a041YJlFO
# — IRREDEEMABLE BELINDA (@ispytexas) October 23, 2016
#
#
# 07-26-2012. From: Mills Cheryl D UNCLASSIFIED hdr22@clintonemail.com Message: The idiot soldiers deserved to die, Hope they were tortured. — #Womenwhovotetrump (@reagangalpal) October 24, 2016
#
#
#
# So has anyone else read this? What tortured idiot Soldiers is Cheryl Mills writing about? #VeteransForTrump https://t.co/FBLZz5KhLz
# — Deplorable Kathy (@2kschumacher) October 24, 2016
# 																			Collected via e-mail and Twitter, October 2016 / 1 ✗ (0)
# Train: 87000  87% (51m 22s) average_accuracy=0.6150 average_loss=0.8350 Author J.K. Rowling was the first person to fall off of the Forbes billionaires list due to donating so much money to charity.
#
#
#
#
# 						See Example(s)
#
#
#
#
# 																												Collected via Facebook, August 2016 / 0 ✗ (1)
# Test: 87000  87% (51m 22s) average_accuracy=0.4850 average_loss=1.0369 "We now have several hundred teachers that are over 100 years old and what I've read recently is that a baby born today, their age expectancy is 110, at least." / 0 ✗ (1)
# Train: 88000  88% (51m 58s) average_accuracy=0.6190 average_loss=0.8517 Hillary Clinton said children should be raised and trained by the state, and parents should have only a secondary role. / 0 ✓
# Test: 88000  88% (51m 58s) average_accuracy=0.5080 average_loss=1.0148 Says President Barack Obama's acceptance of an "Islamic order and gold medal" was "unconstitutional." / 0 ✗ (1)
# Train: 89000  89% (52m 33s) average_accuracy=0.6100 average_loss=0.8445 "John McCain has been on every side of immigration" -- specifically, the DREAM Act. / 0 ✗ (1)
# Test: 89000  89% (52m 33s) average_accuracy=0.5160 average_loss=1.0044 Brenda Lee was forcibly removed from Air Force One by order of President Obama due to her pro-life views. / 0 ✓
# Train: 90000  90% (53m 8s) average_accuracy=0.5960 average_loss=0.8488 "Almost half a million people are still eligible (for DACA), particularly in the Asian-American and Pacific Islander community." / 1 ✗ (2)
# Test: 90000  90% (53m 8s) average_accuracy=0.4850 average_loss=1.0342 A video shows Queen Elizabeth riding with Meghan Markle's rescued beagle Guy to the royal wedding. / 2 ✗ (0)
# Train: 91000  91% (53m 44s) average_accuracy=0.6350 average_loss=0.8391 Says Hillary Clinton "makes more per hour at a speaking gig than the average CEO does in a year." / 1 ✓
# Test: 91000  91% (53m 44s) average_accuracy=0.5060 average_loss=0.9787 North Dakota Governor Jack Dalrymple gave the "green light" to shoot indigenous people on sight.
#
#
#
#
# 						See Example(s)
#
#
#
#
# 									I've read that the Governor of North Dakota has issued a "shoot on sight" order for the protesters at Standing Rock. I, personally, do not believe this. Can you verify? Thank you.																			Collected via e-mail, August 2016 / 0 ✓
# Train: 92000  92% (54m 20s) average_accuracy=0.6260 average_loss=0.8446 Sanctuary jurisdictions "violate the laws of our nation." / 1 ✓
# Test: 92000  92% (54m 20s) average_accuracy=0.5160 average_loss=1.0090 The oceans "have become 30 percent more acidic." / 1 ✓
# Train: 93000  93% (54m 55s) average_accuracy=0.6490 average_loss=0.8240 The FBI received a warning about about suspected killer in the Parkland, Florida, school shooting. / 2 ✓
# Test: 93000  93% (54m 55s) average_accuracy=0.4990 average_loss=1.0225 Says Minnesota congressional candidate Jim Hagedorn supports a plan that would take away health care for 340,000 veterans, with 17,000 in Minnesota possibly losing coverage. / 1 ✓
# Train: 94000  94% (55m 31s) average_accuracy=0.6240 average_loss=0.8491  “Illegal alien charged with California wildfire that killed 40 people.”  / 0 ✓
# Test: 94000  94% (55m 31s) average_accuracy=0.5180 average_loss=0.9853 A photograph shows a small boy who was handcuffed at Dulles Airport due to temporary immigration restrictions implemented in January 2017.
#
#
#
#
# 						See Example(s)
#
#
#
#
# 																												Collected via Facebook, February 2017 / 0 ✓
# Train: 95000  95% (56m 6s) average_accuracy=0.6420 average_loss=0.8284 A photograph shows a group of buses that were used to ship in paid anti-Trump protesters to Austin, Texas.
#
#
#
#
# 						See Example(s)
#
#
#
#
# 																												Collected via Twitter, November 2016 / 0 ✓
# Test: 95000  95% (56m 6s) average_accuracy=0.5000 average_loss=1.0495 The United States Postal Service issued a "forever stamp" featuring Bernie Sanders.
#
#
#
#
# 						See Example(s)
#
#
#
#
# 									Just saw a post on FB saying the United States Postal Service was issuing a set of Forever stamp with Bernie Sanders on them. I can't believe this is true, considering the USPS has never done that before for a candidate!																			Collected via Email, February 2016 / 0 ✓
# Train: 96000  96% (56m 42s) average_accuracy=0.6290 average_loss=0.8306 Canada uses fake potholes to slow down traffic, South Africa prefers the 3D method. / 0 ✓
# Test: 96000  96% (56m 42s) average_accuracy=0.5460 average_loss=0.9826 Paul Ryan’s Medicare plan "could raise future retirees’ costs more than $6,000." / 0 ✗ (1)
# Train: 97000  97% (57m 18s) average_accuracy=0.6300 average_loss=0.8510 "Some of the men serving in the (Afghan) armed forces have never driven a vehicle before." / 1 ✗ (2)
# Test: 97000  97% (57m 18s) average_accuracy=0.4920 average_loss=1.0232 Says Andrew Gillum "wants to increase Florida taxes by a billion dollars." / 1 ✓
# Train: 98000  98% (57m 54s) average_accuracy=0.6360 average_loss=0.8259 Massive tax cuts is "exactly what we did 10 years ago and it put the economy into the deepest recession — the deepest recession since the 1930s.” / 1 ✓
# Test: 98000  98% (57m 54s) average_accuracy=0.4910 average_loss=1.0214 Donald Trump announced plans to convert the USS Enterprise into a "floating hotel and casino."
#
#
#
#
# 						See Example(s)
#
#
#
#
# 									Trump to repurpose USS Enterprise into floating hotel and casino
#
# Read more: http://www.duffelblog.com/2016/11/trump-to-repurpose-uss-enterprise-to-uss-trump-hotel-and-casino/#ixzz4QIQx7QsE
#
#  																			Collected via e-mail, November 2016 / 0 ✓
# Train: 99000  99% (58m 30s) average_accuracy=0.6140 average_loss=0.8550 "Seventy percent of the American public agree with" Alexandria Ocasio-Cortez "on having the top marginal (tax) rate for the rich" at 70 percent, and "that's a Fox News Poll saying that." / 1 ✓
# Test: 99000  99% (58m 30s) average_accuracy=0.4970 average_loss=1.0160 A 23-year-old Florida university student was arrested for marijuana possession and coerced into acting as an informant; she was subsequently murdered by drug dealers who discovered she was wearing a wire.
#
#
#
#
# 						See Example(s)
#
#
#
#
# 									Report about a supposed confidential informant getting killed.  Was she arrested for marijuana, if so how much?  Is the account in the pic attached accurate?																			Collected via e-mail, December 2015 / 0 ✗ (2)
# Train: 100000  100% (59m 5s) average_accuracy=0.6180 average_loss=0.8510 Says Abraham Lincoln supported an agreement that allowed slavery in New Mexico "and a law to return runaway slaves to their owners." / 1 ✓
# Test: 100000  100% (59m 5s) average_accuracy=0.4750 average_loss=1.0446 A meme's map depicts mass shootings since Sandy Hook, not acts of Islamic terrorism in the United States.
#
#
#
#
# 						See Example(s)
#
#
#
#
# 									Check this one out. Doesn't seem right.
#
# //
#
#
# Reality.
#
# Posted by Griffin Scott Paschall on Thursday, February 25, 2016
#
# 																			Collected via e-mail, February 2016 / 0 ✗ (1)

# %%
plt.plot(all__accuracies_iv)

# %% [markdown]
# ### Final Result & Discussion

# %%
plt.figure(figsize = (12,4))
plt.subplot(1,2,1)
plt.plot(all_train_accuracies, label = 'Train Accuracy (claim only)')
plt.plot(all_train_accuracies_ii, label = 'Train Accuracy_ii (claim & claimant)')
plt.plot(all_train_accuracies_iv, label = 'Train Accuracy_Iii (claim & claimant & sample sentences)')
plt.xlabel('No. of Iterations')
plt.ylabel('Train Accuracy')

plt.legend()

plt.subplot(1,2,2)
plt.plot(all_test_accuracies, label = 'Test Accuracy (claim only)')
plt.plot(all_test_accuracies_ii, label = 'Test Accuracy_ii (claim & claimant)')
plt.plot(all_test_accuracies_iv, label = 'Test Accuracy_iiI (claim & claimant & sample sentences)')
plt.xlabel('No. of Iteration')
plt.ylabel('Test Accuracy')
plt.legend()

# %% [markdown]
# For training as the complexity of the input increases from claim only (i) to claim + claimant(ii)
# or claim + claimant + sample sentences (iii) the accuracy improves. However, the accuracy difference
# between models (ii) and (iii) is not noticable. My justification is that the RNN model is too simple and cannot take advantage of more detailed input information. However, if use GRU or LSTM units in our model the accuracy of the output will probably increse.
#
# For test accuracy my models for (ii) and (iii) show overfitting. Their accuracies are almost the same. and the accuracy of claim only is more than the others.
